# %% [markdown]
# # Building Planets with TidalPy
# In this notebook we will see how we can use TidalPy's object oriented approach to build a layered planet.

# %%
from pprint import pprint
from TidalPy import build_world

# %% [markdown]
# ### 2-Layer Layered World
# First we will start with a simple planet with only two layers. We will assume that the density of these layers does not depend on pressure.

# %%
io_simple = build_world('io_simple')
pprint(io_simple.config)
_ = io_simple.paint()
# Out:
# {'TidalPy_Vers': '0.2.1.dev9',
#  'albedo': 0.63,
#  'eccentricity': 0.0041,
#  'emissivity': 0.9,
#  'equilibrium_insolation_model': 'williams',
#  'force_spin_sync': True,
#  'fraction_internal_heating_to_surface': 1.0,
#  'layers': {'Core': {'density': 5200.0,
#                      'is_tidal': False,
#                      'radius': 810000.0,
#                      'type': 'iron'},
#             'Mantle': {'density': 3200.0,
#                        'is_tidal': True,
#                        'radius': 1821490.0,
#                        'surface_temperature': 100.0,
#                        'type': 'rock'}},
#  'name': 'Io_Simple',
#  'orbital_period': 1.769,
#  'pyclass': 'LayeredWorld',
#  'pyname': 'io_simple (LayeredWorld)',
#  'radius': 1821490.0,
#  'slices': None,
#  'spin_period': 1.769,
#  'store_tides_config_in_world': True,
#  'surface_pressure': 0.0,
#  'tides': {'eccentricity_truncation_lvl': 6,
#            'max_tidal_order_l': 2,
#            'multiply_modes_by_sign': True,
#            'obliquity_tides_on': True,
#            'use_planet_params_for_love_calc': False},
#  'tides_on': True,
#  'type': 'layered',
#  'use_real_moi': True}

# %% [markdown]
# ### 4-layer Layered World
# Next we will look at a slightly more complicated planet that has four layers, but we keep the assumption that density does not change with pressure.

# %%
earth_simple = build_world('earth_simple')
pprint(earth_simple.config)
_ = earth_simple.paint()
# Out:
# {'OLD_tides': {'fixed_q': 100.0, 'model': 'global_approx'},
#  'TidalPy_Vers': '0.2.1.dev9',
#  'albedo': 0.3,
#  'eccentricity': 0.01671022,
#  'emissivity': 0.9,
#  'equilibrium_insolation_model': 'williams',
#  'force_spin_sync': True,
#  'fraction_internal_heating_to_surface': 1.0,
#  'layers': {'Inner_Core': {'density': 17000.0,
#                            'is_tidal': False,
#                            'radius': 1220000.0,
#                            'type': 'iron'},
#             'Lower_Mantle': {'density': 5000.0,
#                              'is_tidal': False,
#                              'radius': 5711000.0,
#                              'type': 'rock'},
#             'Outer_Core': {'density': 12000.0,
#                            'is_tidal': False,
#                            'radius': 3480000.0,
#                            'type': 'iron'},
#             'Upper_Mantle': {'density': 3300.0,
#                              'is_tidal': True,
#                              'radius': 6371000.0,
#                              'type': 'rock'}},
#  'name': 'Earth_Simple',
#  'pyclass': 'LayeredWorld',
#  'pyname': 'earth_simple (LayeredWorld)',
#  'radius': 6371000.0,
#  'semi_major_axis': 1.0,
#  'semi_major_axis_in_au': True,
#  'slices': None,
#  'spin_period': 1.0,
#  'store_tides_config_in_world': True,
#  'surface_pressure': 0.0,
#  'tides': {'eccentricity_truncation_lvl': 6,
#            'fixed_q': 100.0,
#            'max_tidal_order_l': 2,
#            'model': 'global_approx',
#            'multiply_modes_by_sign': True,
#            'obliquity_tides_on': True,
#            'use_planet_params_for_love_calc': False},
#  'tides_on': True,
#  'type': 'layered',
#  'use_real_moi': True}

# %% [markdown]
# ### 4-layer Burnman World
# Finally, we will look a more realistic version of an Earth model where we use the Burnman package to calculate a self-consistent interior structure. Density will change with pressure and temperature. The functional form of this relationship depends on the equation of state which is different for each layer.

# %%
earth = build_world('earth')
pprint(earth.config['layers'])
_ = earth.paint()
# Out:
# {'Inner_Core': {'fixed_temperature': None,
#                 'interp_lookup_method': 'mid',
#                 'is_tidal': False,
#                 'material': 'Fe_Dewaele',
#                 'material_source': 'other',
#                 'radius': 1220000.0,
#                 'radius_lower': 0.0,
#                 'radius_upper': 1220000.0,
#                 'slices': 50,
#                 'temperature_fixed': 300.0,
#                 'temperature_mode': 'user-defined',
#                 'thickness': 1220000.0,
#                 'top_temperature': None,
#                 'type': 'iron'},
#  'Lower_Mantle': {'fixed_temperature': None,
#                   'interp_lookup_method': 'mid',
#                   'is_tidal': False,
#                   'material': 'mg_bridgmanite',
#                   'material_source': 'SLB_2011',
#                   'radius': 5711000.0,
#                   'radius_lower': 3480000.0,
#                   'radius_upper': 5711000.0,
#                   'slices': 50,
#                   'temperature_mode': 'adiabatic',
#                   'thickness': 2231000.0,
#                   'top_temperature': None,
#                   'type': 'rock'},
#  'Outer_Core': {'fixed_temperature': None,
#                 'interp_lookup_method': 'mid',
#                 'is_tidal': False,
#                 'material': 'Liquid_Fe_Anderson',
#                 'material_source': 'other',
#                 'radius': 3480000.0,
#                 'radius_lower': 1220000.0,
#                 'radius_upper': 3480000.0,
#                 'slices': 50,
#                 'temperature_fixed': 300.0,
#                 'temperature_mode': 'user-defined',
#                 'thickness': 2260000.0,
#                 'top_temperature': None,
#                 'type': 'iron'},
#  'Upper_Mantle': {'fixed_temperature': None,
#                   'interp_lookup_method': 'mid',
#                   'is_tidal': True,
#                   'material': 'forsterite',
#                   'material_source': 'SLB_2011',
#                   'radius': 6371000.0,
#                   'radius_lower': 5711000.0,
#                   'radius_upper': 6371000.0,
#                   'slices': 50,
#                   'surface_temperature': 300.0,
#                   'temperature_mode': 'adiabatic',
#                   'temperature_top': 1200.0,
#                   'thickness': 660000.0,
#                   'top_temperature': None,
#                   'type': 'rock'}}
