# %%
# Import basic libraries and tools
import os
import warnings
from time import time
from scipy.special import gamma
import math
from sympy import Rational, trigsimp, simplify, expand, factor, Abs, sign, latex, sin, cos, diff, Order, Symbol, Function
from functions.sympy_help import *
from functions.inclination_funcs import F_func
from functions.eccentricity_funcs import G_func
from functions.general_math import binomial_coeff, besselj_func
from functions.hansen import hansen_wrapper
from functions.hansen import hansen_bessel as hansen_domain_0
from functions.hansen import hansen_kIsZero_nIsNeg as hansen_domain_1
from functions.hansen import hansen_kIsZero_nIsPos as hansen_domain_2

# %%
# use real or symbolic legendre polynomials
#legP = legendreP
legP = legendreP_symbolic

# use NSR
use_nsr = True

# Set Max l
min_l = 2
max_l = 2

# Set max power of eccentricity
max_e_power = 5

max_s = 3

# Performance Notes:
#    Compiling Results for l=2, e=20 on my desktop takes 68952.3862695694 Sec (19 Hours)
#    After ^ that compile, did it for l=3, e=20 ** ** takes 104769.17482447624 Sec (29 Hours) 
#   ^^ for l=7, e=20 ^^ takes 376306.64565110207 (using function, not this notebook) (4.35 days)

max_e_calc_power = max_e_power

max_q = math.ceil(max_e_calc_power / 2)
max_q += 2
print(max_q)

if max_e_power > 18:
    warnings.warn('Setting the max eccentricity power to above 18 may require significant system memory and (until multi-processing is implemented) significant calculation times.')
# Out:
# 5

# %%
# Calculate universal coefficients
print_uni_coeffs = False
if print_uni_coeffs:
    for l in range(7, 7+1):
        for m in range(0, l+1):
            if m == 0:
                universal_coeff = Rational(gamma(1 + l - m), gamma(1 + l + m))
            else:
                universal_coeff = 2*Rational(gamma(1 + l - m), gamma(1 + l + m))
            print(l, m)
            disp(universal_coeff)

# %%
lib_A = Symbol('^{z}\\mathcal{A}_{j}', real=True, positive=True)
spin_frac = Symbol('\\mathcal{z}', real=True, positive=True)
def small_ampl_lib(m, s):
    
    if s == 0:
        return 1 - (Rational(m, 2) * lib_A)**2
    elif s > 0:
        return Rational(1, gamma(s + 1)) * (Rational(m, 2) * lib_A)**s
    elif s < 0:
        return Rational((-1)**s, gamma(-s + 1)) * (Rational(m, 2) * lib_A)**-s

# %%
# Print and/or Save to Disk Inclination Functions

print_inclines = False
reduce_fractions = True
tab = '    '

l_ = max_l

incline_str = '@njit\ndef calc_inclination(inclination: FloatArray) -> Dict[Tuple[int, int], FloatArray]:\n' + tab + '"""Calculate F^2_lmp for l = ' + f'{l_}' + '"""\n\n' + tab
incline_str += f'# Inclination Functions Calculated for l = {l_}.\n' + tab
incline_str_off = '@njit\ndef calc_inclination_off(inclination: FloatArray) -> Dict[Tuple[int, int], FloatArray]:\n' + tab + '"""Calculate F^2_lmp (assuming I=0) for l = ' + f'{l_}' + '"""\n\n' + tab
incline_str_off += f'# Inclination Functions Calculated for l = {l_}, Inclination == off.\n'

incline_str += f'# Optimizations\n' + tab
incline_str += 'i = inclination\n' + tab
incline_str += 'i_half = i / 2.\n' + tab
incline_str += 'i_double = 2. * i\n' + tab
incline_str += 'i_triple = 3. * i\n' + tab
incline_str += 'sin_i = np.sin(i)\n' + tab
incline_str += 'cos_i = np.cos(i)\n' + tab
incline_str += 'sin_i_half = np.sin(i_half)\n' + tab
incline_str += 'cos_i_half = np.cos(i_half)\n' + tab
incline_str += 'sin_i_double = np.sin(i_double)\n' + tab
incline_str += 'cos_i_double = np.cos(i_double)\n' + tab
incline_str += 'sin_i_triple = np.sin(i_triple)\n' + tab
incline_str += 'cos_i_triple = np.cos(i_triple)\n' + '\n'

incline_str += tab + 'inclination_results = {\n'

incline_str_off += tab + 'ones_ = np.ones_like(inclination)\n\n'
incline_str_off += tab + 'inclination_results = {\n'

for m in range(0, l_ + 1):

    for p in range(0, l_ + 1):

        F2 = trigsimp(F_func(l_, m, p, obliquity_sat)**2)
        if print_inclines:
            print(l_, m, p)
            disp(F2)
        F2_off = F2.subs(obliquity_sat, 0)
        if reduce_fractions:
            F2 = F2.evalf(25)
            F2_off = F2_off.evalf(25)
        F2_str = str(F2)
        F2_off_str = str(F2_off)
        F2_str = F2_str.replace('sin(I___S/2)', 'sin_i_half')
        F2_str = F2_str.replace('cos(I___S/2)', 'cos_i_half')
        F2_str = F2_str.replace('sin(2*I___S)', 'sin_i_double')
        F2_str = F2_str.replace('cos(2*I___S)', 'cos_i_double')
        F2_str = F2_str.replace('sin(3*I___S)', 'sin_i_triple')
        F2_str = F2_str.replace('cos(3*I___S)', 'cos_i_triple')
        F2_str = F2_str.replace('sin(I___S)', 'sin_i')
        F2_str = F2_str.replace('cos(I___S)', 'cos_i')

        if F2_str == '0':
            pass
        else:
            incline_str += 2*tab + f'({m}, {p}) : ' + F2_str
            if m == l_ and p == l_:
                incline_str += '\n'
            else:
                incline_str += ',\n'

        if F2_off_str == '0':
            pass
        else:
            incline_str_off += 2*tab + f'({m}, {p}) : ' + F2_off_str + ' * ones_'
            if m == l_ and p == l_:
                incline_str_off += '\n'
            else:
                incline_str_off += ',\n'

incline_str += tab + '}\n'
incline_str += '\n' + tab + 'return inclination_results\n'
incline_str_off += tab + '}\n'
incline_str_off += '\n' + tab + 'return inclination_results\n'

file_name = f'NSR Dissipation - TidalPy Output - Inclination Output for {l_}.py'
with open(file_name, 'w') as incline_file:
    incline_file.write(incline_str_off + '\n\n')
    incline_file.write(incline_str)

# %%
## Comparison to Kaula...
compare_to_kaula = False

if compare_to_kaula:
    f_table_kaula = {
        (2, 0, 0): -Rational(3, 8) * (sin(obliquity_sat))**2,
        (2, 0, 1): Rational(3, 4) * (sin(obliquity_sat))**2 - Rational(1, 2),
        (2, 0, 2): -Rational(3, 8) * (sin(obliquity_sat))**2,
        (2, 1, 0): Rational(3, 4) * sin(obliquity_sat)*(1 + cos(obliquity_sat)),
        (2, 1, 1): -Rational(3, 2) * sin(obliquity_sat) * cos(obliquity_sat),
        (2, 1, 2): Rational(3, 4) * sin(obliquity_sat) * (cos(obliquity_sat) - 1),
        (2, 2, 0): Rational(3, 4) * (1 + cos(obliquity_sat))**2,
        (2, 2, 1): Rational(3, 2) * (sin(obliquity_sat))**2,
        (2, 2, 2): Rational(3, 4) * (1 - cos(obliquity_sat))**2,

    }

    for m in range(0, 2+1):
        for p in range(0, 2+1):
            print(2, m, p)
            disp(taylor(trigsimp(f_table_sat[(2, m, p)] / f_table_kaula[(2, m, p)]), obliquity_sat, 2))

# %%
# Test what q-values we should include.taylor(func, x, n, x0=0., debug=False)
show_q_check = False
show_all_relavent_qs = False
show_specific_qs = []

if show_q_check:
    if show_all_relavent_qs:
        q_range = range(-max_q, max_q+1)
    else:
        q_range = show_specific_qs

    for q_ in q_range:
        
        print('... next q ...')
        print(f'\tq = {q_}')
        for p_ in [0, 1, 2]:
            print('... next p ...')
            print(f'\tp = {p_}')
            t_i = time()
            _, g_ = G_func(2, p_, q_, eccentricity, cutoff_power=max_e_calc_power)
            print(f'Calc Time = {time() - t_i}')
            
#             print('\tG')
#             disp(g)
            print('\tG^2')
            
            t_i = time()
            if g_.getO() is None:
                res = g_**2
            else:
                g_ = g_.removeO()**2
                res = taylor(g_, eccentricity, max_e_calc_power+1)
            print(f'Taylor Time = {time() - t_i}')
            disp(res)

# %%
# Primary Calculation Point: Build eccentricity, obliquity, and mode tables

print_list = False
build_tables = True
loud_eccentricity_funcs = True

g_table = dict()
f_table_host = dict()
f_table_sat = dict()
g2_table = dict()
f2_table_host = dict()
f2_table_sat = dict()
omega_table_host = dict()
omega_table_sat = dict()
freq_table_host = dict()
freq_table_sat = dict()
sign_table_host = dict()
sign_table_sat = dict()
love_table_host = dict()
love_table_sat = dict()
love_omg_table_host = dict()
love_omg_table_sat = dict()


omega_table_sat_LIB = dict()
freq_table_sat_LIB = dict()
sign_table_sat_LIB = dict()
love_table_sat_LIB = dict()
love_omg_table_sat_LIB = dict()

init_time = time()

if print_list or build_tables:
    for l in range(min_l, max_l+1):
        
        try:
            love_func_host = love_func_lookup['host'][l]
            love_func_sat = love_func_lookup['sat'][l]
        except KeyError:
            raise NotImplemented(f'l = {l} has not been implemented.')
        
        for m in range(0, l+1):
            for p in range(0, l+1):
                
                if build_tables:
                    # Build Inclination (Obliquity) Tables
                    f_table_host[(l, m, p)] = F_func(l, m, p, obliquity_host, auto_taylor=False, run_trigsimp=False)
                    f_table_sat[(l, m, p)] = F_func(l, m, p, obliquity_sat, auto_taylor=False, run_trigsimp=False)
                    f2_table_host[(l, m, p)] = simplify(expand(f_table_host[(l, m, p)] * f_table_host[(l, m, p)]))
                    f2_table_sat[(l, m, p)] = simplify(expand(f_table_sat[(l, m, p)] * f_table_sat[(l, m, p)]))
        
                for q in range(-max_q, max_q+1):
                    
                    if build_tables:
                        # Build Eccentricity Tables
                        if m == 0:
                            # There are only unique eccentricity functions for the m=0 (they are the same for other m's)
                            q_init_time = time()
                            if loud_eccentricity_funcs:
                                print(f'Building: ({l}, {m}, {p}, {q})  ')
                            
                            is_exact, g_table[(l, p, q)] = G_func(l, p, q, eccentricity, max_e_calc_power, going_to_square=True)
                            
                            if is_exact:
                                g2_table[(l, p, q)] = simplify(g_table[(l, p, q)]**2)
                            else:
                                g2_table[(l, p, q)] = taylor(g_table[(l, p, q)].removeO()**2, eccentricity,
                                                             max_e_calc_power+1)
                            
                            if loud_eccentricity_funcs:
                                print(f'\tTime to Build Mode: {time() - q_init_time:0.2f} s')
                    
                    # Build Mode and Frequency Tables
                    omega_table_host[(l, m, p, q)] = (l - 2*p + q)*mean_n - m*spin_host
                    omega_table_sat[(l, m, p, q)] = (l - 2*p + q)*mean_n - m*spin_sat
                    freq_table_host[(l, m, p, q)] = Abs(omega_table_host[(l, m, p, q)])
                    freq_table_sat[(l, m, p, q)] = Abs(omega_table_sat[(l, m, p, q)])
                    sign_table_host[(l, m, p, q)] = sign(omega_table_host[(l, m, p, q)])
                    sign_table_sat[(l, m, p, q)] = sign(omega_table_sat[(l, m, p, q)])
                    
                    for s in range(-max_s, max_s+1):
                        omega_table_sat_LIB[(l, m, p, q, s)] = (l - 2 * p - m * spin_frac + q - s) * mean_n
                        freq_table_sat_LIB[(l, m, p, q, s)] = Abs(omega_table_sat_LIB[(l, m, p, q, s)])
                        sign_table_sat_LIB[(l, m, p, q, s)] = sign(omega_table_sat_LIB[(l, m, p, q, s)])
                        
                        if omega_table_sat_LIB[(l, m, p, q, s)] == 0:                            
                            love_table_sat_LIB[(l, m, p, q, s)] = 0
                            love_omg_table_sat_LIB[(l, m, p, q, s)] = 0
                        else:
                            love_table_sat_LIB[(l, m, p, q, s)] = love_func_sat(freq_table_sat_LIB[(l, m, p, q, s)])
                            love_omg_table_sat_LIB[(l, m, p, q, s)] = love_func_sat(omega_table_sat_LIB[(l, m, p, q, s)])
                            
                            
                    
                    # Build Love Number Tables
                    if omega_table_host[(l, m, p, q)] == 0:
                        love_table_host[(l, m, p, q)] = 0
                        love_omg_table_host[(l, m, p, q)] = 0
                    else:
                        love_table_host[(l, m, p, q)] = love_func_host(freq_table_host[(l, m, p, q)])
                        love_omg_table_host[(l, m, p, q)] = love_func_host(omega_table_host[(l, m, p, q)])
                    if omega_table_sat[(l, m, p, q)] == 0:
                        love_table_sat[(l, m, p, q)] = 0
                        love_omg_table_sat[(l, m, p, q)] = 0
                    else:
                        love_table_sat[(l, m, p, q)] = love_func_sat(freq_table_sat[(l, m, p, q)])
                        love_omg_table_sat[(l, m, p, q)] = love_func_sat(omega_table_sat[(l, m, p, q)])
                    
                    if print_list:
                        disp('')
                        print(f'\nl, m, p, q = {l}{m}{p}{q}')
                        print('\tMode_h=')
                        disp(nsimplify(omega_table_host[(l, m, p, q)]))
                        print('\tG(e)=')
                        disp(nsimplify(g_table[(l, p, q)]))
                        print('\tF_h(I)=')
                        disp(nsimplify(f_table_host[(l, m, p)]))

delta_time = time() - init_time
if delta_time >=300:
    time_txt = f'{delta_time/60:0.4f} Mins'
elif delta_time >= 7200:
    time_txt = f'{delta_time/(60*60):0.4f} Hours'
elif delta_time >= 86400:
    time_txt = f'{delta_time/(60*60*24):0.4f} Days'
else:
    time_txt = f'{delta_time:0.2f} Secs'
print(f'Total Time to Construct Tables: {time_txt}')
# Out:
# Building: (2, 0, 0, -5)
# Starting Hansen Calculation (Bessel Domain, CO=3)
# 0
# 0[                              ]
# 0[########                      ]
# 0[###############               ]
# 0[#######################       ]
# 	[##############################]
# 	Time to Build Mode: 0.08 s
# Building: (2, 0, 0, -4)
# Starting Hansen Calculation (Bessel Domain, CO=3)
# 0
# 0[                              ]
# 0[########                      ]
# 0[###############               ]
# 0[#######################       ]
# 	[##############################]
# 	Time to Build Mode: 0.01 s
# Building: (2, 0, 0, -3)
# Starting Hansen Calculation (Bessel Domain, CO=3)
# e**3/48
# O(e**3)                         ]
# O(e**3)###                      ]
# O(e**3)##########               ]
# O(e**3)##################       ]
# 	[##############################]
# 	Time to Build Mode: 0.02 s
# Building: (2, 0, 0, -2)
# 	Time to Build Mode: 0.00 s
# Building: (2, 0, 0, -1)
# Starting Hansen Calculation (Bessel Domain, CO=5)
# -e**5/384 + e**3/16 - e/2
# (-e**3/8 - e/2)*(e**4/24 - e**2/2) - e/2 + e**3/16 + O(e**5)
# -e/2 + 5*e**3/16 + O(e**5)      ]
# -e/2 + 5*e**3/16 + O(e**5)      ]
# -e/2 + 5*e**3/16 + O(e**5)      ]
# -e/2 + 5*e**3/16 + O(e**5)      ]
# -e/2 + 5*e**3/16 + O(e**5)#     ]
# 	[##############################]
# 	Time to Build Mode: 0.25 s
# Building: (2, 0, 0, 0)
# Starting Hansen Calculation (Bessel Domain, CO=6)
# -e**6/36 + e**4/4 - e**2 + 1
# 1 + (-e**5/16 - e**3/8 - e/2)*(e**5/3 - 2*e**3 + 4*e) - e**2 + e**4/4 + O(e**6)
# 1 + (-e**5/16 - e**3/8 - e/2)**2*(5*e**6/24 - 5*e**4/3 + 5*e**2) - 3*e**2 + 3*e**4/4 + O(e**6)
# 1 - 3*e**2 + 2*e**4 + O(e**6)   ]
# 1 - 3*e**2 + 2*e**4 + O(e**6)   ]
# 1 - 3*e**2 + 2*e**4 + O(e**6)   ]
# 1 - 3*e**2 + 2*e**4 + O(e**6)   ]
# 1 - 3*e**2 + 2*e**4 + O(e**6)   ]
# 	[##############################]
# 	Time to Build Mode: 0.42 s
# Building: (2, 0, 0, 1)
# Starting Hansen Calculation (Bessel Domain, CO=5)
# 81*e**5/128 - 27*e**3/16 + 3*e/2
# (-e**3/8 - e/2)*(-81*e**4/16 + 9*e**2 - 4) + 3*e/2 - 27*e**3/16 + O(e**5)
# (-e**3/8 - e/2)**2*(-405*e**5/64 + 135*e**3/8 - 15*e) + 7*e/2 - 91*e**3/16 + O(e**5)
# 7*e/2 - 151*e**3/16 + O(e**5)   ]
# 7*e/2 - 151*e**3/16 + O(e**5)   ]
# 7*e/2 - 151*e**3/16 + O(e**5)   ]
# 7*e/2 - 151*e**3/16 + O(e**5)   ]
# 	[##############################]
# 	Time to Build Mode: 0.26 s
# Building: (2, 0, 0, 2)
# Starting Hansen Calculation (Bessel Domain, CO=4)
# -8*e**4/3 + 2*e**2
# (-e**3/8 - e/2)*(16*e**3 - 8*e) + 2*e**2 + O(e**4)
# (-e**3/8 - e/2)**2*(40*e**4 - 40*e**2 + 10) + 6*e**2 + O(e**4)
# 17*e**2/2 + O(e**4)             ]
# 17*e**2/2 + O(e**4)#            ]
# 17*e**2/2 + O(e**4)#######      ]
# 	[##############################]
# 	Time to Build Mode: 0.15 s
# Building: (2, 0, 0, 3)
# Starting Hansen Calculation (Bessel Domain, CO=3)
# 125*e**3/48
# O(e**3)                         ]
# O(e**3)###                      ]
# O(e**3)##########               ]
# O(e**3)##################       ]
# 	[##############################]
# 	Time to Build Mode: 0.04 s
# Building: (2, 0, 0, 4)
# Starting Hansen Calculation (Bessel Domain, CO=3)
# 0
# 9*e**4                          ]
# O(e**3)###                      ]
# O(e**3)##########               ]
# O(e**3)##################       ]
# 	[##############################]
# 	Time to Build Mode: 0.03 s
# Building: (2, 0, 0, 5)
# Starting Hansen Calculation (Bessel Domain, CO=3)
# 0
# 0[                              ]
# 1715*e**5/96                    ]
# O(e**3)##########               ]
# O(e**3)##################       ]
# 	[##############################]
# 	Time to Build Mode: 0.02 s
# Building: (2, 0, 1, -5)
# Starting Hansen Calculation (Bessel Domain, CO=3)
# 0
# 0[                              ]
# 125*e**5/64                     ]
# O(e**3)##########               ]
# O(e**3)##################       ]
# 	[##############################]
# 	Time to Build Mode: 0.02 s
# Building: (2, 0, 1, -4)
# Starting Hansen Calculation (Bessel Domain, CO=3)
# 0
# 4*e**4/3                        ]
# O(e**3)###                      ]
# O(e**3)##########               ]
# O(e**3)##################       ]
# 	[##############################]
# 	Time to Build Mode: 0.03 s
# Building: (2, 0, 1, -3)
# Starting Hansen Calculation (Bessel Domain, CO=3)
# 9*e**3/16
# O(e**3)                         ]
# O(e**3)###                      ]
# O(e**3)##########               ]
# O(e**3)##################       ]
# 	[##############################]
# 	Time to Build Mode: 0.03 s
# Building: (2, 0, 1, -2)
# Starting Hansen Calculation (Bessel Domain, CO=4)
# -e**4/6 + e**2/2
# (-e**3/8 - e/2)*(2*e**3/3 - 2*e) + e**2/2 + O(e**4)
# (-e**3/8 - e/2)**2*(5*e**4/24 - e**2 + 3) + 3*e**2/2 + O(e**4)
# 9*e**2/4 + O(e**4)              ]
# 9*e**2/4 + O(e**4)##            ]
# 9*e**2/4 + O(e**4)########      ]
# 	[##############################]
# 	Time to Build Mode: 0.11 s
# Building: (2, 0, 1, -1)
# Starting Hansen Calculation (Bessel Domain, CO=5)
# e**5/384 - e**3/16 + e/2
# (-e**3/8 - e/2)*(-e**4/96 + e**2/4 - 2) + e/2 - e**3/16 + O(e**5)
# (-e**3/8 - e/2)**2*(-e**5/768 + e/2) + 3*e/2 + e**3/16 + O(e**5)
# (e**2/4 - 6)*(-e**3/8 - e/2)**3 + 3*e/2 + 3*e**3/16 + O(e**5)
# 3*e/2 + 15*e**3/16 + O(e**5)    ]
# 3*e/2 + 15*e**3/16 + O(e**5)    ]
# 3*e/2 + 15*e**3/16 + O(e**5)    ]
# 	[##############################]
# 	Time to Build Mode: 0.20 s
# Building: (2, 0, 1, 0)
# 	Time to Build Mode: 0.03 s
# Building: (2, 0, 1, 1)
# 	Time to Build Mode: 0.01 s
# Building: (2, 0, 1, 2)
# 	Time to Build Mode: 0.00 s
# Building: (2, 0, 1, 3)
# 	Time to Build Mode: 0.00 s
# Building: (2, 0, 1, 4)
# 	Time to Build Mode: 0.00 s
# Building: (2, 0, 1, 5)
# 	Time to Build Mode: 0.00 s
# Building: (2, 0, 2, -5)
# 	Time to Build Mode: 0.00 s
# Building: (2, 0, 2, -4)
# 	Time to Build Mode: 0.00 s
# Building: (2, 0, 2, -3)
# 	Time to Build Mode: 0.00 s
# Building: (2, 0, 2, -2)
# 	Time to Build Mode: 0.00 s
# Building: (2, 0, 2, -1)
# 	Time to Build Mode: 0.01 s
# Building: (2, 0, 2, 0)
# 	Time to Build Mode: 0.02 s
# Building: (2, 0, 2, 1)
# 	Time to Build Mode: 0.02 s
# Building: (2, 0, 2, 2)
# 	Time to Build Mode: 0.00 s
# Building: (2, 0, 2, 3)
# Starting Hansen Calculation (Bessel Domain, CO=3)
# e**3/48
# O(e**3)                         ]
# O(e**3)###                      ]
# O(e**3)##########               ]
# O(e**3)##################       ]
# 	[##############################]
# 	Time to Build Mode: 0.01 s
# Building: (2, 0, 2, 4)
# Starting Hansen Calculation (Bessel Domain, CO=3)
# 0
# 0[                              ]
# 0[########                      ]
# 0[###############               ]
# 0[#######################       ]
# 	[##############################]
# 	Time to Build Mode: 0.00 s
# Building: (2, 0, 2, 5)
# Starting Hansen Calculation (Bessel Domain, CO=3)
# 0
# 0[                              ]
# 0[########                      ]
# 0[###############               ]
# 0[#######################       ]
# 	[##############################]
# 	Time to Build Mode: 0.01 s
# Total Time to Construct Tables: 3.80 Secs

# %%
from pprint import pprint
import copy

gtemp_table = copy.deepcopy(g_table)

for key, dat in g_table.items():
    try:
        gtemp_table[key] = dat.removeO()
    except:
        continue


pprint(gtemp_table)
# Out:
# {(2, 0, -5): 0,
#  (2, 0, -4): 0,
#  (2, 0, -3): 0,
#  (2, 0, -2): 0,
#  (2, 0, -1): e**3/16 - e/2,
#  (2, 0, 0): 13*e**4/16 - 5*e**2/2 + 1,
#  (2, 0, 1): -123*e**3/16 + 7*e/2,
#  (2, 0, 2): 17*e**2/2,
#  (2, 0, 3): 0,
#  (2, 0, 4): 0,
#  (2, 0, 5): 0,
#  (2, 1, -5): 0,
#  (2, 1, -4): 0,
#  (2, 1, -3): 0,
#  (2, 1, -2): 9*e**2/4,
#  (2, 1, -1): 27*e**3/16 + 3*e/2,
#  (2, 1, 0): (1 - e**2)**(-3/2),
#  (2, 1, 1): 27*e**3/16 + 3*e/2,
#  (2, 1, 2): 9*e**2/4,
#  (2, 1, 3): 0,
#  (2, 1, 4): 0,
#  (2, 1, 5): 0,
#  (2, 2, -5): 0,
#  (2, 2, -4): 0,
#  (2, 2, -3): 0,
#  (2, 2, -2): 17*e**2/2,
#  (2, 2, -1): -123*e**3/16 + 7*e/2,
#  (2, 2, 0): 13*e**4/16 - 5*e**2/2 + 1,
#  (2, 2, 1): e**3/16 - e/2,
#  (2, 2, 2): 0,
#  (2, 2, 3): 0,
#  (2, 2, 4): 0,
#  (2, 2, 5): 0}

# %%
# Print Python Function Cache Information
print_cache = False
if print_cache:
    
    print('G and F Funcs')
    print('Inclination Function')
    print(F_func.cache_info())
    print('Eccentricity Function')
    print(G_func.cache_info())
    
    print('\nEccentricity Func Components\nHansen Wrapper')
    print(hansen_wrapper.cache_info())
    print('Hansen Bessel Domain')
    print(hansen_domain_0.cache_info())
    print('Hansen k=0, n>=0')
    print(hansen_domain_1.cache_info())
    print('Hansen k=0, n<0')
    print(hansen_domain_2.cache_info())
    
    print('\nOther Math Funcs')
    print('Binomial Coefficient')
    print(binomial_coeff.cache_info())
    print('Bessel Function')
    print(besselj_func.cache_info())

# %% [markdown]
# ## Tidal Potential Derivative Calculations

# %%
physical_coeffs_sat = dict()
physical_coeffs_host = dict()
eccen_inclin_coeffs_sat = dict()
eccen_inclin_coeffs_sat_LIB = dict()
LIB_COEFF = dict()
love_coeffs_sat_LIB = dict()
universal_coeffs_LIB = dict()
love_coeffs_sat = dict()
eccen_inclin_coeffs_host = dict()
love_coeffs_host = dict()
universal_coeffs = dict()
dUdM_coeffs = dict()
dUdw_coeffs = dict()
dUdO_coeffs = dict()
full_potential_coeffs = dict()
potential_coeffs = dict()
varpis = list()

for l in range(min_l, max_l+1):
    for m in range(0, l+1):
        for p in range(0, l+1):
            F_S1 = f_table_sat[(l, m, p)]
            F_H2 = f2_table_host[(l, m, p)]
            F_S2 = f2_table_sat[(l, m, p)]
            
            for q in range(-max_q, max_q+1):
                
                sgn_H = sign_table_host[(l, m, p, q)]
                sgn_S = sign_table_sat[(l, m, p, q)]
                freq_H = freq_table_host[(l, m, p, q)]
                freq_S = freq_table_sat[(l, m, p, q)]
                omg_H = omega_table_host[(l, m, p, q)]
                omg_S = omega_table_sat[(l, m, p, q)]
                love_H = love_table_host[(l, m, p, q)]
                love_S = love_table_sat[(l, m, p, q)]
                love_omg_H = love_omg_table_host[(l, m, p, q)]
                love_omg_S = love_omg_table_sat[(l, m, p, q)]
                
                G2 = g2_table[(l, p, q)]
                G_ = g_table[(l, p, q)]
                
                eccen_inclin_coeffs_host[(l, m, p, q)] = factor(expand(G2 * F_H2).removeO())
                eccen_inclin_coeffs_sat[(l, m, p, q)] = factor(expand(G2 * F_S2).removeO())
                
                if m == 0:
                    lm_coeff = Rational(gamma(1 + l - m), gamma(1 + l + m))
                else:
                    lm_coeff = 2 * Rational(gamma(1 + l - m), gamma(1 + l + m))
                    
                universal_coeffs[(l, m, p, q)] = lm_coeff
                
                for q_prime in range(-max_q, max_q+1):
                    
                    G_prime = g_table[(l, p, q_prime)]
                    GG_F = factor(expand(G_ * G_prime * F_S2).removeO())
                    
                    for s in range(-max_s, max_s+1):
                        LIB_COEFF[(l, m, p, q, q_prime, s)] = small_ampl_lib(m, q_prime - q + s) * small_ampl_lib(m, s)
                        love_coeffs_sat_LIB[(l, m, p, q, q_prime, s)] = love_table_sat_LIB[(l, m, p, q, s)]
                        eccen_inclin_coeffs_sat_LIB[(l, m, p, q, q_prime, s)] = GG_F
                        universal_coeffs_LIB[(l, m, p, q, q_prime, s)] = lm_coeff
                 
                love_coeffs_sat[(l, m, p, q)] = love_S * sgn_S
                love_coeffs_host[(l, m, p, q)] = love_H * sgn_H
                
                dUdM_coeffs[(l, m, p, q)] = l - 2*p + q
                dUdw_coeffs[(l, m, p, q)] = l - 2*p
                dUdO_coeffs[(l, m, p, q)] = m
                
                # The overall negative on the potential is author dependent. Leaving it off for now.
                potential_coeffs[(l, m, p, q)] = \
                    (newton_G * mass_host / semi_major_axis) * lm_coeff * (r_sat / semi_major_axis)**(l) * legP(l, m, cos(latitude)) * factor(expand(G_ * F_S1).removeO())
                varpi = find_varpi(l, m, p, q)
                if varpi not in varpis:
                    varpis.append(varpi)
                if (l-m) % 2 == 0:
                    potential_coeffs[(l, m, p, q)] *= cos(varpi - m * (longitude + sidereal_time))
                else:                    
                    potential_coeffs[(l, m, p, q)] *= sin(varpi - m * (longitude + sidereal_time))
                    
                full_potential_coeffs[(l, m, p, q)] = 1
                
                # For the purposes of putting coefficients into TidalPy, I want every thing reduced by a factor of 
                #    (3 / 2) as that will be multipled by tidal susceptibility in a later step. 
                universal_coeffs[(l, m, p, q)] /= Rational(3, 2)
                
                physical_coeffs_host[(l, m, p, q)] = \
                    ((radius_host / semi_major_axis)**(2*l + 1) * newton_G * mass_sat) / semi_major_axis
                physical_coeffs_sat[(l, m, p, q)] = \
                    ((radius_sat / semi_major_axis)**(2*l + 1) * newton_G * mass_host) / semi_major_axis
                
print('Completed Coeff Tables Calculations')
# Out:
# Completed Coeff Tables Calculations

# %% [markdown]
# ## Print and save Eccentricity Results

# %%
save_tidalpy_data = False
max_e_toconvert_power_sign = 6
reduce_to_floats = False
if save_tidalpy_data:
    
    output_file = f'NSR Dissipation - TidalPy Output - min_order_l {min_l} - max_e {max_e_power}.py'
    
    tab = '    '
    eccentricity_section = '# Unique results.\neccentricity_results_bymode = {\n'
    eccentricity_dupes_section = '\n# Duplicate results are stored as dictionary lookups to previous calculations\n#    Generally leads to a 30--50% speed-up when working with large arrays.\n'
    eccentricity_preamble = f'# Eccentricity functions calculated at truncation level {max_e_power}.\n' +\
                            f'#     and order-l = {min_l}.\n\n'
    needed_eccens = dict()
    eccens_grabbed = list()
    unique_funcs = dict()
    max_e_text_len = 1
    for i in range(2, max_e_power+1, 2):
        needed_eccens[f'e**{i}'] = f'e{i}'
        max_e_text_len = max(max_e_text_len, len(f'e{i}'))
    
    num_eccen = len(g2_table)
    curr_eccen = 0
    
    for l in range(min_l, min_l+1):
        if max_l != min_l:
            raise Exception('TidalPy Printing only designed to work on one "l" at a time.')
            
        for p in range(0, l+1):

            # Make a new p subsection
            eccentricity_section += tab + f'{p}: ' + '{\n'
            
            # Need to include at least one item in each p otherwise njit will not compile correctly
            p_used = False

            for q in range(-max_q, max_q+1):

                gfunc = g2_table[(l, p, q)].removeO()
                if (l, p, q) not in eccens_grabbed:
                    eccens_grabbed.append((l, p, q))

                    # Clean up the equation text
                    if reduce_to_floats:
                        gfunc_clean = str(gfunc.evalf())
                    else:
                        gfunc_clean = str(gfunc)
                    for old_text in list(reversed(sorted(needed_eccens.keys()))):
                            # Get rid of "e**N" in favor of "eN" which are precomputed
                            new_text = needed_eccens[old_text]
                            gfunc_clean = gfunc_clean.replace(old_text, new_text)

                    if gfunc_clean not in unique_funcs or not p_used:
                        
                        if gfunc_clean == '0':
                            # Ignore 0's
                            continue

                        # Unique equation
                        unique_funcs[gfunc_clean] = (l, p, q)


                        # Record the new equation
                        if q < 0:
                            mode_text = f'{q}: '
                        else:
                            mode_text = f'{q}:  '
                        eccentricity_section += 2*tab + mode_text + gfunc_clean
                        if curr_eccen == num_eccen - 1:
                            eccentricity_section += '\n}\n'
                        else:
                            eccentricity_section += ',\n'
                            
                        # Note that at least one thing was added to this p-dict
                        p_used = True
                    else:
                        
                        # If it is a duplicate, simply point to the old equation to save on computation
                        if gfunc_clean == '0':
                            # Ignore 0's
                            continue
                        
                        old_copy_key = unique_funcs[gfunc_clean]
                        old_l, old_p, old_q = old_copy_key
                        eccentricity_dupes_section += f'eccentricity_results_bymode[{p}][{q}] = eccentricity_results_bymode[{old_p}][{old_q}]\n'

                    curr_eccen += 1

            # End the previous p section
            if p == l:
                eccentricity_section += tab + '}\n}'
            else:
                eccentricity_section += tab + '},\n'
                    
                    
    eccentricity_preamble += '# Performance and readability improvements\n'
    eccentricity_preamble += 'e = eccentricity\n'    
    for old_text, new_text in needed_eccens.items():
        for max_e_conversion in range(2, max_e_toconvert_power_sign+2, 2):
            if f'**{max_e_conversion}' == old_text[-3:]:
                old_text = ' * '.join(list('e'*max_e_conversion))
                break
        eccentricity_preamble += f'{new_text}' + ' ' * (max_e_text_len-len(new_text)) + f' = {old_text}\n'
        
    eccentricity_section = eccentricity_preamble + '\n' + eccentricity_section + '\n' + eccentricity_dupes_section
    
    with open(output_file, 'w') as output_file:
        output_file.write(eccentricity_section)

# %%
save_latex_table = False
if save_latex_table:
    
    unique_modes = list()
    unique_freqs = list()
    max_eq_length = 100
    
    table_preamble = \
        '\\begin{landscape}\n' + \
        '\\fudge{3cm}{1.5cm} % 3cm longer and raise by 1.5cm\n' + \
        '\\begin{longtable}[c]{@{}c|c|cccc|c|l@{}}\n' + \
        '    \\caption{Caption \\label{tab:dissipation_order10}} \\\\ \\toprule\n' + \
        '    \tMode & Signature & \\multicolumn{4}{c|}{Coefficients, $C_{X}$} & Inclination Function & Eccentricity Function \\\\\n' + \
        '    $\\omega_{j}$ & $l$, $m$, $p$, $q$ & $\\frac{dU_{j}}{d\\mathcal{M}}$ & $\\frac{dU_{j}}{d\\varpi_{j}}$ & $\\frac{dU_{j}}{d\\Omega_{j}}$ & $\\dot{E}_{j}$ & $F^{2}$ & $G^{2}$ \\\\ \\midrule\n' + \
        '    \\midrule           % line head body\n' + \
        '    \\endfirsthead      % Definition of 1. table header\n' + \
        '    \\toprule\n' + \
        '    \\multicolumn{8}{c}{continue table}\\\\\n' + \
        '    Mode & Signature & \\multicolumn{4}{c|}{Coefficients, $C_{X}$} & Inclination Function & Eccentricity Function \\\\\n' + \
        '    $\\omega_{j}$ & $l$, $m$, $p$, $q$ & $\\frac{dU_{j}}{d\\mathcal{M}}$ & $\\frac{dU_{j}}{d\\varpi_{j}}$ & $\\frac{dU_{j}}{d\\Omega_{j}}$ & $\\dot{E}_{j}$ & $F^{2}$ & $G^{2}$ \\\\ \\midrule\n' + \
        '    \\midrule           % line head body\n' + \
        '    \\endhead      % Definition of all following headers\n' + \
        '    \\midrule\n' + \
        '    \\multicolumn{8}{c}{table continues} \\\\ % footer 1. (and more) part(s) of table\n' + \
        '    \\midrule\n' + \
        '    \\endfoot      % foots of the table without the last one\n' + \
        '    \\bottomrule\n' + \
        '    \\endlastfoot  % the last(!!) foot of the table  %%%%%\n' 
    
    table_postamble = \
        '\\end{longtable}\n' + \
        '\\end{landscape}\n'
    
    
    mode_str = ''
    
    for l in range(min_l, max_l+1):
        for m in range(0, l+1):
            for p in range(0, l+1):
                
                this_incline_grabbed = False
                ffunc = f2_table_sat[(l, m, p)]
                ffunc = simplify(ffunc)
                
                for q in range(-max_q, max_q+1):
                    
                    gfunc = g2_table[(l, p, q)].removeO()
                    
                    # Check if G or F funcs are zero. skip if they are
                    if ffunc == 0 or gfunc == 0:
                        continue
                    
                    # If not skipped then we need to add a line. Add the tab
                    mode_str += '\n'  # Line break before new mode.
                    mode_str += f'    % Mode (lmpq) = ({l}, {m}, {p}, {q})\n' # Add a comment for easy searching within the latex
                    mode_str += '    '
                    
                    # Then check if the tidal mode is zero
                    omg_S = omega_table_sat[(l, m, p, q)]
                    if omg_S == 0:
                        continue
                        
                    omg_S_str = str(omg_S).replace('Omega___S', '\\ddot{\\theta}_{j}')
                    omg_S_str = omg_S_str.replace('*', '')
                    mode_str += '$' + omg_S_str + '$'
                    
                    # Store unique modes and freqs
                    if omg_S not in unique_modes:
                        unique_modes.append(omg_S)
                    freq_S = expand(abs(omg_S))
                    if freq_S not in unique_freqs:
                        unique_freqs.append(freq_S)
                    
                    # Next the lmpq
                    if q < 0:
                        mode_str += ' & ' + f'{l}, {m}, {p}, {q}'
                    else:
                        mode_str += ' & ' + f'{l}, {m}, {p}, \;{q}'
                    
                    # Then the coefficients
                    dUdM_coeff = dUdM_coeffs[(l, m, p, q)]
                    dUdw_coeff = dUdw_coeffs[(l, m, p, q)]
                    dUdO_coeff = dUdO_coeffs[(l, m, p, q)]
                    heating_coeff = 1
                    uni_coeff = universal_coeffs[(l, m, p, q)]
                    dUdM_coeff *= uni_coeff
                    dUdw_coeff *= uni_coeff
                    dUdO_coeff *= uni_coeff
                    heating_coeff *= uni_coeff
                    
                    mode_str += ' & $' + latex(dUdM_coeff) + '$ & $' + latex(dUdw_coeff) + '$ & $' + latex(dUdO_coeff) + \
                        '$ & $' + latex(heating_coeff) + '$ & \n'
                    mode_str += '    '
                    
                    # Now the inclination functions
                    if not this_incline_grabbed:
                        
                        # Clean up inclination function string
                        incline_str = latex(ffunc).replace('_{S}', '_{j}')
                        incline_str = incline_str.replace('I^{}', 'I')
                        incline_str = incline_str.replace('\\frac{I_{j}}{2}', 'I_{j}/2')
                        
                        
                        mode_str += '\\begin{math}\n    \\begin{aligned}\n        & '
                        # Check length?
                        mode_str += incline_str
                        mode_str += ' \n    \\end{aligned}\n    \end{math} & \n'
                        this_incline_grabbed = True
                    else:
                        mode_str += '--- & \n'
                    
                    # Finally the eccentricity functions
                    mode_str += '    '
                    eccen_str = latex(gfunc)
                    eccen_str = eccen_str.replace('e^{}', 'e')
                    
                    # Check if the eccentricity function needs to be split onto multiple lines.
                    eccen_lines = 1
                    if len(eccen_str) > max_eq_length:
                        
                        term_list = list()
                        # First split along positives
                        for term in eccen_str.split(' + '):
                            if ' - ' in term:
                                # And then along negatives
                                for t_i, neg_term in enumerate(term.split(' - ')):
                                    if t_i == 0:
                                        # First term is the positive term
                                        term_list.append((neg_term, True))
                                    else:
                                        term_list.append((neg_term, False))
                            else:
                                term_list.append((term, True))
                        
                        # Make new string
                        new_eccen_str = ''
                        running_num = 0
                        for t_i, (term, leading_pos) in enumerate(term_list):
                            if t_i > 0:
                                if leading_pos:
                                    term = ' + ' + term.strip()
                                else:
                                    term = ' - ' + term.strip()
                            else:
                                term = term.strip()
                                    
                            running_num += len(term)
                            if running_num > max_eq_length:
                                new_eccen_str += ' \\\\ \n        &' + term
                                running_num = len(term)
                                eccen_lines += 1
                            else:
                                new_eccen_str += term
                                
                        eccen_str = new_eccen_str
                    
                    # The minipage enviornment allows there to be padding above and below the multi line equations (only thing I could get to work)
                    #    The 80mm probably needs to be adjusted if you give the equations more/less horizontal room.
                    mode_str += '\\begin{minipage}{80mm}\n    \\vspace{2mm}    \\begin{math}\n    \\begin{aligned}\n        & '
                    # Check length?
                    mode_str += eccen_str
                    mode_str += ' \n    \\end{aligned}\n    \\end{math}\n    \\vspace{2mm}\n    \\end{minipage} \\\\ \\hline\n'
                    
    # Save as text file
    with open(f'NSR Dissipation - Latex Output - emax_{max_e_power}_minl_{min_l}.txt', 'w') as latex_file:
        output_str = table_preamble + mode_str + table_postamble
        latex_file.write(output_str)

    print('Done!')
    print('# Unique Modes:', len(unique_modes))
    print('# Unique Frequencies:', len(unique_freqs))

# %%
print('Type "c" and press enter to continue the calculations')
breakpoint()
# Out:
# Type "c" and press enter to continue the calculations
# --Call--
# > c:\users\joepr\.conda\envs\dev\lib\site-packages\ipython\core\displayhook.py(252)__call__()
#     250         sys.stdout.flush()
#     251
# --> 252     def __call__(self, result=None):
#     253         """Printing with history cache management.
#     254
#
# ipdb> q
# ---------------------------------------------------------------------------
# BdbQuit                                   Traceback (most recent call last)
# <ipython-input-14-4a63d4063813> in <module>
#       1 print('Type "c" and press enter to continue the calculations')
# ----> 2 breakpoint()
#
# ~\.conda\envs\dev\lib\site-packages\IPython\core\displayhook.py in __call__(self, result)
#     250         sys.stdout.flush()
#     251
# --> 252     def __call__(self, result=None):
#     253         """Printing with history cache management.
#     254
#
# ~\.conda\envs\dev\lib\bdb.py in trace_dispatch(self, frame, event, arg)
#      88             return self.dispatch_line(frame)
#      89         if event == 'call':
# ---> 90             return self.dispatch_call(frame, arg)
#      91         if event == 'return':
#      92             return self.dispatch_return(frame, arg)
#
# ~\.conda\envs\dev\lib\bdb.py in dispatch_call(self, frame, arg)
#     133             return self.trace_dispatch
#     134         self.user_call(frame, arg)
# --> 135         if self.quitting: raise BdbQuit
#     136         return self.trace_dispatch
#     137
#
# BdbQuit:

# %% [markdown]
# ### Compile Derivatives

# %%
beta = (mass_host * mass_sat) / (mass_host + mass_sat)

# Host
torque_H = 0.
heating_H = 0.
dUdM_H = 0.
dUdw_H = 0.
dUdO_H = 0.
for mode, love_coeff in love_coeffs_host.items():
    ei_coeff = eccen_inclin_coeffs_host[mode]
    uni_coeff = universal_coeffs[mode]
    phys_coeff = physical_coeffs_host[mode]
    dUdM_coeff = dUdM_coeffs[mode]
    dUdw_coeff = dUdw_coeffs[mode]
    dUdO_coeff = dUdO_coeffs[mode]
    freq = freq_table_host[mode]
    sgn_H = sign_table_host[mode]
    love_H = love_table_host[mode]
    
    heating_H += expand(Rational(3, 2) * ei_coeff * uni_coeff * phys_coeff * freq * love_H * mass_sat)
    torque_H += expand(Rational(3, 2) * dUdO_coeff * ei_coeff * uni_coeff * phys_coeff * love_coeff * mass_sat)
    dUdM_H += expand(Rational(3, 2) * dUdM_coeff * ei_coeff * uni_coeff * phys_coeff * love_coeff)
    dUdw_H += expand(Rational(3, 2) * dUdw_coeff * ei_coeff * uni_coeff * phys_coeff * love_coeff)
    dUdO_H += expand(Rational(3, 2) * dUdO_coeff * ei_coeff * uni_coeff * phys_coeff * love_coeff)
    
    
# Satellite
heating_S_LIB = 0
heating_S = 0
torque_S = 0
dUdM_S = 0
dUdw_S = 0
dUdO_S = 0
potential = 0
heating_S_simp = 0
torque_S_simp = 0
dUdM_S_simp = 0
dUdw_S_simp = 0
dUdO_S_simp = 0
for mode, love_coeff in love_coeffs_sat.items():
    ei_coeff = eccen_inclin_coeffs_sat[mode]
    uni_coeff = universal_coeffs[mode]
    phys_coeff = physical_coeffs_sat[mode]
    dUdM_coeff = dUdM_coeffs[mode]
    dUdw_coeff = dUdw_coeffs[mode]
    dUdO_coeff = dUdO_coeffs[mode]
    fullpot_coeff = full_potential_coeffs[mode]
    freq = freq_table_sat[mode]
    sgn_S = sign_table_sat[mode]
    love_S = love_table_sat[mode]
    
    heating_S += expand(Rational(3, 2) * ei_coeff * uni_coeff * phys_coeff * freq * love_S * mass_host)
    torque_S += expand(Rational(3, 2) * dUdO_coeff * ei_coeff * uni_coeff * phys_coeff * love_coeff * mass_host)
    dUdM_S += expand(Rational(3, 2) * dUdM_coeff * ei_coeff * uni_coeff * phys_coeff * love_coeff)
    dUdw_S += expand(Rational(3, 2) * dUdw_coeff * ei_coeff * uni_coeff * phys_coeff * love_coeff)
    potential += expand(potential_coeffs[mode])
    
    heating_S_simp += expand(ei_coeff * uni_coeff * freq * love_S)
    torque_S_simp += expand(dUdO_coeff * ei_coeff * uni_coeff * love_coeff)
    dUdM_S_simp += expand(dUdM_coeff * ei_coeff * uni_coeff * love_coeff)
    dUdw_S_simp += expand(dUdw_coeff * ei_coeff * uni_coeff * love_coeff)
    dUdO_S_simp += expand(dUdO_coeff * ei_coeff * uni_coeff * love_coeff)
    
    
for mode, love_coeff in love_coeffs_sat_LIB.items():
        
    e_f_coeff = eccen_inclin_coeffs_sat_LIB[mode]
    uni_coeff = universal_coeffs_LIB[mode]
    lib_coeff = LIB_COEFF[mode]

    heating_S_LIB += expand(e_f_coeff * uni_coeff * lib_coeff * love_coeff)
    
# Check if the user wanted the objects to both be forced into spin-sync from the get go.
if not use_nsr:
    heating_H = sync_spin(heating_H, host=True, sat=False, max_q=max_q)
    torque_H = sync_spin(torque_H, host=True, sat=False, max_q=max_q)
    dUdM_H = sync_spin(dUdM_H, host=True, sat=False, max_q=max_q)
    dUdw_H = sync_spin(dUdw_H, host=True, sat=False, max_q=max_q)
    dUdO_H = sync_spin(dUdO_H, host=True, sat=False, max_q=max_q)
    
    heating_S = sync_spin(heating_S, host=False, sat=True, max_q=max_q)
    torque_S = sync_spin(torque_S, host=False, sat=True, max_q=max_q)
    dUdM_S = sync_spin(dUdM_S, host=False, sat=True, max_q=max_q)
    dUdw_S = sync_spin(dUdw_S, host=False, sat=True, max_q=max_q)
    dUdO_S = sync_spin(dUdO_S, host=False, sat=True, max_q=max_q)

# %%
tidal_susceptibility = Rational(3, 2) * newton_G * mass_host**2 * radius_sat**5 / semi_major_axis**6
tidal_susceptibility_reduced = Rational(3, 2) * newton_G * mass_host * radius_sat**2 / semi_major_axis**3
radius_factor = (r_sat / radius_sat)**2

# %% [markdown]
# ## Libration Heating

# %%
lib_heating_11 = heating_S_LIB
lib_heating_11 = lib_heating_11.subs(spin_frac, 1)
lib_heating_11 = lib_heating_11.subs(love_func_sat(0), 0)
lib_heating_11 = taylor(lib_heating_11, eccentricity, 4).removeO()
lib_heating_11 = taylor(lib_heating_11, lib_A, 5).removeO()
lib_heating_11 = taylor(lib_heating_11, obliquity_sat, 5).removeO()
lib_A11 = Symbol('\mathcal{A}_{1, 1:1}', real=True, positive=True)
lib_heating_11 = lib_heating_11.subs(lib_A, lib_A11)
lib_heating_11 = expand(lib_heating_11)

# %%
disp(lib_heating_11)
# Out:
#           4                     4  2                        4
# 6743⋅I_S__ ⋅\mathcal{A}_{1, 1:1} ⋅e ⋅Ξ_S2__(n)   15911⋅I_S__ ⋅\mathcal{A}_{1,
# ────────────────────────────────────────────── - ─────────────────────────────
#                      768                                                3072
#
#     4  2                        4                     4  2
# 1:1} ⋅e ⋅Ξ_S2__(2⋅n)   527⋅I_S__ ⋅\mathcal{A}_{1, 1:1} ⋅e ⋅Ξ_S2__(3⋅n)   2783⋅
# ──────────────────── + ─────────────────────────────────────────────── - ─────
#                                              192
#
#      4                     4  2                       4                     4
# I_S__ ⋅\mathcal{A}_{1, 1:1} ⋅e ⋅Ξ_S2__(4⋅n)   63⋅I_S__ ⋅\mathcal{A}_{1, 1:1} ⋅
# ─────────────────────────────────────────── + ────────────────────────────────
#                  6144                                              256
#
#  2                       4                     4                     4
# e ⋅Ξ_S2__(5⋅n)   65⋅I_S__ ⋅\mathcal{A}_{1, 1:1} ⋅Ξ_S2__(n)   23⋅I_S__ ⋅\mathca
# ────────────── - ───────────────────────────────────────── + ─────────────────
#                                     512
#
#              4                       4                     4
# l{A}_{1, 1:1} ⋅Ξ_S2__(2⋅n)   13⋅I_S__ ⋅\mathcal{A}_{1, 1:1} ⋅Ξ_S2__(3⋅n)   3⋅I
# ────────────────────────── - ─────────────────────────────────────────── + ───
#     64                                           512
#
#     4                     4                           4                     3
# _S__ ⋅\mathcal{A}_{1, 1:1} ⋅Ξ_S2__(4⋅n)   144959⋅I_S__ ⋅\mathcal{A}_{1, 1:1} ⋅
# ─────────────────────────────────────── - ────────────────────────────────────
#                  64                                             3072
#
#  3                         4                     3  3
# e ⋅Ξ_S2__(n)   107657⋅I_S__ ⋅\mathcal{A}_{1, 1:1} ⋅e ⋅Ξ_S2__(2⋅n)   49009⋅I_S_
# ──────────── + ────────────────────────────────────────────────── - ──────────
#                                       3072
#
#  4                     3  3                        4                     3  3
# _ ⋅\mathcal{A}_{1, 1:1} ⋅e ⋅Ξ_S2__(3⋅n)   203⋅I_S__ ⋅\mathcal{A}_{1, 1:1} ⋅e ⋅
# ─────────────────────────────────────── + ────────────────────────────────────
#              3072                                               128
#
#                       4                     3  3                        4
# Ξ_S2__(4⋅n)   81⋅I_S__ ⋅\mathcal{A}_{1, 1:1} ⋅e ⋅Ξ_S2__(5⋅n)   673⋅I_S__ ⋅\mat
# ─────────── + ────────────────────────────────────────────── + ───────────────
#                                    128
#
#                 3                        4                     3
# hcal{A}_{1, 1:1} ⋅e⋅Ξ_S2__(n)   227⋅I_S__ ⋅\mathcal{A}_{1, 1:1} ⋅e⋅Ξ_S2__(2⋅n)
# ───────────────────────────── - ──────────────────────────────────────────────
#      128                                             128
#
#            4                     3                        4
#    25⋅I_S__ ⋅\mathcal{A}_{1, 1:1} ⋅e⋅Ξ_S2__(3⋅n)   9⋅I_S__ ⋅\mathcal{A}_{1, 1:
#  - ───────────────────────────────────────────── + ───────────────────────────
#                         128                                             32
#
#   3                           4                     2  2
# 1} ⋅e⋅Ξ_S2__(4⋅n)   3323⋅I_S__ ⋅\mathcal{A}_{1, 1:1} ⋅e ⋅Ξ_S2__(n)   1973⋅I_S_
# ───────────────── - ────────────────────────────────────────────── + ─────────
#                                          128
#
#  4                     2  2                        4                     2  2
# _ ⋅\mathcal{A}_{1, 1:1} ⋅e ⋅Ξ_S2__(2⋅n)   649⋅I_S__ ⋅\mathcal{A}_{1, 1:1} ⋅e ⋅
# ─────────────────────────────────────── - ────────────────────────────────────
#              128                                                128
#
#                       4                     2  2                       4
# Ξ_S2__(3⋅n)   27⋅I_S__ ⋅\mathcal{A}_{1, 1:1} ⋅e ⋅Ξ_S2__(4⋅n)   27⋅I_S__ ⋅\math
# ─────────── + ────────────────────────────────────────────── + ───────────────
#                                     32
#
#                2                     4                     2
# cal{A}_{1, 1:1} ⋅Ξ_S2__(n)   25⋅I_S__ ⋅\mathcal{A}_{1, 1:1} ⋅Ξ_S2__(2⋅n)   3⋅I
# ────────────────────────── - ─────────────────────────────────────────── + ───
#      16                                           32
#
#     4                     2                         4                       3
# _S__ ⋅\mathcal{A}_{1, 1:1} ⋅Ξ_S2__(3⋅n)   6005⋅I_S__ ⋅\mathcal{A}_{1, 1:1}⋅e ⋅
# ─────────────────────────────────────── + ────────────────────────────────────
#                  16                                            128
#
#                       4                       3                         4
# Ξ_S2__(n)   6385⋅I_S__ ⋅\mathcal{A}_{1, 1:1}⋅e ⋅Ξ_S2__(2⋅n)   1975⋅I_S__ ⋅\mat
# ───────── - ─────────────────────────────────────────────── + ────────────────
#                                   128
#
#                   3                       4                       3
# hcal{A}_{1, 1:1}⋅e ⋅Ξ_S2__(3⋅n)   81⋅I_S__ ⋅\mathcal{A}_{1, 1:1}⋅e ⋅Ξ_S2__(4⋅n
# ─────────────────────────────── + ────────────────────────────────────────────
#       128                                               64
#
#             4                                            4
# )   93⋅I_S__ ⋅\mathcal{A}_{1, 1:1}⋅e⋅Ξ_S2__(n)   11⋅I_S__ ⋅\mathcal{A}_{1, 1:1
# ─ - ────────────────────────────────────────── + ─────────────────────────────
#                         16                                            16
#
#                          4                                                4  2
# }⋅e⋅Ξ_S2__(2⋅n)   9⋅I_S__ ⋅\mathcal{A}_{1, 1:1}⋅e⋅Ξ_S2__(3⋅n)   1097⋅I_S__ ⋅e
# ─────────────── + ─────────────────────────────────────────── + ──────────────
#                                        16                                 128
#
#                      4  2                        4  2                       4
# ⋅Ξ_S2__(n)   43⋅I_S__ ⋅e ⋅Ξ_S2__(2⋅n)   495⋅I_S__ ⋅e ⋅Ξ_S2__(3⋅n)   13⋅I_S__ ⋅
# ────────── - ──────────────────────── + ───────────────────────── - ──────────
#                         4                          128                       8
#
#                     4                         2                     4  2
# Ξ_S2__(n)   15⋅I_S__ ⋅Ξ_S2__(2⋅n)   4427⋅I_S__ ⋅\mathcal{A}_{1, 1:1} ⋅e ⋅Ξ_S2_
# ───────── + ───────────────────── - ──────────────────────────────────────────
#                       32                                 256
#
#                  2                     4  2                         2
# _(n)   2537⋅I_S__ ⋅\mathcal{A}_{1, 1:1} ⋅e ⋅Ξ_S2__(2⋅n)   1277⋅I_S__ ⋅\mathcal
# ──── + ──────────────────────────────────────────────── - ────────────────────
#                              256
#
#             4  2                        2                     4  2
# {A}_{1, 1:1} ⋅e ⋅Ξ_S2__(3⋅n)   173⋅I_S__ ⋅\mathcal{A}_{1, 1:1} ⋅e ⋅Ξ_S2__(4⋅n)
# ──────────────────────────── + ───────────────────────────────────────────────
#   256                                                512
#
#            2                     4                    2                     4
#    15⋅I_S__ ⋅\mathcal{A}_{1, 1:1} ⋅Ξ_S2__(n)   3⋅I_S__ ⋅\mathcal{A}_{1, 1:1} ⋅
#  + ───────────────────────────────────────── - ───────────────────────────────
#                       128                                          8
#
#                      2                     4                         2
# Ξ_S2__(2⋅n)   3⋅I_S__ ⋅\mathcal{A}_{1, 1:1} ⋅Ξ_S2__(3⋅n)   6119⋅I_S__ ⋅\mathca
# ─────────── + ────────────────────────────────────────── + ───────────────────
#                                  128
#
#              3  3                       2                     3  3
# l{A}_{1, 1:1} ⋅e ⋅Ξ_S2__(n)   8761⋅I_S__ ⋅\mathcal{A}_{1, 1:1} ⋅e ⋅Ξ_S2__(2⋅n)
# ─────────────────────────── - ────────────────────────────────────────────────
#    64                                               128
#
#             2                     3  3                        2
#    941⋅I_S__ ⋅\mathcal{A}_{1, 1:1} ⋅e ⋅Ξ_S2__(3⋅n)   633⋅I_S__ ⋅\mathcal{A}_{1
#  + ─────────────────────────────────────────────── - ─────────────────────────
#                           32                                               256
#
#       3  3                        2                     3
# , 1:1} ⋅e ⋅Ξ_S2__(4⋅n)   159⋅I_S__ ⋅\mathcal{A}_{1, 1:1} ⋅e⋅Ξ_S2__(n)   57⋅I_S
# ────────────────────── - ──────────────────────────────────────────── + ──────
#                                               16
#
#   2                     3                        2                     3
# __ ⋅\mathcal{A}_{1, 1:1} ⋅e⋅Ξ_S2__(2⋅n)   3⋅I_S__ ⋅\mathcal{A}_{1, 1:1} ⋅e⋅Ξ_S
# ─────────────────────────────────────── - ────────────────────────────────────
#                 16                                             16
#
#                      2                     2  2                     2
# 2__(3⋅n)   3117⋅I_S__ ⋅\mathcal{A}_{1, 1:1} ⋅e ⋅Ξ_S2__(n)   51⋅I_S__ ⋅\mathcal
# ──────── + ────────────────────────────────────────────── - ──────────────────
#                                  64
#
#             2  2                        2                     2  2
# {A}_{1, 1:1} ⋅e ⋅Ξ_S2__(2⋅n)   303⋅I_S__ ⋅\mathcal{A}_{1, 1:1} ⋅e ⋅Ξ_S2__(3⋅n)
# ──────────────────────────── + ───────────────────────────────────────────────
#     2                                                 64
#
#           2                     2                    2                     2
#    9⋅I_S__ ⋅\mathcal{A}_{1, 1:1} ⋅Ξ_S2__(n)   3⋅I_S__ ⋅\mathcal{A}_{1, 1:1} ⋅Ξ
#  - ──────────────────────────────────────── + ────────────────────────────────
#                       4                                           8
#
#                        2                       3                       2
# _S2__(2⋅n)   2787⋅I_S__ ⋅\mathcal{A}_{1, 1:1}⋅e ⋅Ξ_S2__(n)   1275⋅I_S__ ⋅\math
# ────────── - ───────────────────────────────────────────── + ─────────────────
#                                    32
#
#                  3                        2                       3
# cal{A}_{1, 1:1}⋅e ⋅Ξ_S2__(2⋅n)   633⋅I_S__ ⋅\mathcal{A}_{1, 1:1}⋅e ⋅Ξ_S2__(3⋅n
# ────────────────────────────── - ─────────────────────────────────────────────
#       16                                               32
#
#                                                        2
# )          2                                    3⋅I_S__ ⋅\mathcal{A}_{1, 1:1}⋅
# ─ + 9⋅I_S__ ⋅\mathcal{A}_{1, 1:1}⋅e⋅Ξ_S2__(n) - ──────────────────────────────
#                                                                      2
#
#                         2  2                     2  2                      2
# e⋅Ξ_S2__(2⋅n)   57⋅I_S__ ⋅e ⋅Ξ_S2__(n)   87⋅I_S__ ⋅e ⋅Ξ_S2__(2⋅n)   3⋅I_S__ ⋅Ξ
# ───────────── - ────────────────────── + ──────────────────────── + ──────────
#                           4                         8                       2
#
#                                    4  2                                    4
# _S2__(n)   527⋅\mathcal{A}_{1, 1:1} ⋅e ⋅Ξ_S2__(n)   73⋅\mathcal{A}_{1, 1:1} ⋅e
# ──────── + ────────────────────────────────────── - ──────────────────────────
#                              32                                        8
#
# 2                                       4  2
#  ⋅Ξ_S2__(2⋅n)   143⋅\mathcal{A}_{1, 1:1} ⋅e ⋅Ξ_S2__(3⋅n)   3⋅\mathcal{A}_{1, 1
# ───────────── + ──────────────────────────────────────── + ───────────────────
#                                    32                                       8
#
#    4                                        3  3
# :1} ⋅Ξ_S2__(2⋅n)   1421⋅\mathcal{A}_{1, 1:1} ⋅e ⋅Ξ_S2__(n)
# ──────────────── - ─────────────────────────────────────── + 59⋅\mathcal{A}_{1
#                                       16
#
#                                                  3  3
#       3  3               357⋅\mathcal{A}_{1, 1:1} ⋅e ⋅Ξ_S2__(3⋅n)
# , 1:1} ⋅e ⋅Ξ_S2__(2⋅n) - ──────────────────────────────────────── + 9⋅\mathcal
#                                             16
#
#
#             3                                     3                 333⋅\mathc
# {A}_{1, 1:1} ⋅e⋅Ξ_S2__(n) - 3⋅\mathcal{A}_{1, 1:1} ⋅e⋅Ξ_S2__(2⋅n) - ──────────
#
#
#               2  2                                    2  2
# al{A}_{1, 1:1} ⋅e ⋅Ξ_S2__(n)   63⋅\mathcal{A}_{1, 1:1} ⋅e ⋅Ξ_S2__(2⋅n)   3⋅\ma
# ──────────────────────────── + ─────────────────────────────────────── + ─────
#         8                                         4
#
#                  2                                       3
# thcal{A}_{1, 1:1} ⋅Ξ_S2__(n)   285⋅\mathcal{A}_{1, 1:1}⋅e ⋅Ξ_S2__(n)   357⋅\ma
# ──────────────────────────── + ───────────────────────────────────── - ───────
#            2                                     4
#
#                    3                                                        2
# thcal{A}_{1, 1:1}⋅e ⋅Ξ_S2__(2⋅n)                                        21⋅e ⋅
# ──────────────────────────────── - 6⋅\mathcal{A}_{1, 1:1}⋅e⋅Ξ_S2__(n) + ──────
#             8
#
#
# Ξ_S2__(n)
# ─────────
#  2

# %%
lib_heating_32 = heating_S_LIB
lib_heating_32 = lib_heating_32.subs(spin_frac, Rational(3, 2))
lib_heating_32 = lib_heating_32.subs(love_func_sat(0), 0)
lib_heating_32 = taylor(lib_heating_32, eccentricity, 4).removeO()
lib_heating_32 = taylor(lib_heating_32, lib_A, 5).removeO()
lib_heating_32 = taylor(lib_heating_32, obliquity_sat, 5).removeO()
lib_A32 = Symbol('\mathcal{A}_{1, 3:2}', real=True, positive=True)
lib_heating_32 = lib_heating_32.subs(lib_A, lib_A32)
lib_heating_32 = expand(lib_heating_32)

# %%
disp(lib_heating_32)
# Out:
#           4                     4  2       ⎛n⎞
# 1129⋅I_S__ ⋅\mathcal{A}_{1, 3:2} ⋅e ⋅Ξ_S2__⎜─⎟           4
#                                            ⎝2⎠   25⋅I_S__ ⋅\mathcal{A}_{1, 3:2
# ────────────────────────────────────────────── - ─────────────────────────────
#                      6144                                             3
#
#                             4                     4  2       ⎛3⋅n⎞
#  4  2             2863⋅I_S__ ⋅\mathcal{A}_{1, 3:2} ⋅e ⋅Ξ_S2__⎜───⎟
# } ⋅e ⋅Ξ_S2__(n)                                              ⎝ 2 ⎠   1915⋅I_S_
# ─────────────── - ──────────────────────────────────────────────── + ─────────
#                                         6144
#
#                                                     4                     4  2
#  4                     4  2               1961⋅I_S__ ⋅\mathcal{A}_{1, 3:2} ⋅e
# _ ⋅\mathcal{A}_{1, 3:2} ⋅e ⋅Ξ_S2__(2⋅n)
# ─────────────────────────────────────── + ────────────────────────────────────
#              384                                                6144
#
#        ⎛5⋅n⎞                                                               4
# ⋅Ξ_S2__⎜───⎟            4                     4  2               1127⋅I_S__ ⋅\
#        ⎝ 2 ⎠   175⋅I_S__ ⋅\mathcal{A}_{1, 3:2} ⋅e ⋅Ξ_S2__(3⋅n)
# ──────────── - ─────────────────────────────────────────────── - ─────────────
#                                      192
#
#                    4  2       ⎛7⋅n⎞
# mathcal{A}_{1, 3:2} ⋅e ⋅Ξ_S2__⎜───⎟            4                     4  2
#                               ⎝ 2 ⎠   137⋅I_S__ ⋅\mathcal{A}_{1, 3:2} ⋅e ⋅Ξ_S2
# ─────────────────────────────────── + ────────────────────────────────────────
#          6144                                               512
#
#                   4                     4  2       ⎛9⋅n⎞
#           21⋅I_S__ ⋅\mathcal{A}_{1, 3:2} ⋅e ⋅Ξ_S2__⎜───⎟          4
# __(4⋅n)                                            ⎝ 2 ⎠   9⋅I_S__ ⋅\mathcal{A
# ─────── - ────────────────────────────────────────────── - ───────────────────
#                                256
#
#
#           4  2                       4                     4  2
# }_{1, 3:2} ⋅e ⋅Ξ_S2__(5⋅n)   63⋅I_S__ ⋅\mathcal{A}_{1, 3:2} ⋅e ⋅Ξ_S2__(6⋅n)
# ────────────────────────── + ────────────────────────────────────────────── -
#    64                                             256
#
#        4                     4       ⎛n⎞
# 7⋅I_S__ ⋅\mathcal{A}_{1, 3:2} ⋅Ξ_S2__⎜─⎟           4                     4
#                                      ⎝2⎠   61⋅I_S__ ⋅\mathcal{A}_{1, 3:2} ⋅Ξ_S
# ──────────────────────────────────────── + ───────────────────────────────────
#                   128                                         128
#
#                  4                     4       ⎛3⋅n⎞          4
#          37⋅I_S__ ⋅\mathcal{A}_{1, 3:2} ⋅Ξ_S2__⎜───⎟   5⋅I_S__ ⋅\mathcal{A}_{1
# 2__(n)                                         ⎝ 2 ⎠
# ────── - ─────────────────────────────────────────── - ───────────────────────
#                              512                                          512
#
#       4       ⎛5⋅n⎞                                                      4
# , 3:2} ⋅Ξ_S2__⎜───⎟           4                     4               I_S__ ⋅\ma
#               ⎝ 2 ⎠   35⋅I_S__ ⋅\mathcal{A}_{1, 3:2} ⋅Ξ_S2__(3⋅n)
# ─────────────────── + ─────────────────────────────────────────── - ──────────
#                                           128
#
#                  4       ⎛7⋅n⎞
# thcal{A}_{1, 3:2} ⋅Ξ_S2__⎜───⎟          4                     4
#                          ⎝ 2 ⎠   3⋅I_S__ ⋅\mathcal{A}_{1, 3:2} ⋅Ξ_S2__(5⋅n)
# ────────────────────────────── + ────────────────────────────────────────── -
#          64                                          64
#
#            4                     3  3       ⎛n⎞
# 12197⋅I_S__ ⋅\mathcal{A}_{1, 3:2} ⋅e ⋅Ξ_S2__⎜─⎟              4
#                                             ⎝2⎠   78025⋅I_S__ ⋅\mathcal{A}_{1,
# ─────────────────────────────────────────────── + ────────────────────────────
#                       3072                                              1536
#
#                                 4                     3  3       ⎛3⋅n⎞
#      3  3             4081⋅I_S__ ⋅\mathcal{A}_{1, 3:2} ⋅e ⋅Ξ_S2__⎜───⎟
#  3:2} ⋅e ⋅Ξ_S2__(n)                                              ⎝ 2 ⎠   26683
# ─────────────────── + ──────────────────────────────────────────────── - ─────
#                                             512
#
#                                                           4
#       4                     3  3               18781⋅I_S__ ⋅\mathcal{A}_{1, 3:
# ⋅I_S__ ⋅\mathcal{A}_{1, 3:2} ⋅e ⋅Ξ_S2__(2⋅n)
# ──────────────────────────────────────────── - ───────────────────────────────
#                   1536                                                3072
#
#   3  3       ⎛5⋅n⎞
# 2} ⋅e ⋅Ξ_S2__⎜───⎟            4                     3  3               649⋅I_S
#              ⎝ 2 ⎠   231⋅I_S__ ⋅\mathcal{A}_{1, 3:2} ⋅e ⋅Ξ_S2__(3⋅n)
# ────────────────── + ─────────────────────────────────────────────── + ───────
#                                            512
#
#   4                     3  3       ⎛7⋅n⎞
# __ ⋅\mathcal{A}_{1, 3:2} ⋅e ⋅Ξ_S2__⎜───⎟           4                     3  3
#                                    ⎝ 2 ⎠   27⋅I_S__ ⋅\mathcal{A}_{1, 3:2} ⋅e ⋅
# ──────────────────────────────────────── + ───────────────────────────────────
#                256                                              256
#
#                       4                     3  3       ⎛9⋅n⎞
#               27⋅I_S__ ⋅\mathcal{A}_{1, 3:2} ⋅e ⋅Ξ_S2__⎜───⎟           4
# Ξ_S2__(4⋅n)                                            ⎝ 2 ⎠   81⋅I_S__ ⋅\math
# ─────────── - ────────────────────────────────────────────── - ───────────────
#                                     64
#
#
#                3  3                       4                     3  3
# cal{A}_{1, 3:2} ⋅e ⋅Ξ_S2__(5⋅n)   81⋅I_S__ ⋅\mathcal{A}_{1, 3:2} ⋅e ⋅Ξ_S2__(6⋅
# ─────────────────────────────── + ────────────────────────────────────────────
#       256                                              128
#
#              4                     3         ⎛n⎞
#      35⋅I_S__ ⋅\mathcal{A}_{1, 3:2} ⋅e⋅Ξ_S2__⎜─⎟            4
# n)                                           ⎝2⎠   271⋅I_S__ ⋅\mathcal{A}_{1,
# ── + ─────────────────────────────────────────── - ───────────────────────────
#                          128                                            64
#
#                             4                     3         ⎛3⋅n⎞
#     3               35⋅I_S__ ⋅\mathcal{A}_{1, 3:2} ⋅e⋅Ξ_S2__⎜───⎟            4
# 3:2} ⋅e⋅Ξ_S2__(n)                                           ⎝ 2 ⎠   117⋅I_S__
# ───────────────── - ───────────────────────────────────────────── + ──────────
#                                           64
#
#                                                4                     3
#                      3                 59⋅I_S__ ⋅\mathcal{A}_{1, 3:2} ⋅e⋅Ξ_S2_
# ⋅\mathcal{A}_{1, 3:2} ⋅e⋅Ξ_S2__(2⋅n)
# ──────────────────────────────────── + ───────────────────────────────────────
#             64                                              128
#
#  ⎛5⋅n⎞                                                          4
# _⎜───⎟           4                     3                 3⋅I_S__ ⋅\mathcal{A}_
#  ⎝ 2 ⎠   11⋅I_S__ ⋅\mathcal{A}_{1, 3:2} ⋅e⋅Ξ_S2__(3⋅n)
# ────── - ───────────────────────────────────────────── - ─────────────────────
#                                64
#
#         3         ⎛7⋅n⎞
# {1, 3:2} ⋅e⋅Ξ_S2__⎜───⎟          4                     3
#                   ⎝ 2 ⎠   9⋅I_S__ ⋅\mathcal{A}_{1, 3:2} ⋅e⋅Ξ_S2__(4⋅n)   9⋅I_S
# ─────────────────────── - ──────────────────────────────────────────── + ─────
# 16                                             32
#
#                                                    4                     2  2
#   4                     3                 569⋅I_S__ ⋅\mathcal{A}_{1, 3:2} ⋅e ⋅
# __ ⋅\mathcal{A}_{1, 3:2} ⋅e⋅Ξ_S2__(5⋅n)
# ─────────────────────────────────────── - ────────────────────────────────────
#                 32                                             128
#
#       ⎛n⎞                                                            4
# Ξ_S2__⎜─⎟             4                     2  2             63⋅I_S__ ⋅\mathca
#       ⎝2⎠   2539⋅I_S__ ⋅\mathcal{A}_{1, 3:2} ⋅e ⋅Ξ_S2__(n)
# ───────── + ────────────────────────────────────────────── + ─────────────────
#                                  128
#
#              2  2       ⎛3⋅n⎞
# l{A}_{1, 3:2} ⋅e ⋅Ξ_S2__⎜───⎟            4                     2  2
#                         ⎝ 2 ⎠   409⋅I_S__ ⋅\mathcal{A}_{1, 3:2} ⋅e ⋅Ξ_S2__(2⋅n
# ───────────────────────────── - ──────────────────────────────────────────────
#      8                                                128
#
#              4                     2  2       ⎛5⋅n⎞
#     295⋅I_S__ ⋅\mathcal{A}_{1, 3:2} ⋅e ⋅Ξ_S2__⎜───⎟           4
# )                                             ⎝ 2 ⎠   25⋅I_S__ ⋅\mathcal{A}_{1
# ─ - ─────────────────────────────────────────────── - ────────────────────────
#                           128                                              128
#
#                                 4                     2  2       ⎛7⋅n⎞
#       2  2               9⋅I_S__ ⋅\mathcal{A}_{1, 3:2} ⋅e ⋅Ξ_S2__⎜───⎟
# , 3:2} ⋅e ⋅Ξ_S2__(3⋅n)                                           ⎝ 2 ⎠   45⋅I_
# ────────────────────── - ───────────────────────────────────────────── - ─────
#                                                8
#
#
#    4                     2  2                       4                     2  2
# S__ ⋅\mathcal{A}_{1, 3:2} ⋅e ⋅Ξ_S2__(4⋅n)   27⋅I_S__ ⋅\mathcal{A}_{1, 3:2} ⋅e
# ───────────────────────────────────────── + ──────────────────────────────────
#                  64                                               32
#
#                       4                     2       ⎛n⎞
#                3⋅I_S__ ⋅\mathcal{A}_{1, 3:2} ⋅Ξ_S2__⎜─⎟           4
# ⋅Ξ_S2__(5⋅n)                                        ⎝2⎠   11⋅I_S__ ⋅\mathcal{A
# ──────────── - ──────────────────────────────────────── - ────────────────────
#                                   32
#
#                                 4                     2       ⎛3⋅n⎞
#           2             11⋅I_S__ ⋅\mathcal{A}_{1, 3:2} ⋅Ξ_S2__⎜───⎟
# }_{1, 3:2} ⋅Ξ_S2__(n)                                         ⎝ 2 ⎠   17⋅I_S__
# ───────────────────── + ─────────────────────────────────────────── + ────────
# 16                                           32
#
#                                            4                     2       ⎛5⋅n⎞
# 4                     2               I_S__ ⋅\mathcal{A}_{1, 3:2} ⋅Ξ_S2__⎜───⎟
#  ⋅\mathcal{A}_{1, 3:2} ⋅Ξ_S2__(2⋅n)                                      ⎝ 2 ⎠
# ─────────────────────────────────── - ────────────────────────────────────────
#              32                                          4
#
#
#           4                     2                      4                     2
#    3⋅I_S__ ⋅\mathcal{A}_{1, 3:2} ⋅Ξ_S2__(3⋅n)   3⋅I_S__ ⋅\mathcal{A}_{1, 3:2}
#  - ────────────────────────────────────────── + ──────────────────────────────
#                        8                                            16
#
#                          4                       3       ⎛n⎞
#                1819⋅I_S__ ⋅\mathcal{A}_{1, 3:2}⋅e ⋅Ξ_S2__⎜─⎟             4
# ⋅Ξ_S2__(4⋅n)                                             ⎝2⎠   2171⋅I_S__ ⋅\ma
# ──────────── + ───────────────────────────────────────────── - ───────────────
#                                     128
#
#                                            4                       3       ⎛3⋅
#                    3             3695⋅I_S__ ⋅\mathcal{A}_{1, 3:2}⋅e ⋅Ξ_S2__⎜──
# thcal{A}_{1, 3:2}⋅e ⋅Ξ_S2__(n)                                             ⎝ 2
# ────────────────────────────── - ─────────────────────────────────────────────
#        64                                              128
#
# n⎞                                                             4
# ─⎟            4                       3               577⋅I_S__ ⋅\mathcal{A}_{
#  ⎠   177⋅I_S__ ⋅\mathcal{A}_{1, 3:2}⋅e ⋅Ξ_S2__(2⋅n)
# ── + ────────────────────────────────────────────── + ────────────────────────
#                           256                                               32
#
#          3       ⎛5⋅n⎞           4                       3       ⎛7⋅n⎞
# 1, 3:2}⋅e ⋅Ξ_S2__⎜───⎟   27⋅I_S__ ⋅\mathcal{A}_{1, 3:2}⋅e ⋅Ξ_S2__⎜───⎟
#                  ⎝ 2 ⎠                                           ⎝ 2 ⎠   27⋅I_
# ────────────────────── - ───────────────────────────────────────────── + ─────
#                                                8
#
#
#    4                       3                       4                       3
# S__ ⋅\mathcal{A}_{1, 3:2}⋅e ⋅Ξ_S2__(4⋅n)   81⋅I_S__ ⋅\mathcal{A}_{1, 3:2}⋅e ⋅Ξ
# ──────────────────────────────────────── + ───────────────────────────────────
#                 128                                              64
#
#                      4                              ⎛n⎞
#              11⋅I_S__ ⋅\mathcal{A}_{1, 3:2}⋅e⋅Ξ_S2__⎜─⎟           4
# _S2__(5⋅n)                                          ⎝2⎠   11⋅I_S__ ⋅\mathcal{A
# ────────── - ────────────────────────────────────────── + ────────────────────
#                                  16
#
#                                  4                              ⎛3⋅n⎞
#                          35⋅I_S__ ⋅\mathcal{A}_{1, 3:2}⋅e⋅Ξ_S2__⎜───⎟
# }_{1, 3:2}⋅e⋅Ξ_S2__(n)                                          ⎝ 2 ⎠   29⋅I_S
# ────────────────────── + ──────────────────────────────────────────── - ──────
# 4                                             16
#
#                                                 4
#   4                                      3⋅I_S__ ⋅\mathcal{A}_{1, 3:2}⋅e⋅Ξ_S2_
# __ ⋅\mathcal{A}_{1, 3:2}⋅e⋅Ξ_S2__(2⋅n)
# ────────────────────────────────────── - ─────────────────────────────────────
#                32                                             2
#
#  ⎛5⋅n⎞                                                         4  2       ⎛n⎞
# _⎜───⎟          4                                      23⋅I_S__ ⋅e ⋅Ξ_S2__⎜─⎟
#  ⎝ 2 ⎠   9⋅I_S__ ⋅\mathcal{A}_{1, 3:2}⋅e⋅Ξ_S2__(4⋅n)                      ⎝2⎠
# ────── + ─────────────────────────────────────────── + ──────────────────────
#                               16                                 32
#
#                                      4  2       ⎛3⋅n⎞
#            4  2             341⋅I_S__ ⋅e ⋅Ξ_S2__⎜───⎟            4  2
#   257⋅I_S__ ⋅e ⋅Ξ_S2__(n)                       ⎝ 2 ⎠   115⋅I_S__ ⋅e ⋅Ξ_S2__(2
# + ─────────────────────── - ───────────────────────── - ──────────────────────
#             128                         32                         128
#
#              4  2       ⎛5⋅n⎞
#       9⋅I_S__ ⋅e ⋅Ξ_S2__⎜───⎟            4  2                       4  2
# ⋅n)                     ⎝ 2 ⎠   513⋅I_S__ ⋅e ⋅Ξ_S2__(3⋅n)   27⋅I_S__ ⋅e ⋅Ξ_S2_
# ─── - ─────────────────────── + ───────────────────────── + ──────────────────
#                  4                         128                         64
#
#                 4       ⎛n⎞
#          5⋅I_S__ ⋅Ξ_S2__⎜─⎟           4
# _(4⋅n)                  ⎝2⎠   11⋅I_S__ ⋅Ξ_S2__(n)        4       ⎛3⋅n⎞   9⋅I_S
# ────── - ────────────────── + ─────────────────── - I_S__ ⋅Ξ_S2__⎜───⎟ + ─────
#                  8                     32                        ⎝ 2 ⎠
#
#                                                   2                     4  2
#   4                      4               121⋅I_S__ ⋅\mathcal{A}_{1, 3:2} ⋅e ⋅Ξ
# __ ⋅Ξ_S2__(2⋅n)   3⋅I_S__ ⋅Ξ_S2__(3⋅n)
# ─────────────── + ──────────────────── - ─────────────────────────────────────
#     32                     16                                 512
#
#      ⎛n⎞                                                            2
# _S2__⎜─⎟            2                     4  2             289⋅I_S__ ⋅\mathcal
#      ⎝2⎠   143⋅I_S__ ⋅\mathcal{A}_{1, 3:2} ⋅e ⋅Ξ_S2__(n)
# ──────── + ───────────────────────────────────────────── + ───────────────────
#                                  8
#
#             4  2       ⎛3⋅n⎞
# {A}_{1, 3:2} ⋅e ⋅Ξ_S2__⎜───⎟            2                     4  2
#                        ⎝ 2 ⎠   331⋅I_S__ ⋅\mathcal{A}_{1, 3:2} ⋅e ⋅Ξ_S2__(2⋅n)
# ──────────────────────────── - ───────────────────────────────────────────────
#    512                                                32
#
#             2                     4  2       ⎛5⋅n⎞
#    215⋅I_S__ ⋅\mathcal{A}_{1, 3:2} ⋅e ⋅Ξ_S2__⎜───⎟           2
#                                              ⎝ 2 ⎠   11⋅I_S__ ⋅\mathcal{A}_{1,
#  - ─────────────────────────────────────────────── + ─────────────────────────
#                          512                                               8
#
#                                  2                     4  2       ⎛7⋅n⎞
#      4  2               247⋅I_S__ ⋅\mathcal{A}_{1, 3:2} ⋅e ⋅Ξ_S2__⎜───⎟
#  3:2} ⋅e ⋅Ξ_S2__(3⋅n)                                             ⎝ 2 ⎠   3⋅I_
# ───────────────────── + ─────────────────────────────────────────────── - ────
#                                               1024
#
#                                                     2                     4  2
#    2                     4  2               63⋅I_S__ ⋅\mathcal{A}_{1, 3:2} ⋅e
# S__ ⋅\mathcal{A}_{1, 3:2} ⋅e ⋅Ξ_S2__(4⋅n)
# ───────────────────────────────────────── + ──────────────────────────────────
#                   64                                             1024
#
#        ⎛9⋅n⎞           2                     4       ⎛n⎞
# ⋅Ξ_S2__⎜───⎟   15⋅I_S__ ⋅\mathcal{A}_{1, 3:2} ⋅Ξ_S2__⎜─⎟           2
#        ⎝ 2 ⎠                                         ⎝2⎠   15⋅I_S__ ⋅\mathcal{
# ──────────── + ───────────────────────────────────────── - ───────────────────
#                                   256
#
#                                  2                     4       ⎛3⋅n⎞
#            4             15⋅I_S__ ⋅\mathcal{A}_{1, 3:2} ⋅Ξ_S2__⎜───⎟   3⋅I_S__
# A}_{1, 3:2} ⋅Ξ_S2__(n)                                         ⎝ 2 ⎠
# ────────────────────── + ─────────────────────────────────────────── + ───────
#  16                                          256
#
# 2                     4       ⎛5⋅n⎞
#  ⋅\mathcal{A}_{1, 3:2} ⋅Ξ_S2__⎜───⎟          2                     4
#                               ⎝ 2 ⎠   3⋅I_S__ ⋅\mathcal{A}_{1, 3:2} ⋅Ξ_S2__(3⋅
# ─────────────────────────────────── - ────────────────────────────────────────
#             256                                           16
#
#             2                     4       ⎛7⋅n⎞             2
#      3⋅I_S__ ⋅\mathcal{A}_{1, 3:2} ⋅Ξ_S2__⎜───⎟   2407⋅I_S__ ⋅\mathcal{A}_{1,
# n)                                        ⎝ 2 ⎠
# ── + ────────────────────────────────────────── + ────────────────────────────
#                         256                                            512
#
#     3  3       ⎛n⎞
# 3:2} ⋅e ⋅Ξ_S2__⎜─⎟             2                     3  3             75⋅I_S__
#                ⎝2⎠   7049⋅I_S__ ⋅\mathcal{A}_{1, 3:2} ⋅e ⋅Ξ_S2__(n)
# ────────────────── - ────────────────────────────────────────────── - ────────
#                                            64
#
# 2                     3  3       ⎛3⋅n⎞
#  ⋅\mathcal{A}_{1, 3:2} ⋅e ⋅Ξ_S2__⎜───⎟             2                     3  3
#                                  ⎝ 2 ⎠   2411⋅I_S__ ⋅\mathcal{A}_{1, 3:2} ⋅e ⋅
# ────────────────────────────────────── + ─────────────────────────────────────
#               8                                                 64
#
#                        2                     3  3       ⎛5⋅n⎞
#               935⋅I_S__ ⋅\mathcal{A}_{1, 3:2} ⋅e ⋅Ξ_S2__⎜───⎟           2
# Ξ_S2__(2⋅n)                                             ⎝ 2 ⎠   63⋅I_S__ ⋅\mat
# ─────────── + ─────────────────────────────────────────────── - ──────────────
#                                     128
#
#                                              2                     3  3
#                 3  3               1509⋅I_S__ ⋅\mathcal{A}_{1, 3:2} ⋅e ⋅Ξ_S2__
# hcal{A}_{1, 3:2} ⋅e ⋅Ξ_S2__(3⋅n)
# ──────────────────────────────── - ───────────────────────────────────────────
#         64                                               512
#
# ⎛7⋅n⎞           2                     3  3       ⎛9⋅n⎞           2
# ⎜───⎟   81⋅I_S__ ⋅\mathcal{A}_{1, 3:2} ⋅e ⋅Ξ_S2__⎜───⎟   21⋅I_S__ ⋅\mathcal{A}
# ⎝ 2 ⎠                                            ⎝ 2 ⎠
# ───── + ────────────────────────────────────────────── - ─────────────────────
#                              256
#
#          3         ⎛n⎞
# _{1, 3:2} ⋅e⋅Ξ_S2__⎜─⎟           2                     3               21⋅I_S_
#                    ⎝2⎠   69⋅I_S__ ⋅\mathcal{A}_{1, 3:2} ⋅e⋅Ξ_S2__(n)
# ────────────────────── + ─────────────────────────────────────────── + ───────
# 64                                            8
#
#  2                     3         ⎛3⋅n⎞
# _ ⋅\mathcal{A}_{1, 3:2} ⋅e⋅Ξ_S2__⎜───⎟           2                     3
#                                  ⎝ 2 ⎠   27⋅I_S__ ⋅\mathcal{A}_{1, 3:2} ⋅e⋅Ξ_S
# ────────────────────────────────────── - ─────────────────────────────────────
#                32                                              8
#
#                    2                     3         ⎛5⋅n⎞
#            15⋅I_S__ ⋅\mathcal{A}_{1, 3:2} ⋅e⋅Ξ_S2__⎜───⎟          2
# 2__(2⋅n)                                           ⎝ 2 ⎠   3⋅I_S__ ⋅\mathcal{A
# ──────── - ───────────────────────────────────────────── + ───────────────────
#                                  32
#
#                                    2                     3         ⎛7⋅n⎞
#           3                 9⋅I_S__ ⋅\mathcal{A}_{1, 3:2} ⋅e⋅Ξ_S2__⎜───⎟   21⋅
# }_{1, 3:2} ⋅e⋅Ξ_S2__(3⋅n)                                          ⎝ 2 ⎠
# ───────────────────────── + ──────────────────────────────────────────── + ───
#   8                                              64
#
#      2                     2  2       ⎛n⎞
# I_S__ ⋅\mathcal{A}_{1, 3:2} ⋅e ⋅Ξ_S2__⎜─⎟            2                     2
#                                       ⎝2⎠   663⋅I_S__ ⋅\mathcal{A}_{1, 3:2} ⋅e
# ───────────────────────────────────────── - ──────────────────────────────────
#                   4                                               16
#
#                        2                     2  2       ⎛3⋅n⎞
# 2             297⋅I_S__ ⋅\mathcal{A}_{1, 3:2} ⋅e ⋅Ξ_S2__⎜───⎟           2
#  ⋅Ξ_S2__(n)                                             ⎝ 2 ⎠   87⋅I_S__ ⋅\mat
# ─────────── - ─────────────────────────────────────────────── + ──────────────
#                                      32
#
#                                            2                     2  2       ⎛5
#                 2  2               51⋅I_S__ ⋅\mathcal{A}_{1, 3:2} ⋅e ⋅Ξ_S2__⎜─
# hcal{A}_{1, 3:2} ⋅e ⋅Ξ_S2__(2⋅n)                                            ⎝
# ──────────────────────────────── + ───────────────────────────────────────────
#         16                                               16
#
# ⋅n⎞                                                           2
# ──⎟          2                     2  2               27⋅I_S__ ⋅\mathcal{A}_{1
# 2 ⎠   3⋅I_S__ ⋅\mathcal{A}_{1, 3:2} ⋅e ⋅Ξ_S2__(3⋅n)
# ─── - ───────────────────────────────────────────── + ────────────────────────
#                             16                                              32
#
#       2  2       ⎛7⋅n⎞                                                     2
# , 3:2} ⋅e ⋅Ξ_S2__⎜───⎟          2                     2             3⋅I_S__ ⋅\
#                  ⎝ 2 ⎠   3⋅I_S__ ⋅\mathcal{A}_{1, 3:2} ⋅Ξ_S2__(n)
# ────────────────────── + ──────────────────────────────────────── - ──────────
#                                             2
#
#                    2       ⎛3⋅n⎞
# mathcal{A}_{1, 3:2} ⋅Ξ_S2__⎜───⎟          2                     2
#                            ⎝ 2 ⎠   3⋅I_S__ ⋅\mathcal{A}_{1, 3:2} ⋅Ξ_S2__(2⋅n)
# ──────────────────────────────── - ──────────────────────────────────────────
#           16                                           4
#
#          2                     2       ⎛5⋅n⎞            2
#   3⋅I_S__ ⋅\mathcal{A}_{1, 3:2} ⋅Ξ_S2__⎜───⎟   489⋅I_S__ ⋅\mathcal{A}_{1, 3:2}
#                                        ⎝ 2 ⎠
# + ────────────────────────────────────────── - ───────────────────────────────
#                       16                                            32
#
#   3       ⎛n⎞                                                            2
# ⋅e ⋅Ξ_S2__⎜─⎟            2                       3             2217⋅I_S__ ⋅\ma
#           ⎝2⎠   285⋅I_S__ ⋅\mathcal{A}_{1, 3:2}⋅e ⋅Ξ_S2__(n)
# ───────────── + ──────────────────────────────────────────── + ───────────────
#                                      4
#
#                    3       ⎛3⋅n⎞
# thcal{A}_{1, 3:2}⋅e ⋅Ξ_S2__⎜───⎟           2                       3
#                            ⎝ 2 ⎠   63⋅I_S__ ⋅\mathcal{A}_{1, 3:2}⋅e ⋅Ξ_S2__(2⋅
# ──────────────────────────────── - ───────────────────────────────────────────
#         64                                               32
#
#                2                       3       ⎛5⋅n⎞           2
#      1401⋅I_S__ ⋅\mathcal{A}_{1, 3:2}⋅e ⋅Ξ_S2__⎜───⎟   81⋅I_S__ ⋅\mathcal{A}_{
# n)                                             ⎝ 2 ⎠
# ── - ─────────────────────────────────────────────── + ───────────────────────
#                             64                                               3
#
#          3       ⎛7⋅n⎞          2                              ⎛n⎞
# 1, 3:2}⋅e ⋅Ξ_S2__⎜───⎟   3⋅I_S__ ⋅\mathcal{A}_{1, 3:2}⋅e⋅Ξ_S2__⎜─⎟
#                  ⎝ 2 ⎠                                         ⎝2⎠          2
# ────────────────────── + ───────────────────────────────────────── - 6⋅I_S__ ⋅
# 2                                            2
#
#                                            2                              ⎛3⋅n
#                                    21⋅I_S__ ⋅\mathcal{A}_{1, 3:2}⋅e⋅Ξ_S2__⎜───
#                                                                           ⎝ 2
# \mathcal{A}_{1, 3:2}⋅e⋅Ξ_S2__(n) - ───────────────────────────────────────────
#                                                         8
#
# ⎞                                                        2
# ⎟          2                                      9⋅I_S__ ⋅\mathcal{A}_{1, 3:2
# ⎠   3⋅I_S__ ⋅\mathcal{A}_{1, 3:2}⋅e⋅Ξ_S2__(2⋅n)
# ─ + ─────────────────────────────────────────── + ────────────────────────────
#                          4                                             8
#
#           ⎛5⋅n⎞           2  2       ⎛n⎞                                    2
# }⋅e⋅Ξ_S2__⎜───⎟   15⋅I_S__ ⋅e ⋅Ξ_S2__⎜─⎟          2  2             183⋅I_S__ ⋅
#           ⎝ 2 ⎠                      ⎝2⎠   3⋅I_S__ ⋅e ⋅Ξ_S2__(n)
# ─────────────── - ────────────────────── + ───────────────────── + ───────────
#                             8                        8
#
#  2       ⎛3⋅n⎞                                     2  2       ⎛5⋅n⎞          2
# e ⋅Ξ_S2__⎜───⎟          2  2               27⋅I_S__ ⋅e ⋅Ξ_S2__⎜───⎟   3⋅I_S__
#          ⎝ 2 ⎠   3⋅I_S__ ⋅e ⋅Ξ_S2__(2⋅n)                      ⎝ 2 ⎠
# ────────────── - ─────────────────────── + ──────────────────────── + ────────
#  16                         16                        16
#
#        ⎛n⎞                               2       ⎛3⋅n⎞
# ⋅Ξ_S2__⎜─⎟          2             3⋅I_S__ ⋅Ξ_S2__⎜───⎟
#        ⎝2⎠   3⋅I_S__ ⋅Ξ_S2__(n)                  ⎝ 2 ⎠   143⋅\mathcal{A}_{1, 3
# ────────── - ────────────────── + ──────────────────── - ─────────────────────
# 4                    4                     4                               8
#
#
#    4  2                                     4  2
# :2} ⋅e ⋅Ξ_S2__(n)   331⋅\mathcal{A}_{1, 3:2} ⋅e ⋅Ξ_S2__(2⋅n)   11⋅\mathcal{A}_
# ───────────────── + ──────────────────────────────────────── - ───────────────
#                                        32
#
#
#         4  2                                     4  2
# {1, 3:2} ⋅e ⋅Ξ_S2__(3⋅n)   3⋅\mathcal{A}_{1, 3:2} ⋅e ⋅Ξ_S2__(4⋅n)   15⋅\mathca
# ──────────────────────── + ────────────────────────────────────── + ──────────
#     8                                        64
#
#
#              4                                   4
# l{A}_{1, 3:2} ⋅Ξ_S2__(n)   3⋅\mathcal{A}_{1, 3:2} ⋅Ξ_S2__(3⋅n)   7049⋅\mathcal
# ──────────────────────── + ─────────────────────────────────── + ─────────────
#       16                                    16
#
#
#             3  3                                      3  3
# {A}_{1, 3:2} ⋅e ⋅Ξ_S2__(n)   2411⋅\mathcal{A}_{1, 3:2} ⋅e ⋅Ξ_S2__(2⋅n)   63⋅\m
# ────────────────────────── - ───────────────────────────────────────── + ─────
#       64                                         64
#
#
#                   3  3                                      3
# athcal{A}_{1, 3:2} ⋅e ⋅Ξ_S2__(3⋅n)   69⋅\mathcal{A}_{1, 3:2} ⋅e⋅Ξ_S2__(n)   27
# ────────────────────────────────── - ──────────────────────────────────── + ──
#               64                                      8
#
#
#                      3                                       3
# ⋅\mathcal{A}_{1, 3:2} ⋅e⋅Ξ_S2__(2⋅n)   3⋅\mathcal{A}_{1, 3:2} ⋅e⋅Ξ_S2__(3⋅n)
# ──────────────────────────────────── - ───────────────────────────────────── +
#                 8                                        8
#
#
#                          2  2                                    2  2
#  663⋅\mathcal{A}_{1, 3:2} ⋅e ⋅Ξ_S2__(n)   87⋅\mathcal{A}_{1, 3:2} ⋅e ⋅Ξ_S2__(2
#  ────────────────────────────────────── - ────────────────────────────────────
#                    16                                        16
#
#
#                             2  2                                     2
# ⋅n)   3⋅\mathcal{A}_{1, 3:2} ⋅e ⋅Ξ_S2__(3⋅n)   3⋅\mathcal{A}_{1, 3:2} ⋅Ξ_S2__(
# ─── + ────────────────────────────────────── - ───────────────────────────────
#                         16                                     2
#
#
#                            2                                         3
# n)   3⋅\mathcal{A}_{1, 3:2} ⋅Ξ_S2__(2⋅n)   285⋅\mathcal{A}_{1, 3:2}⋅e ⋅Ξ_S2__(
# ── + ─────────────────────────────────── - ───────────────────────────────────
#                       4                                      4
#
#
#                               3
# n)   63⋅\mathcal{A}_{1, 3:2}⋅e ⋅Ξ_S2__(2⋅n)
# ── + ────────────────────────────────────── + 6⋅\mathcal{A}_{1, 3:2}⋅e⋅Ξ_S2__(
#                        32
#
#
#                                                 2                2
#      3⋅\mathcal{A}_{1, 3:2}⋅e⋅Ξ_S2__(2⋅n)   21⋅e ⋅Ξ_S2__(n)   3⋅e ⋅Ξ_S2__(2⋅n)
# n) - ──────────────────────────────────── - ─────────────── + ────────────────
#                       4                            8                 16
#
#
#
#    3⋅Ξ_S2__(n)
#  + ───────────
#         4

# %%
expr = lib_heating_11

for mode, love_S in love_coeffs_sat_LIB.items():
    expr = collect(expr, love_S)
    
    
disp(expr)
# Out:
# ⎛        4                     4  2           4                     3  3⎞
# ⎜63⋅I_S__ ⋅\mathcal{A}_{1, 1:1} ⋅e    81⋅I_S__ ⋅\mathcal{A}_{1, 1:1} ⋅e ⎟
# ⎜────────────────────────────────── + ──────────────────────────────────⎟⋅Ξ_S2
# ⎝               256                                  128                ⎠
#
#           ⎛            4                     4  2          4
#           ⎜  2783⋅I_S__ ⋅\mathcal{A}_{1, 1:1} ⋅e    3⋅I_S__ ⋅\mathcal{A}_{1, 1
# __(5⋅n) + ⎜- ──────────────────────────────────── + ──────────────────────────
#           ⎝                  6144                                 64
#
#    4            4                     3  3          4                     3
# :1}    203⋅I_S__ ⋅\mathcal{A}_{1, 1:1} ⋅e    9⋅I_S__ ⋅\mathcal{A}_{1, 1:1} ⋅e
# ──── + ─────────────────────────────────── + ────────────────────────────────
#                        128                                  32
#
#           4                     2  2           4                       3
#   27⋅I_S__ ⋅\mathcal{A}_{1, 1:1} ⋅e    81⋅I_S__ ⋅\mathcal{A}_{1, 1:1}⋅e    173
# + ────────────────────────────────── + ───────────────────────────────── + ───
#                   32                                   64
#
#       2                     4  2            2                     3  3⎞
# ⋅I_S__ ⋅\mathcal{A}_{1, 1:1} ⋅e    633⋅I_S__ ⋅\mathcal{A}_{1, 1:1} ⋅e ⎟
# ──────────────────────────────── - ───────────────────────────────────⎟⋅Ξ_S2__
#              512                                   256                ⎠
#
#         ⎛         4                     4  2           4                     4
#         ⎜527⋅I_S__ ⋅\mathcal{A}_{1, 1:1} ⋅e    13⋅I_S__ ⋅\mathcal{A}_{1, 1:1}
# (4⋅n) + ⎜─────────────────────────────────── - ───────────────────────────────
#         ⎝                192                                 512
#
#               4                     3  3           4                     3
#    49009⋅I_S__ ⋅\mathcal{A}_{1, 1:1} ⋅e    25⋅I_S__ ⋅\mathcal{A}_{1, 1:1} ⋅e
#  - ───────────────────────────────────── - ───────────────────────────────── -
#                     3072                                  128
#
#           4                     2  2          4                     2
#  649⋅I_S__ ⋅\mathcal{A}_{1, 1:1} ⋅e    3⋅I_S__ ⋅\mathcal{A}_{1, 1:1}    1975⋅I
#  ─────────────────────────────────── + ────────────────────────────── + ──────
#                  128                                 16
#
#     4                       3          4                                   4
# _S__ ⋅\mathcal{A}_{1, 1:1}⋅e    9⋅I_S__ ⋅\mathcal{A}_{1, 1:1}⋅e   495⋅I_S__ ⋅e
# ───────────────────────────── + ─────────────────────────────── + ────────────
#           128                                  16                      128
#
# 2             2                     4  2          2                     4
#     1277⋅I_S__ ⋅\mathcal{A}_{1, 1:1} ⋅e    3⋅I_S__ ⋅\mathcal{A}_{1, 1:1}    94
# ─ - ──────────────────────────────────── + ────────────────────────────── + ──
#                     256                                 128
#
#        2                     3  3          2                     3
# 1⋅I_S__ ⋅\mathcal{A}_{1, 1:1} ⋅e    3⋅I_S__ ⋅\mathcal{A}_{1, 1:1} ⋅e   303⋅I_S
# ───────────────────────────────── - ──────────────────────────────── + ───────
#                32                                  16
#
#   2                     2  2            2                       3
# __ ⋅\mathcal{A}_{1, 1:1} ⋅e    633⋅I_S__ ⋅\mathcal{A}_{1, 1:1}⋅e    143⋅\mathc
# ──────────────────────────── - ────────────────────────────────── + ──────────
#           64                                   32
#
#               4  2                           3  3⎞               ⎛
# al{A}_{1, 1:1} ⋅e    357⋅\mathcal{A}_{1, 1:1} ⋅e ⎟               ⎜  15911⋅I_S_
# ────────────────── - ────────────────────────────⎟⋅Ξ_S2__(3⋅n) + ⎜- ──────────
#    32                             16             ⎠               ⎝
#
#  4                     4  2           4                     4               4
# _ ⋅\mathcal{A}_{1, 1:1} ⋅e    23⋅I_S__ ⋅\mathcal{A}_{1, 1:1}    107657⋅I_S__ ⋅
# ─────────────────────────── + ─────────────────────────────── + ──────────────
#        3072                                  64
#
#                     3  3            4                     3               4
# \mathcal{A}_{1, 1:1} ⋅e    227⋅I_S__ ⋅\mathcal{A}_{1, 1:1} ⋅e   1973⋅I_S__ ⋅\m
# ──────────────────────── - ────────────────────────────────── + ──────────────
#    3072                                   128
#
#                   2  2           4                     2             4
# athcal{A}_{1, 1:1} ⋅e    25⋅I_S__ ⋅\mathcal{A}_{1, 1:1}    6385⋅I_S__ ⋅\mathca
# ────────────────────── - ─────────────────────────────── - ───────────────────
#   128                                   32                                 128
#
#                3           4                                  4  2           4
# l{A}_{1, 1:1}⋅e    11⋅I_S__ ⋅\mathcal{A}_{1, 1:1}⋅e   43⋅I_S__ ⋅e    15⋅I_S__
# ──────────────── + ──────────────────────────────── - ──────────── + ─────────
#                                   16                       4             32
#
#              2                     4  2          2                     4
#    2537⋅I_S__ ⋅\mathcal{A}_{1, 1:1} ⋅e    3⋅I_S__ ⋅\mathcal{A}_{1, 1:1}    876
#  + ──────────────────────────────────── - ────────────────────────────── - ───
#                    256                                  8
#
#        2                     3  3           2                     3
# 1⋅I_S__ ⋅\mathcal{A}_{1, 1:1} ⋅e    57⋅I_S__ ⋅\mathcal{A}_{1, 1:1} ⋅e   51⋅I_S
# ───────────────────────────────── + ───────────────────────────────── - ──────
#              128                                    16
#
#   2                     2  2          2                     2             2
# __ ⋅\mathcal{A}_{1, 1:1} ⋅e    3⋅I_S__ ⋅\mathcal{A}_{1, 1:1}    1275⋅I_S__ ⋅\m
# ──────────────────────────── + ────────────────────────────── + ──────────────
#           2                                  8
#
#                     3          2                                  2  2
# athcal{A}_{1, 1:1}⋅e    3⋅I_S__ ⋅\mathcal{A}_{1, 1:1}⋅e   87⋅I_S__ ⋅e    73⋅\m
# ───────────────────── - ─────────────────────────────── + ──────────── - ─────
#    16                                  2                       8
#
#                   4  2                         4
# athcal{A}_{1, 1:1} ⋅e    3⋅\mathcal{A}_{1, 1:1}                           3  3
# ────────────────────── + ─────────────────────── + 59⋅\mathcal{A}_{1, 1:1} ⋅e
#         8                           8
#
#                                                       2  2
#                          3     63⋅\mathcal{A}_{1, 1:1} ⋅e    357⋅\mathcal{A}_{
#  - 3⋅\mathcal{A}_{1, 1:1} ⋅e + ─────────────────────────── - ─────────────────
#                                             4                             8
#
#          3⎞               ⎛          4                     4  2           4
# 1, 1:1}⋅e ⎟               ⎜6743⋅I_S__ ⋅\mathcal{A}_{1, 1:1} ⋅e    65⋅I_S__ ⋅\m
# ──────────⎟⋅Ξ_S2__(2⋅n) + ⎜──────────────────────────────────── - ────────────
#           ⎠               ⎝                768
#
#                   4               4                     3  3            4
# athcal{A}_{1, 1:1}    144959⋅I_S__ ⋅\mathcal{A}_{1, 1:1} ⋅e    673⋅I_S__ ⋅\mat
# ─────────────────── - ────────────────────────────────────── + ───────────────
#   512                                  3072
#
#                 3               4                     2  2           4
# hcal{A}_{1, 1:1} ⋅e   3323⋅I_S__ ⋅\mathcal{A}_{1, 1:1} ⋅e    27⋅I_S__ ⋅\mathca
# ─────────────────── - ──────────────────────────────────── + ─────────────────
# 128                                   128                                   16
#
#              2             4                       3           4
# l{A}_{1, 1:1}    6005⋅I_S__ ⋅\mathcal{A}_{1, 1:1}⋅e    93⋅I_S__ ⋅\mathcal{A}_{
# ────────────── + ─────────────────────────────────── - ───────────────────────
#                                  128                                  16
#
#                       4  2           4             2                     4  2
# 1, 1:1}⋅e   1097⋅I_S__ ⋅e    13⋅I_S__    4427⋅I_S__ ⋅\mathcal{A}_{1, 1:1} ⋅e
# ───────── + ────────────── - ───────── - ────────────────────────────────────
#                  128             8                       256
#
#           2                     4             2                     3  3
#   15⋅I_S__ ⋅\mathcal{A}_{1, 1:1}    6119⋅I_S__ ⋅\mathcal{A}_{1, 1:1} ⋅e    159
# + ─────────────────────────────── + ──────────────────────────────────── - ───
#                 128                                  64
#
#       2                     3               2                     2  2
# ⋅I_S__ ⋅\mathcal{A}_{1, 1:1} ⋅e   3117⋅I_S__ ⋅\mathcal{A}_{1, 1:1} ⋅e    9⋅I_S
# ─────────────────────────────── + ──────────────────────────────────── - ─────
#              16                                    64
#
#   2                     2             2                       3
# __ ⋅\mathcal{A}_{1, 1:1}    2787⋅I_S__ ⋅\mathcal{A}_{1, 1:1}⋅e           2
# ───────────────────────── - ─────────────────────────────────── + 9⋅I_S__ ⋅\ma
#          4                                   32
#
#                               2  2          2                           4  2
#                       57⋅I_S__ ⋅e    3⋅I_S__    527⋅\mathcal{A}_{1, 1:1} ⋅e
# thcal{A}_{1, 1:1}⋅e - ──────────── + ──────── + ──────────────────────────── -
#                            4            2                    32
#
#                           3  3
#  1421⋅\mathcal{A}_{1, 1:1} ⋅e                          3     333⋅\mathcal{A}_{
#  ───────────────────────────── + 9⋅\mathcal{A}_{1, 1:1} ⋅e - ─────────────────
#                16                                                         8
#
#        2  2                         2                             3
# 1, 1:1} ⋅e    3⋅\mathcal{A}_{1, 1:1}    285⋅\mathcal{A}_{1, 1:1}⋅e
# ─────────── + ─────────────────────── + ─────────────────────────── - 6⋅\mathc
#                          2                           4
#
#                        2⎞
#                    21⋅e ⎟
# al{A}_{1, 1:1}⋅e + ─────⎟⋅Ξ_S2__(n)
#                      2  ⎠

# %%
expr = lib_heating_32

for mode, love_S in love_coeffs_sat_LIB.items():
    expr = collect(expr, love_S)
    
    
disp(expr)
# Out:
#           4                     4  2       ⎛n⎞             4
# 1129⋅I_S__ ⋅\mathcal{A}_{1, 3:2} ⋅e ⋅Ξ_S2__⎜─⎟   2863⋅I_S__ ⋅\mathcal{A}_{1, 3
#                                            ⎝2⎠
# ────────────────────────────────────────────── - ─────────────────────────────
#                      6144                                              6144
#
#    4  2       ⎛3⋅n⎞             4                     4  2       ⎛5⋅n⎞
# :2} ⋅e ⋅Ξ_S2__⎜───⎟   1961⋅I_S__ ⋅\mathcal{A}_{1, 3:2} ⋅e ⋅Ξ_S2__⎜───⎟   1127⋅
#               ⎝ 2 ⎠                                              ⎝ 2 ⎠
# ─────────────────── + ──────────────────────────────────────────────── - ─────
#                                             6144
#
#      4                     4  2       ⎛7⋅n⎞           4                     4
# I_S__ ⋅\mathcal{A}_{1, 3:2} ⋅e ⋅Ξ_S2__⎜───⎟   21⋅I_S__ ⋅\mathcal{A}_{1, 3:2} ⋅
#                                       ⎝ 2 ⎠
# ─────────────────────────────────────────── - ────────────────────────────────
#                  6144                                              256
#
#  2       ⎛9⋅n⎞          4                     4       ⎛n⎞           4
# e ⋅Ξ_S2__⎜───⎟   7⋅I_S__ ⋅\mathcal{A}_{1, 3:2} ⋅Ξ_S2__⎜─⎟   37⋅I_S__ ⋅\mathcal
#          ⎝ 2 ⎠                                        ⎝2⎠
# ────────────── - ──────────────────────────────────────── - ──────────────────
#                                    128
#
#             4       ⎛3⋅n⎞          4                     4       ⎛5⋅n⎞
# {A}_{1, 3:2} ⋅Ξ_S2__⎜───⎟   5⋅I_S__ ⋅\mathcal{A}_{1, 3:2} ⋅Ξ_S2__⎜───⎟   I_S__
#                     ⎝ 2 ⎠                                        ⎝ 2 ⎠
# ───────────────────────── - ────────────────────────────────────────── - ─────
#   512                                          512
#
# 4                     4       ⎛7⋅n⎞              4                     3  3
#  ⋅\mathcal{A}_{1, 3:2} ⋅Ξ_S2__⎜───⎟   12197⋅I_S__ ⋅\mathcal{A}_{1, 3:2} ⋅e ⋅Ξ_
#                               ⎝ 2 ⎠
# ─────────────────────────────────── - ────────────────────────────────────────
#               64                                            3072
#
#     ⎛n⎞             4                     3  3       ⎛3⋅n⎞              4
# S2__⎜─⎟   4081⋅I_S__ ⋅\mathcal{A}_{1, 3:2} ⋅e ⋅Ξ_S2__⎜───⎟   18781⋅I_S__ ⋅\mat
#     ⎝2⎠                                              ⎝ 2 ⎠
# ─────── + ──────────────────────────────────────────────── - ─────────────────
#                                 512
#
#                 3  3       ⎛5⋅n⎞            4                     3  3       ⎛
# hcal{A}_{1, 3:2} ⋅e ⋅Ξ_S2__⎜───⎟   649⋅I_S__ ⋅\mathcal{A}_{1, 3:2} ⋅e ⋅Ξ_S2__⎜
#                            ⎝ 2 ⎠                                             ⎝
# ──────────────────────────────── + ───────────────────────────────────────────
#       3072                                               256
#
# 7⋅n⎞           4                     3  3       ⎛9⋅n⎞           4
# ───⎟   27⋅I_S__ ⋅\mathcal{A}_{1, 3:2} ⋅e ⋅Ξ_S2__⎜───⎟   35⋅I_S__ ⋅\mathcal{A}_
#  2 ⎠                                            ⎝ 2 ⎠
# ──── - ────────────────────────────────────────────── + ──────────────────────
#                              64                                             12
#
#         3         ⎛n⎞           4                     3         ⎛3⋅n⎞
# {1, 3:2} ⋅e⋅Ξ_S2__⎜─⎟   35⋅I_S__ ⋅\mathcal{A}_{1, 3:2} ⋅e⋅Ξ_S2__⎜───⎟   59⋅I_S
#                   ⎝2⎠                                           ⎝ 2 ⎠
# ───────────────────── - ───────────────────────────────────────────── + ──────
# 8                                             64
#
#   4                     3         ⎛5⋅n⎞          4                     3
# __ ⋅\mathcal{A}_{1, 3:2} ⋅e⋅Ξ_S2__⎜───⎟   3⋅I_S__ ⋅\mathcal{A}_{1, 3:2} ⋅e⋅Ξ_S
#                                   ⎝ 2 ⎠
# ─────────────────────────────────────── - ────────────────────────────────────
#                128                                             16
#
#    ⎛7⋅n⎞            4                     2  2       ⎛n⎞           4
# 2__⎜───⎟   569⋅I_S__ ⋅\mathcal{A}_{1, 3:2} ⋅e ⋅Ξ_S2__⎜─⎟   63⋅I_S__ ⋅\mathcal{
#    ⎝ 2 ⎠                                             ⎝2⎠
# ──────── - ───────────────────────────────────────────── + ───────────────────
#                                 128
#
#            2  2       ⎛3⋅n⎞            4                     2  2       ⎛5⋅n⎞
# A}_{1, 3:2} ⋅e ⋅Ξ_S2__⎜───⎟   295⋅I_S__ ⋅\mathcal{A}_{1, 3:2} ⋅e ⋅Ξ_S2__⎜───⎟
#                       ⎝ 2 ⎠                                             ⎝ 2 ⎠
# ─────────────────────────── - ───────────────────────────────────────────────
#    8                                                128
#
#          4                     2  2       ⎛7⋅n⎞          4
#   9⋅I_S__ ⋅\mathcal{A}_{1, 3:2} ⋅e ⋅Ξ_S2__⎜───⎟   3⋅I_S__ ⋅\mathcal{A}_{1, 3:2
#                                           ⎝ 2 ⎠
# - ───────────────────────────────────────────── - ────────────────────────────
#                         8                                            32
#
#  2       ⎛n⎞           4                     2       ⎛3⋅n⎞        4
# } ⋅Ξ_S2__⎜─⎟   11⋅I_S__ ⋅\mathcal{A}_{1, 3:2} ⋅Ξ_S2__⎜───⎟   I_S__ ⋅\mathcal{A
#          ⎝2⎠                                         ⎝ 2 ⎠
# ──────────── + ─────────────────────────────────────────── - ─────────────────
#                                     32
#
#           2       ⎛5⋅n⎞             4                       3       ⎛n⎞
# }_{1, 3:2} ⋅Ξ_S2__⎜───⎟   1819⋅I_S__ ⋅\mathcal{A}_{1, 3:2}⋅e ⋅Ξ_S2__⎜─⎟   3695
#                   ⎝ 2 ⎠                                             ⎝2⎠
# ─────────────────────── + ───────────────────────────────────────────── - ────
#   4                                            128
#
#       4                       3       ⎛3⋅n⎞            4
# ⋅I_S__ ⋅\mathcal{A}_{1, 3:2}⋅e ⋅Ξ_S2__⎜───⎟   577⋅I_S__ ⋅\mathcal{A}_{1, 3:2}⋅
#                                       ⎝ 2 ⎠
# ─────────────────────────────────────────── + ────────────────────────────────
#                   128                                               32
#
#  3       ⎛5⋅n⎞           4                       3       ⎛7⋅n⎞           4
# e ⋅Ξ_S2__⎜───⎟   27⋅I_S__ ⋅\mathcal{A}_{1, 3:2}⋅e ⋅Ξ_S2__⎜───⎟   11⋅I_S__ ⋅\ma
#          ⎝ 2 ⎠                                           ⎝ 2 ⎠
# ────────────── - ───────────────────────────────────────────── - ─────────────
#                                        8
#
#                           ⎛n⎞           4                              ⎛3⋅n⎞
# thcal{A}_{1, 3:2}⋅e⋅Ξ_S2__⎜─⎟   35⋅I_S__ ⋅\mathcal{A}_{1, 3:2}⋅e⋅Ξ_S2__⎜───⎟
#                           ⎝2⎠                                          ⎝ 2 ⎠
# ───────────────────────────── + ──────────────────────────────────────────── -
#        16                                            16
#
#         4                              ⎛5⋅n⎞           4  2       ⎛n⎞
#  3⋅I_S__ ⋅\mathcal{A}_{1, 3:2}⋅e⋅Ξ_S2__⎜───⎟   23⋅I_S__ ⋅e ⋅Ξ_S2__⎜─⎟   341⋅I_
#                                        ⎝ 2 ⎠                      ⎝2⎠
#  ─────────────────────────────────────────── + ────────────────────── - ──────
#                       2                                  32
#
#    4  2       ⎛3⋅n⎞          4  2       ⎛5⋅n⎞          4       ⎛n⎞
# S__ ⋅e ⋅Ξ_S2__⎜───⎟   9⋅I_S__ ⋅e ⋅Ξ_S2__⎜───⎟   5⋅I_S__ ⋅Ξ_S2__⎜─⎟
#               ⎝ 2 ⎠                     ⎝ 2 ⎠                  ⎝2⎠        4
# ─────────────────── - ─────────────────────── - ────────────────── - I_S__ ⋅Ξ_
#       32                         4                      8
#
#                      2                     4  2       ⎛n⎞            2
#             121⋅I_S__ ⋅\mathcal{A}_{1, 3:2} ⋅e ⋅Ξ_S2__⎜─⎟   289⋅I_S__ ⋅\mathca
#     ⎛3⋅n⎞                                             ⎝2⎠
# S2__⎜───⎟ - ───────────────────────────────────────────── + ──────────────────
#     ⎝ 2 ⎠                        512
#
#              4  2       ⎛3⋅n⎞            2                     4  2       ⎛5⋅n
# l{A}_{1, 3:2} ⋅e ⋅Ξ_S2__⎜───⎟   215⋅I_S__ ⋅\mathcal{A}_{1, 3:2} ⋅e ⋅Ξ_S2__⎜───
#                         ⎝ 2 ⎠                                             ⎝ 2
# ───────────────────────────── - ──────────────────────────────────────────────
#     512                                               512
#
# ⎞            2                     4  2       ⎛7⋅n⎞           2
# ⎟   247⋅I_S__ ⋅\mathcal{A}_{1, 3:2} ⋅e ⋅Ξ_S2__⎜───⎟   63⋅I_S__ ⋅\mathcal{A}_{1
# ⎠                                             ⎝ 2 ⎠
# ─ + ─────────────────────────────────────────────── + ────────────────────────
#                           1024                                             102
#
#       4  2       ⎛9⋅n⎞           2                     4       ⎛n⎞           2
# , 3:2} ⋅e ⋅Ξ_S2__⎜───⎟   15⋅I_S__ ⋅\mathcal{A}_{1, 3:2} ⋅Ξ_S2__⎜─⎟   15⋅I_S__
#                  ⎝ 2 ⎠                                         ⎝2⎠
# ────────────────────── + ───────────────────────────────────────── + ─────────
# 4                                           256
#
#                      4       ⎛3⋅n⎞          2                     4       ⎛5⋅n
# ⋅\mathcal{A}_{1, 3:2} ⋅Ξ_S2__⎜───⎟   3⋅I_S__ ⋅\mathcal{A}_{1, 3:2} ⋅Ξ_S2__⎜───
#                              ⎝ 2 ⎠                                        ⎝ 2
# ────────────────────────────────── + ─────────────────────────────────────────
#            256                                          256
#
# ⎞          2                     4       ⎛7⋅n⎞             2
# ⎟   3⋅I_S__ ⋅\mathcal{A}_{1, 3:2} ⋅Ξ_S2__⎜───⎟   2407⋅I_S__ ⋅\mathcal{A}_{1, 3
# ⎠                                        ⎝ 2 ⎠
# ─ + ────────────────────────────────────────── + ─────────────────────────────
#                        256                                            512
#
#    3  3       ⎛n⎞           2                     3  3       ⎛3⋅n⎞
# :2} ⋅e ⋅Ξ_S2__⎜─⎟   75⋅I_S__ ⋅\mathcal{A}_{1, 3:2} ⋅e ⋅Ξ_S2__⎜───⎟   935⋅I_S__
#               ⎝2⎠                                            ⎝ 2 ⎠
# ───────────────── - ────────────────────────────────────────────── + ─────────
#                                           8
#
# 2                     3  3       ⎛5⋅n⎞             2                     3  3
#  ⋅\mathcal{A}_{1, 3:2} ⋅e ⋅Ξ_S2__⎜───⎟   1509⋅I_S__ ⋅\mathcal{A}_{1, 3:2} ⋅e ⋅
#                                  ⎝ 2 ⎠
# ────────────────────────────────────── - ─────────────────────────────────────
#              128                                               512
#
#       ⎛7⋅n⎞           2                     3  3       ⎛9⋅n⎞           2
# Ξ_S2__⎜───⎟   81⋅I_S__ ⋅\mathcal{A}_{1, 3:2} ⋅e ⋅Ξ_S2__⎜───⎟   21⋅I_S__ ⋅\math
#       ⎝ 2 ⎠                                            ⎝ 2 ⎠
# ─────────── + ────────────────────────────────────────────── - ───────────────
#                                    256
#
#                3         ⎛n⎞           2                     3         ⎛3⋅n⎞
# cal{A}_{1, 3:2} ⋅e⋅Ξ_S2__⎜─⎟   21⋅I_S__ ⋅\mathcal{A}_{1, 3:2} ⋅e⋅Ξ_S2__⎜───⎟
#                          ⎝2⎠                                           ⎝ 2 ⎠
# ──────────────────────────── + ───────────────────────────────────────────── -
#       64                                             32
#
#          2                     3         ⎛5⋅n⎞          2
#  15⋅I_S__ ⋅\mathcal{A}_{1, 3:2} ⋅e⋅Ξ_S2__⎜───⎟   9⋅I_S__ ⋅\mathcal{A}_{1, 3:2}
#                                          ⎝ 2 ⎠
#  ───────────────────────────────────────────── + ─────────────────────────────
#                        32                                             64
#
# 3         ⎛7⋅n⎞           2                     2  2       ⎛n⎞            2
#  ⋅e⋅Ξ_S2__⎜───⎟   21⋅I_S__ ⋅\mathcal{A}_{1, 3:2} ⋅e ⋅Ξ_S2__⎜─⎟   297⋅I_S__ ⋅\m
#           ⎝ 2 ⎠                                            ⎝2⎠
# ─────────────── + ──────────────────────────────────────────── - ─────────────
#                                        4
#
#                   2  2       ⎛3⋅n⎞           2                     2  2
# athcal{A}_{1, 3:2} ⋅e ⋅Ξ_S2__⎜───⎟   51⋅I_S__ ⋅\mathcal{A}_{1, 3:2} ⋅e ⋅Ξ_S2__
#                              ⎝ 2 ⎠
# ────────────────────────────────── + ─────────────────────────────────────────
#           32                                               16
#
# ⎛5⋅n⎞           2                     2  2       ⎛7⋅n⎞          2
# ⎜───⎟   27⋅I_S__ ⋅\mathcal{A}_{1, 3:2} ⋅e ⋅Ξ_S2__⎜───⎟   3⋅I_S__ ⋅\mathcal{A}_
# ⎝ 2 ⎠                                            ⎝ 2 ⎠
# ───── + ────────────────────────────────────────────── - ─────────────────────
#                               32                                             1
#
#         2       ⎛3⋅n⎞          2                     2       ⎛5⋅n⎞
# {1, 3:2} ⋅Ξ_S2__⎜───⎟   3⋅I_S__ ⋅\mathcal{A}_{1, 3:2} ⋅Ξ_S2__⎜───⎟   489⋅I_S__
#                 ⎝ 2 ⎠                                        ⎝ 2 ⎠
# ───────────────────── + ────────────────────────────────────────── - ─────────
# 6                                           16
#
# 2                       3       ⎛n⎞             2                       3
#  ⋅\mathcal{A}_{1, 3:2}⋅e ⋅Ξ_S2__⎜─⎟   2217⋅I_S__ ⋅\mathcal{A}_{1, 3:2}⋅e ⋅Ξ_S2
#                                 ⎝2⎠
# ─────────────────────────────────── + ────────────────────────────────────────
#             32                                               64
#
#   ⎛3⋅n⎞             2                       3       ⎛5⋅n⎞           2
# __⎜───⎟   1401⋅I_S__ ⋅\mathcal{A}_{1, 3:2}⋅e ⋅Ξ_S2__⎜───⎟   81⋅I_S__ ⋅\mathcal
#   ⎝ 2 ⎠                                             ⎝ 2 ⎠
# ─────── - ─────────────────────────────────────────────── + ──────────────────
#                                  64
#
#               3       ⎛7⋅n⎞          2                              ⎛n⎞
# {A}_{1, 3:2}⋅e ⋅Ξ_S2__⎜───⎟   3⋅I_S__ ⋅\mathcal{A}_{1, 3:2}⋅e⋅Ξ_S2__⎜─⎟   21⋅I
#                       ⎝ 2 ⎠                                         ⎝2⎠
# ─────────────────────────── + ───────────────────────────────────────── - ────
#     32                                            2
#
#     2                              ⎛3⋅n⎞          2
# _S__ ⋅\mathcal{A}_{1, 3:2}⋅e⋅Ξ_S2__⎜───⎟   9⋅I_S__ ⋅\mathcal{A}_{1, 3:2}⋅e⋅Ξ_S
#                                    ⎝ 2 ⎠
# ──────────────────────────────────────── + ───────────────────────────────────
#                  8                                              8
#
#    ⎛5⋅n⎞           2  2       ⎛n⎞            2  2       ⎛3⋅n⎞           2  2
# 2__⎜───⎟   15⋅I_S__ ⋅e ⋅Ξ_S2__⎜─⎟   183⋅I_S__ ⋅e ⋅Ξ_S2__⎜───⎟   27⋅I_S__ ⋅e ⋅Ξ
#    ⎝ 2 ⎠                      ⎝2⎠                       ⎝ 2 ⎠
# ──────── - ────────────────────── + ───────────────────────── + ──────────────
#                      8                          16                         16
#
#      ⎛5⋅n⎞          2       ⎛n⎞          2       ⎛3⋅n⎞
# _S2__⎜───⎟   3⋅I_S__ ⋅Ξ_S2__⎜─⎟   3⋅I_S__ ⋅Ξ_S2__⎜───⎟   ⎛        4
#      ⎝ 2 ⎠                  ⎝2⎠                  ⎝ 2 ⎠   ⎜63⋅I_S__ ⋅\mathcal{A
# ────────── + ────────────────── + ──────────────────── + ⎜────────────────────
#                      4                     4             ⎝               256
#
#
#           4  2           4                     3  3⎞               ⎛         4
# }_{1, 3:2} ⋅e    81⋅I_S__ ⋅\mathcal{A}_{1, 3:2} ⋅e ⎟               ⎜  9⋅I_S__
# ────────────── + ──────────────────────────────────⎟⋅Ξ_S2__(6⋅n) + ⎜- ────────
#                                 128                ⎠               ⎝
#
#
#                      4  2          4                     4           4
# ⋅\mathcal{A}_{1, 3:2} ⋅e    3⋅I_S__ ⋅\mathcal{A}_{1, 3:2}    81⋅I_S__ ⋅\mathca
# ───────────────────────── + ────────────────────────────── - ─────────────────
#         64                                64                                25
#
#
#              3  3          4                     3             4
# l{A}_{1, 3:2} ⋅e    9⋅I_S__ ⋅\mathcal{A}_{1, 3:2} ⋅e   27⋅I_S__ ⋅\mathcal{A}_{
# ───────────────── + ──────────────────────────────── + ───────────────────────
# 6                                  32                                  32
#
#
#        2  2           4                       3⎞               ⎛         4
# 1, 3:2} ⋅e    81⋅I_S__ ⋅\mathcal{A}_{1, 3:2}⋅e ⎟               ⎜137⋅I_S__ ⋅\ma
# ─────────── + ─────────────────────────────────⎟⋅Ξ_S2__(5⋅n) + ⎜──────────────
#                               64               ⎠               ⎝
#
#
#                  4  2           4                     3  3          4
# thcal{A}_{1, 3:2} ⋅e    27⋅I_S__ ⋅\mathcal{A}_{1, 3:2} ⋅e    9⋅I_S__ ⋅\mathcal
# ───────────────────── + ────────────────────────────────── - ─────────────────
#   512                                  256                                  32
#
#
#             3             4                     2  2          4
# {A}_{1, 3:2} ⋅e   45⋅I_S__ ⋅\mathcal{A}_{1, 3:2} ⋅e    3⋅I_S__ ⋅\mathcal{A}_{1
# ─────────────── - ────────────────────────────────── + ───────────────────────
#                                   64                                 16
#
#
#       2           4                       3          4
# , 3:2}    27⋅I_S__ ⋅\mathcal{A}_{1, 3:2}⋅e    9⋅I_S__ ⋅\mathcal{A}_{1, 3:2}⋅e
# ─────── + ───────────────────────────────── + ───────────────────────────────
#                          128                                 16
#
#
#           4  2          2                     4  2                         4
#   27⋅I_S__ ⋅e    3⋅I_S__ ⋅\mathcal{A}_{1, 3:2} ⋅e    3⋅\mathcal{A}_{1, 3:2} ⋅e
# + ──────────── - ───────────────────────────────── + ─────────────────────────
#        64                        64                              64
#
#
# 2⎞               ⎛           4                     4  2           4
#  ⎟               ⎜  175⋅I_S__ ⋅\mathcal{A}_{1, 3:2} ⋅e    35⋅I_S__ ⋅\mathcal{A
# ─⎟⋅Ξ_S2__(4⋅n) + ⎜- ─────────────────────────────────── + ────────────────────
#  ⎠               ⎝                  192                                 128
#
#
#           4            4                     3  3           4
# }_{1, 3:2}    231⋅I_S__ ⋅\mathcal{A}_{1, 3:2} ⋅e    11⋅I_S__ ⋅\mathcal{A}_{1,
# ─────────── + ─────────────────────────────────── - ──────────────────────────
#                               512                                   64
#
#
#     3             4                     2  2          4                     2
# 3:2} ⋅e   25⋅I_S__ ⋅\mathcal{A}_{1, 3:2} ⋅e    3⋅I_S__ ⋅\mathcal{A}_{1, 3:2}
# ─────── - ────────────────────────────────── - ──────────────────────────────
#                          128                                 8
#
#
#            4  2          4           2                     4  2          2
#   513⋅I_S__ ⋅e    3⋅I_S__    11⋅I_S__ ⋅\mathcal{A}_{1, 3:2} ⋅e    3⋅I_S__ ⋅\ma
# + ───────────── + ──────── + ────────────────────────────────── - ────────────
#        128           16                      8
#
#
#                  4           2                     3  3          2
# thcal{A}_{1, 3:2}    63⋅I_S__ ⋅\mathcal{A}_{1, 3:2} ⋅e    3⋅I_S__ ⋅\mathcal{A}
# ────────────────── - ────────────────────────────────── + ────────────────────
#   16                                 64                                  8
#
#
#          3            2                     2  2                          4  2
# _{1, 3:2} ⋅e   3⋅I_S__ ⋅\mathcal{A}_{1, 3:2} ⋅e    11⋅\mathcal{A}_{1, 3:2} ⋅e
# ──────────── - ───────────────────────────────── - ───────────────────────────
#                                16                               8
#
#
#                          4                          3  3
#    3⋅\mathcal{A}_{1, 3:2}    63⋅\mathcal{A}_{1, 3:2} ⋅e    3⋅\mathcal{A}_{1, 3
#  + ─────────────────────── + ─────────────────────────── - ───────────────────
#               16                          64                           8
#
#
#    3                           2  2⎞               ⎛          4
# :2} ⋅e   3⋅\mathcal{A}_{1, 3:2} ⋅e ⎟               ⎜1915⋅I_S__ ⋅\mathcal{A}_{1
# ────── + ──────────────────────────⎟⋅Ξ_S2__(3⋅n) + ⎜──────────────────────────
#                      16            ⎠               ⎝                384
#
#
#       4  2              4                     3  3            4
# , 3:2} ⋅e    26683⋅I_S__ ⋅\mathcal{A}_{1, 3:2} ⋅e    117⋅I_S__ ⋅\mathcal{A}_{1
# ────────── - ───────────────────────────────────── + ─────────────────────────
#                               1536                                   64
#
#
#       3              4                     2  2           4
# , 3:2} ⋅e   409⋅I_S__ ⋅\mathcal{A}_{1, 3:2} ⋅e    17⋅I_S__ ⋅\mathcal{A}_{1, 3:
# ───────── - ─────────────────────────────────── + ────────────────────────────
#                             128                                  32
#
#
#   2            4                       3           4
# 2}    177⋅I_S__ ⋅\mathcal{A}_{1, 3:2}⋅e    29⋅I_S__ ⋅\mathcal{A}_{1, 3:2}⋅e
# ─── + ────────────────────────────────── - ──────────────────────────────── -
#                      256                                  32
#
#
#          4  2          4            2                     4  2             2
# 115⋅I_S__ ⋅e    9⋅I_S__    331⋅I_S__ ⋅\mathcal{A}_{1, 3:2} ⋅e    2411⋅I_S__ ⋅\
# ───────────── + ──────── - ─────────────────────────────────── + ─────────────
#      128           32                       32
#
#
#                    3  3           2                     3             2
# mathcal{A}_{1, 3:2} ⋅e    27⋅I_S__ ⋅\mathcal{A}_{1, 3:2} ⋅e   87⋅I_S__ ⋅\mathc
# ─────────────────────── - ───────────────────────────────── + ────────────────
#     64                                    8
#
#
#               2  2          2                     2           2
# al{A}_{1, 3:2} ⋅e    3⋅I_S__ ⋅\mathcal{A}_{1, 3:2}    63⋅I_S__ ⋅\mathcal{A}_{1
# ────────────────── - ────────────────────────────── - ────────────────────────
# 16                                 4                                  32
#
#
#         3          2                                 2  2
# , 3:2}⋅e    3⋅I_S__ ⋅\mathcal{A}_{1, 3:2}⋅e   3⋅I_S__ ⋅e    331⋅\mathcal{A}_{1
# ───────── + ─────────────────────────────── - ─────────── + ──────────────────
#                            4                       16                    32
#
#
#       4  2                            3  3                          3
# , 3:2} ⋅e    2411⋅\mathcal{A}_{1, 3:2} ⋅e    27⋅\mathcal{A}_{1, 3:2} ⋅e   87⋅\
# ────────── - ───────────────────────────── + ────────────────────────── - ────
#                            64                            8
#
#
#                    2  2                         2                            3
# mathcal{A}_{1, 3:2} ⋅e    3⋅\mathcal{A}_{1, 3:2}    63⋅\mathcal{A}_{1, 3:2}⋅e
# ─────────────────────── + ─────────────────────── + ──────────────────────────
#          16                          4                          32
#
#
#                                  2⎞               ⎛          4
#    3⋅\mathcal{A}_{1, 3:2}⋅e   3⋅e ⎟               ⎜  25⋅I_S__ ⋅\mathcal{A}_{1,
#  - ──────────────────────── + ────⎟⋅Ξ_S2__(2⋅n) + ⎜- ─────────────────────────
#               4                16 ⎠               ⎝                  3
#
#
#      4  2           4                     4              4
#  3:2} ⋅e    61⋅I_S__ ⋅\mathcal{A}_{1, 3:2}    78025⋅I_S__ ⋅\mathcal{A}_{1, 3:2
# ───────── + ─────────────────────────────── + ────────────────────────────────
#                           128                                  1536
#
#
#  3  3            4                     3               4                     2
# } ⋅e    271⋅I_S__ ⋅\mathcal{A}_{1, 3:2} ⋅e   2539⋅I_S__ ⋅\mathcal{A}_{1, 3:2}
# ───── - ────────────────────────────────── + ─────────────────────────────────
#                         64                                   128
#
#
#   2           4                     2             4                       3
# ⋅e    11⋅I_S__ ⋅\mathcal{A}_{1, 3:2}    2171⋅I_S__ ⋅\mathcal{A}_{1, 3:2}⋅e
# ─── - ─────────────────────────────── - ─────────────────────────────────── +
#                      16                                  64
#
#
#         4                                   4  2           4            2
# 11⋅I_S__ ⋅\mathcal{A}_{1, 3:2}⋅e   257⋅I_S__ ⋅e    11⋅I_S__    143⋅I_S__ ⋅\mat
# ──────────────────────────────── + ───────────── + ───────── + ───────────────
#                4                        128            32
#
#
#                 4  2           2                     4             2
# hcal{A}_{1, 3:2} ⋅e    15⋅I_S__ ⋅\mathcal{A}_{1, 3:2}    7049⋅I_S__ ⋅\mathcal{
# ──────────────────── - ─────────────────────────────── - ─────────────────────
#   8                                   16                                  64
#
#
#            3  3           2                     3              2
# A}_{1, 3:2} ⋅e    69⋅I_S__ ⋅\mathcal{A}_{1, 3:2} ⋅e   663⋅I_S__ ⋅\mathcal{A}_{
# ─────────────── + ───────────────────────────────── - ────────────────────────
#                                   8                                    16
#
#
#        2  2          2                     2            2
# 1, 3:2} ⋅e    3⋅I_S__ ⋅\mathcal{A}_{1, 3:2}    285⋅I_S__ ⋅\mathcal{A}_{1, 3:2}
# ─────────── + ────────────────────────────── + ───────────────────────────────
#                             2                                  4
#
#
#   3                                            2  2          2
# ⋅e           2                          3⋅I_S__ ⋅e    3⋅I_S__    143⋅\mathcal{
# ─── - 6⋅I_S__ ⋅\mathcal{A}_{1, 3:2}⋅e + ─────────── - ──────── - ─────────────
#                                              8           4
#
#
#            4  2                          4                            3  3
# A}_{1, 3:2} ⋅e    15⋅\mathcal{A}_{1, 3:2}    7049⋅\mathcal{A}_{1, 3:2} ⋅e    6
# ─────────────── + ──────────────────────── + ───────────────────────────── - ─
# 8                            16                            64
#
#
#                       3                             2  2
# 9⋅\mathcal{A}_{1, 3:2} ⋅e   663⋅\mathcal{A}_{1, 3:2} ⋅e    3⋅\mathcal{A}_{1, 3
# ───────────────────────── + ──────────────────────────── - ───────────────────
#            8                             16                           2
#
#
#    2                             3                                  2    ⎞
# :2}    285⋅\mathcal{A}_{1, 3:2}⋅e                               21⋅e    3⎟
# ──── - ─────────────────────────── + 6⋅\mathcal{A}_{1, 3:2}⋅e - ───── + ─⎟⋅Ξ_S
#                     4                                             8     4⎠
#
#
#
#
# 2__(n)

# %%
lib_heating_gen = heating_S_LIB
lib_heating_gen = taylor(lib_heating_gen, eccentricity, 4).removeO()
lib_heating_gen = taylor(lib_heating_gen, lib_A, 5).removeO()
lib_heating_gen = taylor(lib_heating_gen, obliquity_sat, 5).removeO()
lib_gen = Symbol('\mathcal{A}_{1, gen}', real=True, positive=True)
lib_heating_gen = lib_heating_gen.subs(lib_A, lib_gen)
lib_heating_gen = expand(lib_heating_gen)

# %%
expr = lib_heating_gen

for mode, love_S in love_coeffs_sat_LIB.items():
    expr = collect(expr, love_S)
    
    
disp(expr)
# Out:
#            4                     4  2                                    4
#   173⋅I_S__ ⋅\mathcal{A}_{1, gen} ⋅e ⋅Ξ_S2__(\mathcal{z}⋅n + n)   3⋅I_S__ ⋅\ma
# - ───────────────────────────────────────────────────────────── + ────────────
#                                2048
#
#                  4  2                                       4
# thcal{A}_{1, gen} ⋅e ⋅Ξ_S2__(\mathcal{z}⋅n + 2⋅n)   21⋅I_S__ ⋅\mathcal{A}_{1,
# ───────────────────────────────────────────────── - ──────────────────────────
#                   64
#
#     4  2                                        4                     4  2
# gen} ⋅e ⋅Ξ_S2__(\mathcal{z}⋅n + 3⋅n)   137⋅I_S__ ⋅\mathcal{A}_{1, gen} ⋅e ⋅Ξ_S
# ──────────────────────────────────── + ───────────────────────────────────────
#    256                                                               512
#
#                                   4                     4  2
# 2__(2⋅\mathcal{z}⋅n + n)   9⋅I_S__ ⋅\mathcal{A}_{1, gen} ⋅e ⋅Ξ_S2__(2⋅\mathcal
# ──────────────────────── - ───────────────────────────────────────────────────
#                                                           64
#
#                        4                     4  2
# {z}⋅n + 2⋅n)   63⋅I_S__ ⋅\mathcal{A}_{1, gen} ⋅e ⋅Ξ_S2__(2⋅\mathcal{z}⋅n + 3⋅n
# ──────────── + ───────────────────────────────────────────────────────────────
#                                              256
#
#          4                     4                                      4
# )   I_S__ ⋅\mathcal{A}_{1, gen} ⋅Ξ_S2__(\mathcal{z}⋅n + 2⋅n)   3⋅I_S__ ⋅\mathc
# ─ - ──────────────────────────────────────────────────────── + ───────────────
#                                64
#
#               4                                        4                     3
# al{A}_{1, gen} ⋅Ξ_S2__(2⋅\mathcal{z}⋅n + 2⋅n)   9⋅I_S__ ⋅\mathcal{A}_{1, gen}
# ───────────────────────────────────────────── - ──────────────────────────────
#               64                                                            12
#
#   3                                     4                     3  3
# ⋅e ⋅Ξ_S2__(\mathcal{z}⋅n + n)   27⋅I_S__ ⋅\mathcal{A}_{1, gen} ⋅e ⋅Ξ_S2__(\mat
# ───────────────────────────── + ──────────────────────────────────────────────
# 8                                                            128
#
#                            4                     3  3
# hcal{z}⋅n + 2⋅n)   27⋅I_S__ ⋅\mathcal{A}_{1, gen} ⋅e ⋅Ξ_S2__(\mathcal{z}⋅n + 3
# ──────────────── - ───────────────────────────────────────────────────────────
#                                                  64
#
#               4                     3  3
# ⋅n)   27⋅I_S__ ⋅\mathcal{A}_{1, gen} ⋅e ⋅Ξ_S2__(2⋅\mathcal{z}⋅n + n)   81⋅I_S_
# ─── + ────────────────────────────────────────────────────────────── - ───────
#                                    256
#
#  4                     3  3                                         4
# _ ⋅\mathcal{A}_{1, gen} ⋅e ⋅Ξ_S2__(2⋅\mathcal{z}⋅n + 2⋅n)   81⋅I_S__ ⋅\mathcal
# ───────────────────────────────────────────────────────── + ──────────────────
#                        256
#
#             3  3                                        4
# {A}_{1, gen} ⋅e ⋅Ξ_S2__(2⋅\mathcal{z}⋅n + 3⋅n)   3⋅I_S__ ⋅\mathcal{A}_{1, gen}
# ────────────────────────────────────────────── + ─────────────────────────────
#             128                                                              1
#
# 3                                      4                     3
#  ⋅e⋅Ξ_S2__(\mathcal{z}⋅n + n)   3⋅I_S__ ⋅\mathcal{A}_{1, gen} ⋅e⋅Ξ_S2__(\mathc
# ───────────────────────────── - ──────────────────────────────────────────────
# 6                                                            16
#
#                         4                     3
# al{z}⋅n + 2⋅n)   9⋅I_S__ ⋅\mathcal{A}_{1, gen} ⋅e⋅Ξ_S2__(2⋅\mathcal{z}⋅n + n)
# ────────────── - ────────────────────────────────────────────────────────────
#                                               32
#
#          4                     3                                           4
#   9⋅I_S__ ⋅\mathcal{A}_{1, gen} ⋅e⋅Ξ_S2__(2⋅\mathcal{z}⋅n + 2⋅n)   15⋅I_S__ ⋅\
# + ────────────────────────────────────────────────────────────── + ───────────
#                                 32
#
#                    2  2                                    4
# mathcal{A}_{1, gen} ⋅e ⋅Ξ_S2__(\mathcal{z}⋅n + n)   9⋅I_S__ ⋅\mathcal{A}_{1, g
# ───────────────────────────────────────────────── - ──────────────────────────
#                   16
#
#    2  2                                       4                     2  2
# en} ⋅e ⋅Ξ_S2__(\mathcal{z}⋅n + 2⋅n)   45⋅I_S__ ⋅\mathcal{A}_{1, gen} ⋅e ⋅Ξ_S2_
# ─────────────────────────────────── - ────────────────────────────────────────
#     8                                                               64
#
#                                  4                     2  2
# _(2⋅\mathcal{z}⋅n + n)   27⋅I_S__ ⋅\mathcal{A}_{1, gen} ⋅e ⋅Ξ_S2__(2⋅\mathcal{
# ────────────────────── + ─────────────────────────────────────────────────────
#                                                         32
#
#                    4                     2
# z}⋅n + 2⋅n)   I_S__ ⋅\mathcal{A}_{1, gen} ⋅Ξ_S2__(\mathcal{z}⋅n + n)   3⋅I_S__
# ─────────── - ────────────────────────────────────────────────────── + ───────
#                                         4
#
# 4                     2                                      4
#  ⋅\mathcal{A}_{1, gen} ⋅Ξ_S2__(2⋅\mathcal{z}⋅n + n)   9⋅I_S__ ⋅\mathcal{A}_{1,
# ─────────────────────────────────────────────────── - ────────────────────────
#                      16
#
#        3                                     4                       3
#  gen}⋅e ⋅Ξ_S2__(\mathcal{z}⋅n + n)   27⋅I_S__ ⋅\mathcal{A}_{1, gen}⋅e ⋅Ξ_S2__(
# ────────────────────────────────── - ─────────────────────────────────────────
#     16                                                             8
#
#                                4                       3
# \mathcal{z}⋅n + 2⋅n)   27⋅I_S__ ⋅\mathcal{A}_{1, gen}⋅e ⋅Ξ_S2__(2⋅\mathcal{z}⋅
# ──────────────────── + ───────────────────────────────────────────────────────
#                                                     128
#
#                  4                       3
# n + n)   81⋅I_S__ ⋅\mathcal{A}_{1, gen}⋅e ⋅Ξ_S2__(2⋅\mathcal{z}⋅n + 2⋅n)   3⋅I
# ────── + ─────────────────────────────────────────────────────────────── - ───
#                                         64
#
#     4                                                           4
# _S__ ⋅\mathcal{A}_{1, gen}⋅e⋅Ξ_S2__(\mathcal{z}⋅n + n)   9⋅I_S__ ⋅\mathcal{A}_
# ────────────────────────────────────────────────────── + ─────────────────────
#                          2
#
#                                                   4  2                      4
# {1, gen}⋅e⋅Ξ_S2__(2⋅\mathcal{z}⋅n + n)   441⋅I_S__ ⋅e ⋅Ξ_S2__(3⋅n)   9⋅I_S__ ⋅
# ────────────────────────────────────── + ───────────────────────── - ─────────
#         16                                          128
#
#  2                                     4  2
# e ⋅Ξ_S2__(\mathcal{z}⋅n + n)   27⋅I_S__ ⋅e ⋅Ξ_S2__(2⋅\mathcal{z}⋅n + n)   33⋅I
# ──────────────────────────── + ──────────────────────────────────────── + ────
#          4                                        64
#
#     2                     4  2                                    2
# _S__ ⋅\mathcal{A}_{1, gen} ⋅e ⋅Ξ_S2__(\mathcal{z}⋅n + n)   9⋅I_S__ ⋅\mathcal{A
# ──────────────────────────────────────────────────────── - ───────────────────
#                         512
#
#           4  2                                       2                     4
# }_{1, gen} ⋅e ⋅Ξ_S2__(\mathcal{z}⋅n + 2⋅n)   63⋅I_S__ ⋅\mathcal{A}_{1, gen} ⋅e
# ────────────────────────────────────────── + ─────────────────────────────────
#           256                                                             1024
#
# 2                                      2                     4  2
#  ⋅Ξ_S2__(\mathcal{z}⋅n + 3⋅n)   3⋅I_S__ ⋅\mathcal{A}_{1, gen} ⋅e ⋅Ξ_S2__(2⋅\ma
# ───────────────────────────── - ──────────────────────────────────────────────
#                                                               64
#
#                          2                     4
# thcal{z}⋅n + n)   3⋅I_S__ ⋅\mathcal{A}_{1, gen} ⋅Ξ_S2__(\mathcal{z}⋅n + 2⋅n)
# ─────────────── + ────────────────────────────────────────────────────────── +
#                                              256
#
#          2                     3  3                                     2
#  27⋅I_S__ ⋅\mathcal{A}_{1, gen} ⋅e ⋅Ξ_S2__(\mathcal{z}⋅n + n)   81⋅I_S__ ⋅\mat
#  ──────────────────────────────────────────────────────────── - ──────────────
#                              512
#
#                 3  3                                       2
# hcal{A}_{1, gen} ⋅e ⋅Ξ_S2__(\mathcal{z}⋅n + 2⋅n)   81⋅I_S__ ⋅\mathcal{A}_{1, g
# ──────────────────────────────────────────────── + ───────────────────────────
#                512
#
#    3  3                                      2                     3
# en} ⋅e ⋅Ξ_S2__(\mathcal{z}⋅n + 3⋅n)   9⋅I_S__ ⋅\mathcal{A}_{1, gen} ⋅e⋅Ξ_S2__(
# ─────────────────────────────────── - ────────────────────────────────────────
#   256                                                             64
#
#                             2                     3
# \mathcal{z}⋅n + n)   9⋅I_S__ ⋅\mathcal{A}_{1, gen} ⋅e⋅Ξ_S2__(\mathcal{z}⋅n + 2
# ────────────────── + ─────────────────────────────────────────────────────────
#                                                   64
#
#               2                     2  2                                     2
# ⋅n)   45⋅I_S__ ⋅\mathcal{A}_{1, gen} ⋅e ⋅Ξ_S2__(\mathcal{z}⋅n + n)   27⋅I_S__
# ─── - ──────────────────────────────────────────────────────────── + ─────────
#                                    64
#
#                      2  2                                      2
# ⋅\mathcal{A}_{1, gen} ⋅e ⋅Ξ_S2__(\mathcal{z}⋅n + 2⋅n)   3⋅I_S__ ⋅\mathcal{A}_{
# ───────────────────────────────────────────────────── + ──────────────────────
#                      32
#
#        2                                     2                       3
# 1, gen} ⋅Ξ_S2__(\mathcal{z}⋅n + n)   27⋅I_S__ ⋅\mathcal{A}_{1, gen}⋅e ⋅Ξ_S2__(
# ────────────────────────────────── + ─────────────────────────────────────────
#      16                                                           64
#
#                              2                       3
# \mathcal{z}⋅n + n)   81⋅I_S__ ⋅\mathcal{A}_{1, gen}⋅e ⋅Ξ_S2__(\mathcal{z}⋅n +
# ────────────────── + ─────────────────────────────────────────────────────────
#                                                    32
#
#               2                                                            2
# 2⋅n)   9⋅I_S__ ⋅\mathcal{A}_{1, gen}⋅e⋅Ξ_S2__(\mathcal{z}⋅n + n)   27⋅I_S__ ⋅e
# ──── + ───────────────────────────────────────────────────────── + ───────────
#                                    8
#
# 2                                                   4  2
#  ⋅Ξ_S2__(\mathcal{z}⋅n + n)   3⋅\mathcal{A}_{1, gen} ⋅e ⋅Ξ_S2__(2⋅\mathcal{z}⋅
# ─────────────────────────── + ────────────────────────────────────────────────
#        16                                               64
#
#          ⎛          4  2          4⎞               ⎛         4  2           2
# n + n)   ⎜  45⋅I_S__ ⋅e    9⋅I_S__ ⎟               ⎜477⋅I_S__ ⋅e    27⋅I_S__ ⋅
# ────── + ⎜- ──────────── + ────────⎟⋅Ξ_S2__(2⋅n) + ⎜───────────── - ──────────
#          ⎝       32           32   ⎠               ⎝     128             8
#
#  2      2⎞             ⎛            4                     4  2            4
# e    9⋅e ⎟             ⎜  1415⋅I_S__ ⋅\mathcal{A}_{1, gen} ⋅e    595⋅I_S__ ⋅\m
# ── + ────⎟⋅Ξ_S2__(n) + ⎜- ──────────────────────────────────── + ─────────────
#       8  ⎠             ⎝                  6144
#
#                   3  3            2                     4  2            2
# athcal{A}_{1, gen} ⋅e    283⋅I_S__ ⋅\mathcal{A}_{1, gen} ⋅e    357⋅I_S__ ⋅\mat
# ────────────────────── + ─────────────────────────────────── - ───────────────
#    256                                   1024
#
#                 3  3⎞                               ⎛          4
# hcal{A}_{1, gen} ⋅e ⎟                               ⎜3113⋅I_S__ ⋅\mathcal{A}_{
# ────────────────────⎟⋅Ξ_S2__(n⋅│\mathcal{z} - 5│) + ⎜─────────────────────────
#  128                ⎠                               ⎝                1536
#
#        4  2             4                     3  3            2
# 1, gen} ⋅e    1309⋅I_S__ ⋅\mathcal{A}_{1, gen} ⋅e    283⋅I_S__ ⋅\mathcal{A}_{1
# ─────────── - ──────────────────────────────────── - ─────────────────────────
#                               128                                     64
#
#       4  2            2                     3  3                           4
# , gen} ⋅e    357⋅I_S__ ⋅\mathcal{A}_{1, gen} ⋅e    283⋅\mathcal{A}_{1, gen} ⋅e
# ────────── + ─────────────────────────────────── + ───────────────────────────
#                               16                                64
#
# 2                           3  3⎞                                 ⎛         4
#     357⋅\mathcal{A}_{1, gen} ⋅e ⎟                                 ⎜155⋅I_S__ ⋅
# ─ - ────────────────────────────⎟⋅Ξ_S2__(n⋅│2⋅\mathcal{z} - 5│) + ⎜───────────
#                  16             ⎠                                 ⎝
#
#                     4  2          4                     4              4
# \mathcal{A}_{1, gen} ⋅e    5⋅I_S__ ⋅\mathcal{A}_{1, gen}    18565⋅I_S__ ⋅\math
# ──────────────────────── - ────────────────────────────── - ──────────────────
#      384                                512                                  3
#
#                3  3           4                     3              4
# cal{A}_{1, gen} ⋅e    35⋅I_S__ ⋅\mathcal{A}_{1, gen} ⋅e   415⋅I_S__ ⋅\mathcal{
# ─────────────────── + ───────────────────────────────── - ────────────────────
# 072                                  128                                  128
#
#            2  2            4                       3           2
# A}_{1, gen} ⋅e    595⋅I_S__ ⋅\mathcal{A}_{1, gen}⋅e    31⋅I_S__ ⋅\mathcal{A}_{
# ─────────────── + ────────────────────────────────── - ───────────────────────
#                                   32                                   64
#
#        4  2          2                     4             2
# 1, gen} ⋅e    3⋅I_S__ ⋅\mathcal{A}_{1, gen}    3713⋅I_S__ ⋅\mathcal{A}_{1, gen
# ─────────── + ────────────────────────────── + ───────────────────────────────
#                            256                                 512
#
#  3  3           2                     3              2                     2
# } ⋅e    21⋅I_S__ ⋅\mathcal{A}_{1, gen} ⋅e   249⋅I_S__ ⋅\mathcal{A}_{1, gen} ⋅e
# ───── - ───────────────────────────────── + ──────────────────────────────────
#                         64                                   64
#
# 2            2                       3⎞                               ⎛
#     357⋅I_S__ ⋅\mathcal{A}_{1, gen}⋅e ⎟                               ⎜  1293⋅
# ─ - ──────────────────────────────────⎟⋅Ξ_S2__(n⋅│\mathcal{z} - 4│) + ⎜- ─────
#                     16                ⎠                               ⎝
#
#      4                     4  2             4                     3  3
# I_S__ ⋅\mathcal{A}_{1, gen} ⋅e    8267⋅I_S__ ⋅\mathcal{A}_{1, gen} ⋅e    75⋅I_
# ─────────────────────────────── + ──────────────────────────────────── - ─────
#            2048                                   1024
#
#    4                     3              4                     2  2          4
# S__ ⋅\mathcal{A}_{1, gen} ⋅e   965⋅I_S__ ⋅\mathcal{A}_{1, gen} ⋅e    5⋅I_S__ ⋅
# ──────────────────────────── + ─────────────────────────────────── - ─────────
#           128                                  128
#
#                     2             4                       3           4
# \mathcal{A}_{1, gen}    3695⋅I_S__ ⋅\mathcal{A}_{1, gen}⋅e    35⋅I_S__ ⋅\mathc
# ───────────────────── - ─────────────────────────────────── + ────────────────
#      32                                 128                                  1
#
#                             4  2            2                     4  2
# al{A}_{1, gen}⋅e   245⋅I_S__ ⋅e    369⋅I_S__ ⋅\mathcal{A}_{1, gen} ⋅e    4863⋅
# ──────────────── - ───────────── + ─────────────────────────────────── - ─────
# 6                        32                        512
#
#      2                     3  3           2                     3
# I_S__ ⋅\mathcal{A}_{1, gen} ⋅e    45⋅I_S__ ⋅\mathcal{A}_{1, gen} ⋅e   579⋅I_S_
# ─────────────────────────────── + ───────────────────────────────── - ────────
#            512                                    64
#
#  2                     2  2          2                     2             2
# _ ⋅\mathcal{A}_{1, gen} ⋅e    3⋅I_S__ ⋅\mathcal{A}_{1, gen}    2217⋅I_S__ ⋅\ma
# ─────────────────────────── + ────────────────────────────── + ───────────────
#          64                                 16
#
#                    3           2                                   2  2⎞
# thcal{A}_{1, gen}⋅e    21⋅I_S__ ⋅\mathcal{A}_{1, gen}⋅e   147⋅I_S__ ⋅e ⎟
# ──────────────────── - ──────────────────────────────── + ─────────────⎟⋅Ξ_S2_
#   64                                  8                         16     ⎠
#
#                          ⎛            4                     4  2             4
#                          ⎜  2399⋅I_S__ ⋅\mathcal{A}_{1, gen} ⋅e    5131⋅I_S__
# _(n⋅│\mathcal{z} - 3│) + ⎜- ──────────────────────────────────── + ───────────
#                          ⎝                  6144
#
#                      3  3           4                     3              4
# ⋅\mathcal{A}_{1, gen} ⋅e    69⋅I_S__ ⋅\mathcal{A}_{1, gen} ⋅e   265⋅I_S__ ⋅\ma
# ───────────────────────── - ───────────────────────────────── + ──────────────
#      3072                                  128
#
#                  2  2           4                     2           4
# thcal{A}_{1, gen} ⋅e    13⋅I_S__ ⋅\mathcal{A}_{1, gen}    33⋅I_S__ ⋅\mathcal{A
# ───────────────────── - ─────────────────────────────── - ────────────────────
#   128                                  32                                128
#
#             3           4                                  4  2            2
# }_{1, gen}⋅e    29⋅I_S__ ⋅\mathcal{A}_{1, gen}⋅e   77⋅I_S__ ⋅e    221⋅I_S__ ⋅\
# ───────────── + ──────────────────────────────── - ──────────── + ────────────
#                                16                       32
#
#                    4  2            2                     3  3          2
# mathcal{A}_{1, gen} ⋅e    505⋅I_S__ ⋅\mathcal{A}_{1, gen} ⋅e    9⋅I_S__ ⋅\math
# ─────────────────────── - ─────────────────────────────────── + ──────────────
#     512                                   256
#
#                3             2                     2  2          2
# cal{A}_{1, gen} ⋅e   33⋅I_S__ ⋅\mathcal{A}_{1, gen} ⋅e    3⋅I_S__ ⋅\mathcal{A}
# ────────────────── - ────────────────────────────────── + ────────────────────
#  16                                  16                                 8
#
#          2          2                       3          2
# _{1, gen}    9⋅I_S__ ⋅\mathcal{A}_{1, gen}⋅e    3⋅I_S__ ⋅\mathcal{A}_{1, gen}⋅
# ────────── + ──────────────────────────────── - ──────────────────────────────
#                             16                                 2
#
#             2  2⎞                               ⎛         4
# e   15⋅I_S__ ⋅e ⎟                               ⎜127⋅I_S__ ⋅\mathcal{A}_{1, ge
# ─ + ────────────⎟⋅Ξ_S2__(n⋅│\mathcal{z} - 1│) + ⎜─────────────────────────────
#          8      ⎠                               ⎝                768
#
#   4  2           4                     4            4                     3  3
# n} ⋅e    37⋅I_S__ ⋅\mathcal{A}_{1, gen}    105⋅I_S__ ⋅\mathcal{A}_{1, gen} ⋅e
# ────── - ─────────────────────────────── - ───────────────────────────────────
#                        512                                 1024
#
#           4                     3             4                     2  2
#    5⋅I_S__ ⋅\mathcal{A}_{1, gen} ⋅e   43⋅I_S__ ⋅\mathcal{A}_{1, gen} ⋅e    I_S
#  + ──────────────────────────────── + ────────────────────────────────── + ───
#                  128                                 128
#
#   4                     2                                 2
# __ ⋅\mathcal{A}_{1, gen}           4  2        4   5⋅I_S__ ⋅\mathcal{A}_{1, ge
# ───────────────────────── - 3⋅I_S__ ⋅e  - I_S__  - ───────────────────────────
#           2                                                        32
#
#   4  2           2                     4           2                     3  3
# n} ⋅e    15⋅I_S__ ⋅\mathcal{A}_{1, gen}    63⋅I_S__ ⋅\mathcal{A}_{1, gen} ⋅e
# ────── + ─────────────────────────────── + ──────────────────────────────────
#                        256                                512
#
#          2                     3             2                     2  2
#   3⋅I_S__ ⋅\mathcal{A}_{1, gen} ⋅e   15⋅I_S__ ⋅\mathcal{A}_{1, gen} ⋅e    3⋅I_
# - ──────────────────────────────── - ────────────────────────────────── - ────
#                  64                                  64
#
#    2                     2          2  2          2⎞                         ⎛
# S__ ⋅\mathcal{A}_{1, gen}    9⋅I_S__ ⋅e    3⋅I_S__ ⎟                         ⎜
# ────────────────────────── + ─────────── + ────────⎟⋅Ξ_S2__(\mathcal{z}⋅n) + ⎜
#           8                       4           4    ⎠                         ⎝
#
#            4                     4  2           4                     4
#   341⋅I_S__ ⋅\mathcal{A}_{1, gen} ⋅e    11⋅I_S__ ⋅\mathcal{A}_{1, gen}    4084
# - ─────────────────────────────────── + ─────────────────────────────── + ────
#                    96                                 128
#
#        4                     3  3           4                     3
# 3⋅I_S__ ⋅\mathcal{A}_{1, gen} ⋅e    77⋅I_S__ ⋅\mathcal{A}_{1, gen} ⋅e   913⋅I_
# ───────────────────────────────── - ───────────────────────────────── + ──────
#              1536                                   64
#
#    4                     2  2             4                       3
# S__ ⋅\mathcal{A}_{1, gen} ⋅e    1309⋅I_S__ ⋅\mathcal{A}_{1, gen}⋅e    31⋅I_S__
# ───────────────────────────── - ─────────────────────────────────── + ────────
#           128                                    64
#
# 2                     4  2          2                     4             2
#  ⋅\mathcal{A}_{1, gen} ⋅e    3⋅I_S__ ⋅\mathcal{A}_{1, gen}    3713⋅I_S__ ⋅\mat
# ────────────────────────── - ────────────────────────────── - ────────────────
#         4                                  16
#
#                 3  3           2                     3              2
# hcal{A}_{1, gen} ⋅e    21⋅I_S__ ⋅\mathcal{A}_{1, gen} ⋅e   249⋅I_S__ ⋅\mathcal
# ──────────────────── + ───────────────────────────────── - ───────────────────
#  64                                    8                                    16
#
#             2  2            2                       3
# {A}_{1, gen} ⋅e    357⋅I_S__ ⋅\mathcal{A}_{1, gen}⋅e    31⋅\mathcal{A}_{1, gen
# ──────────────── + ────────────────────────────────── - ──────────────────────
#                                    8                                 4
#
#  4  2                         4                            3  3
# } ⋅e    3⋅\mathcal{A}_{1, gen}    3713⋅\mathcal{A}_{1, gen} ⋅e    21⋅\mathcal{
# ───── + ─────────────────────── + ───────────────────────────── - ────────────
#                    16                           64
#
#            3                             2  2                             3⎞
# A}_{1, gen} ⋅e   249⋅\mathcal{A}_{1, gen} ⋅e    357⋅\mathcal{A}_{1, gen}⋅e ⎟
# ────────────── + ──────────────────────────── - ───────────────────────────⎟⋅Ξ
# 8                             16                             8             ⎠
#
#                                ⎛           4                     4  2
#                                ⎜  175⋅I_S__ ⋅\mathcal{A}_{1, gen} ⋅e    35⋅I_S
# _S2__(n⋅│2⋅\mathcal{z} - 4│) + ⎜- ─────────────────────────────────── + ──────
#                                ⎝                  192
#
#   4                     4            4                     3  3           4
# __ ⋅\mathcal{A}_{1, gen}    231⋅I_S__ ⋅\mathcal{A}_{1, gen} ⋅e    11⋅I_S__ ⋅\m
# ───────────────────────── + ─────────────────────────────────── - ────────────
#         128                                 512
#
#                   3             4                     2  2          4
# athcal{A}_{1, gen} ⋅e   25⋅I_S__ ⋅\mathcal{A}_{1, gen} ⋅e    3⋅I_S__ ⋅\mathcal
# ───────────────────── - ────────────────────────────────── - ─────────────────
#     64                                 128                                 8
#
#             2          4  2          4           2                     4  2
# {A}_{1, gen}    9⋅I_S__ ⋅e    3⋅I_S__    11⋅I_S__ ⋅\mathcal{A}_{1, gen} ⋅e
# ───────────── + ─────────── + ──────── + ────────────────────────────────── -
#                      16          16                      8
#
#        2                     4           2                     3  3          2
# 3⋅I_S__ ⋅\mathcal{A}_{1, gen}    63⋅I_S__ ⋅\mathcal{A}_{1, gen} ⋅e    3⋅I_S__
# ────────────────────────────── - ────────────────────────────────── + ────────
#               16                                 64
#
#                      3            2                     2  2
# ⋅\mathcal{A}_{1, gen} ⋅e   3⋅I_S__ ⋅\mathcal{A}_{1, gen} ⋅e    11⋅\mathcal{A}_
# ──────────────────────── - ───────────────────────────────── - ───────────────
#        8                                   16                               8
#
#         4  2                         4                          3  3
# {1, gen} ⋅e    3⋅\mathcal{A}_{1, gen}    63⋅\mathcal{A}_{1, gen} ⋅e    3⋅\math
# ──────────── + ─────────────────────── + ─────────────────────────── - ───────
#                           16                          64
#
#                3                           2  2⎞                           ⎛
# cal{A}_{1, gen} ⋅e   3⋅\mathcal{A}_{1, gen} ⋅e ⎟                           ⎜14
# ────────────────── + ──────────────────────────⎟⋅Ξ_S2__(2⋅\mathcal{z}⋅n) + ⎜──
#      8                           16            ⎠                           ⎝
#
#        4                     4  2          4                     4
# 7⋅I_S__ ⋅\mathcal{A}_{1, gen} ⋅e    7⋅I_S__ ⋅\mathcal{A}_{1, gen}    361⋅I_S__
# ───────────────────────────────── - ────────────────────────────── - ─────────
#               256                                128
#
# 4                     3  3           4                     3              4
#  ⋅\mathcal{A}_{1, gen} ⋅e    13⋅I_S__ ⋅\mathcal{A}_{1, gen} ⋅e   417⋅I_S__ ⋅\m
# ────────────────────────── + ───────────────────────────────── - ─────────────
#         64                                   16
#
#                   2  2          4                     2            4
# athcal{A}_{1, gen} ⋅e    5⋅I_S__ ⋅\mathcal{A}_{1, gen}    463⋅I_S__ ⋅\mathcal{
# ────────────────────── + ────────────────────────────── + ────────────────────
#     64                                 16                                 32
#
#              3          4                                  4  2          4
# A}_{1, gen}⋅e    5⋅I_S__ ⋅\mathcal{A}_{1, gen}⋅e   25⋅I_S__ ⋅e    5⋅I_S__    1
# ────────────── - ─────────────────────────────── + ──────────── - ──────── - ─
#                                 2                       8            8
#
#         2                     4  2           2                     4
# 71⋅I_S__ ⋅\mathcal{A}_{1, gen} ⋅e    15⋅I_S__ ⋅\mathcal{A}_{1, gen}    3417⋅I_
# ────────────────────────────────── + ─────────────────────────────── + ───────
#                256                                 256
#
#    2                     3  3           2                     3              2
# S__ ⋅\mathcal{A}_{1, gen} ⋅e    57⋅I_S__ ⋅\mathcal{A}_{1, gen} ⋅e   117⋅I_S__
# ───────────────────────────── - ───────────────────────────────── + ──────────
#          512                                    64
#
#                      2  2          2                     2            2
# ⋅\mathcal{A}_{1, gen} ⋅e    3⋅I_S__ ⋅\mathcal{A}_{1, gen}    507⋅I_S__ ⋅\mathc
# ───────────────────────── - ────────────────────────────── - ─────────────────
#        16                                 8                                  3
#
#                 3                                             2  2          2⎞
# al{A}_{1, gen}⋅e           2                          15⋅I_S__ ⋅e    3⋅I_S__ ⎟
# ───────────────── + 3⋅I_S__ ⋅\mathcal{A}_{1, gen}⋅e - ──────────── + ────────⎟
# 2                                                          4            4    ⎠
#
#                                ⎛          4                     4  2
#                                ⎜4547⋅I_S__ ⋅\mathcal{A}_{1, gen} ⋅e    10975⋅I
# ⋅Ξ_S2__(n⋅│\mathcal{z} - 2│) + ⎜──────────────────────────────────── - ───────
#                                ⎝                1536
#
#     4                     3  3            4                     3
# _S__ ⋅\mathcal{A}_{1, gen} ⋅e    117⋅I_S__ ⋅\mathcal{A}_{1, gen} ⋅e   409⋅I_S_
# ────────────────────────────── + ────────────────────────────────── - ────────
#           1536                                   64
#
#  4                     2  2           4                     2            4
# _ ⋅\mathcal{A}_{1, gen} ⋅e    17⋅I_S__ ⋅\mathcal{A}_{1, gen}    177⋅I_S__ ⋅\ma
# ─────────────────────────── + ─────────────────────────────── + ──────────────
#         128                                  32
#
#                    3           4                                  4  2
# thcal{A}_{1, gen}⋅e    29⋅I_S__ ⋅\mathcal{A}_{1, gen}⋅e   65⋅I_S__ ⋅e    379⋅I
# ──────────────────── - ──────────────────────────────── + ──────────── - ─────
#  256                                  32                      128
#
#     2                     4  2            2                     3  3
# _S__ ⋅\mathcal{A}_{1, gen} ⋅e    983⋅I_S__ ⋅\mathcal{A}_{1, gen} ⋅e    27⋅I_S_
# ────────────────────────────── + ─────────────────────────────────── - ───────
#             64                                    64
#
#  2                     3             2                     2  2          2
# _ ⋅\mathcal{A}_{1, gen} ⋅e   87⋅I_S__ ⋅\mathcal{A}_{1, gen} ⋅e    3⋅I_S__ ⋅\ma
# ────────────────────────── + ────────────────────────────────── - ────────────
#          8                                   16
#
#                  2           2                       3          2
# thcal{A}_{1, gen}    63⋅I_S__ ⋅\mathcal{A}_{1, gen}⋅e    3⋅I_S__ ⋅\mathcal{A}_
# ────────────────── - ───────────────────────────────── + ─────────────────────
#   4                                  32                                 4
#
#                     2  2                           4  2
# {1, gen}⋅e   3⋅I_S__ ⋅e    379⋅\mathcal{A}_{1, gen} ⋅e    983⋅\mathcal{A}_{1,
# ────────── - ─────────── + ──────────────────────────── - ────────────────────
#                   16                    64                             64
#
#     3  3                          3                            2  2
# gen} ⋅e    27⋅\mathcal{A}_{1, gen} ⋅e   87⋅\mathcal{A}_{1, gen} ⋅e    3⋅\mathc
# ──────── + ────────────────────────── - ─────────────────────────── + ────────
#                        8                             16
#
#               2                            3                                 2
# al{A}_{1, gen}    63⋅\mathcal{A}_{1, gen}⋅e    3⋅\mathcal{A}_{1, gen}⋅e   3⋅e
# ─────────────── + ────────────────────────── - ──────────────────────── + ────
#    4                          32                          4                16
#
# ⎞                                 ⎛          4                     4  2
# ⎟                                 ⎜2601⋅I_S__ ⋅\mathcal{A}_{1, gen} ⋅e    1756
# ⎟⋅Ξ_S2__(n⋅│2⋅\mathcal{z} - 1│) + ⎜──────────────────────────────────── - ────
# ⎠                                 ⎝                512
#
#        4                     3  3            4                     3
# 1⋅I_S__ ⋅\mathcal{A}_{1, gen} ⋅e    165⋅I_S__ ⋅\mathcal{A}_{1, gen} ⋅e   2123⋅
# ───────────────────────────────── + ────────────────────────────────── - ─────
#              512                                    64
#
#      4                     2  2           4                     2
# I_S__ ⋅\mathcal{A}_{1, gen} ⋅e    11⋅I_S__ ⋅\mathcal{A}_{1, gen}    8129⋅I_S__
# ─────────────────────────────── + ─────────────────────────────── + ──────────
#            128                                   32
#
# 4                       3           4                                   4  2
#  ⋅\mathcal{A}_{1, gen}⋅e    77⋅I_S__ ⋅\mathcal{A}_{1, gen}⋅e   539⋅I_S__ ⋅e
# ───────────────────────── - ──────────────────────────────── + ───────────── -
#       256                                  32                       128
#
#           2                     4  2             2                     3  3
#  675⋅I_S__ ⋅\mathcal{A}_{1, gen} ⋅e    4701⋅I_S__ ⋅\mathcal{A}_{1, gen} ⋅e
#  ─────────────────────────────────── + ──────────────────────────────────── -
#                   64                                    64
#
#         2                     3              2                     2  2
# 45⋅I_S__ ⋅\mathcal{A}_{1, gen} ⋅e   579⋅I_S__ ⋅\mathcal{A}_{1, gen} ⋅e    3⋅I_
# ───────────────────────────────── + ─────────────────────────────────── - ────
#                 8                                    16
#
#    2                     2             2                       3           2
# S__ ⋅\mathcal{A}_{1, gen}    2217⋅I_S__ ⋅\mathcal{A}_{1, gen}⋅e    21⋅I_S__ ⋅\
# ────────────────────────── - ─────────────────────────────────── + ───────────
#           4                                   32
#
#                                  2  2                           4  2
# mathcal{A}_{1, gen}⋅e   147⋅I_S__ ⋅e    675⋅\mathcal{A}_{1, gen} ⋅e    4701⋅\m
# ───────────────────── - ───────────── + ──────────────────────────── - ───────
#     4                         16                     64
#
#                   3  3                          3
# athcal{A}_{1, gen} ⋅e    45⋅\mathcal{A}_{1, gen} ⋅e   579⋅\mathcal{A}_{1, gen}
# ────────────────────── + ────────────────────────── - ────────────────────────
#        64                            8                             16
#
# 2  2                         2                              3
#  ⋅e    3⋅\mathcal{A}_{1, gen}    2217⋅\mathcal{A}_{1, gen}⋅e    21⋅\mathcal{A}
# ──── + ─────────────────────── + ──────────────────────────── - ──────────────
#                   4                           32                            4
#
#                    2⎞                                 ⎛           4
# _{1, gen}⋅e   147⋅e ⎟                                 ⎜  153⋅I_S__ ⋅\mathcal{A
# ─────────── + ──────⎟⋅Ξ_S2__(n⋅│2⋅\mathcal{z} - 3│) + ⎜- ─────────────────────
#                 16  ⎠                                 ⎝                   32
#
#           4  2           4                     4             4
# }_{1, gen} ⋅e    25⋅I_S__ ⋅\mathcal{A}_{1, gen}    6197⋅I_S__ ⋅\mathcal{A}_{1,
# ────────────── + ─────────────────────────────── + ───────────────────────────
#                                 64                                 256
#
#      3  3           4                     3              4
#  gen} ⋅e    97⋅I_S__ ⋅\mathcal{A}_{1, gen} ⋅e   813⋅I_S__ ⋅\mathcal{A}_{1, gen
# ───────── - ───────────────────────────────── + ──────────────────────────────
#                             32                                   64
#
#  2  2           4                     2            4                       3
# } ⋅e    11⋅I_S__ ⋅\mathcal{A}_{1, gen}    431⋅I_S__ ⋅\mathcal{A}_{1, gen}⋅e
# ───── - ─────────────────────────────── - ────────────────────────────────── +
#                        16                                 32
#
#          4                                  4  2           4           2
#  11⋅I_S__ ⋅\mathcal{A}_{1, gen}⋅e   55⋅I_S__ ⋅e    11⋅I_S__    81⋅I_S__ ⋅\math
#  ──────────────────────────────── - ──────────── + ───────── + ───────────────
#                 4                        32            32
#
#                4  2          2                     4            2
# cal{A}_{1, gen} ⋅e    3⋅I_S__ ⋅\mathcal{A}_{1, gen}    417⋅I_S__ ⋅\mathcal{A}_
# ─────────────────── - ────────────────────────────── - ───────────────────────
#  8                                  4                                   8
#
#         3  3                                               2
# {1, gen} ⋅e           2                     3     207⋅I_S__ ⋅\mathcal{A}_{1, g
# ──────────── + 6⋅I_S__ ⋅\mathcal{A}_{1, gen} ⋅e - ────────────────────────────
#                                                                    8
#
#    2  2          2                     2            2                       3
# en} ⋅e    3⋅I_S__ ⋅\mathcal{A}_{1, gen}    213⋅I_S__ ⋅\mathcal{A}_{1, gen}⋅e
# ─────── + ────────────────────────────── + ──────────────────────────────────
#                         2                                  8
#
#                                             2  2          2
#          2                          15⋅I_S__ ⋅e    3⋅I_S__    81⋅\mathcal{A}_{
# - 6⋅I_S__ ⋅\mathcal{A}_{1, gen}⋅e + ──────────── - ──────── - ────────────────
#                                          4            4                    8
#
#        4  2                         4                           3  3
# 1, gen} ⋅e    3⋅\mathcal{A}_{1, gen}    417⋅\mathcal{A}_{1, gen} ⋅e
# ─────────── + ─────────────────────── + ──────────────────────────── - 6⋅\math
#                          4                           8
#
#                                              2  2                         2
#                3     207⋅\mathcal{A}_{1, gen} ⋅e    3⋅\mathcal{A}_{1, gen}
# cal{A}_{1, gen} ⋅e + ──────────────────────────── - ─────────────────────── -
#                                   8                            2
#
#                           3                                  2    ⎞
# 213⋅\mathcal{A}_{1, gen}⋅e                               15⋅e    3⎟
# ─────────────────────────── + 6⋅\mathcal{A}_{1, gen}⋅e - ───── + ─⎟⋅Ξ_S2__(n⋅│
#              8                                             4     4⎠
#
#
#
# 2⋅\mathcal{z} - 2│)

# %%
expr = heating_S_LIB
expr = expr.subs(obliquity_sat, 0)
expr = taylor(expr, eccentricity, 6).removeO()
expr = expr.subs(spin_frac, Rational(3,2))
expr = taylor(expr, lib_A, 2).removeO()
for mode, love_S in love_coeffs_sat_LIB.items():
    expr = collect(expr, love_S)
    
    
disp(expr)

# %%
expr = heating_S_LIB
expr = expr.subs(obliquity_sat, 0)
disp(expr)

# %%
expr = heating_S_LIB
expr = expr.subs(obliquity_sat, 0)
expr = taylor(expr, eccentricity, 3).removeO()
expr = taylor(expr, lib_A, 7).removeO()
expr = expr.subs(spin_frac, 1)

lib_A11 = Symbol('\mathcal{A}_{1, 1:1}')
expr = expr.subs(lib_A, lib_A11)
for mode, love_S in love_coeffs_sat_LIB.items():
    expr = collect(expr, love_S)
    
    
disp(expr)

# %%
expr = heating_S_LIB
expr = taylor(expr, obliquity_sat, 3).removeO()
expr = taylor(expr, eccentricity, 4).removeO()
expr = expr.subs(spin_frac, 1)
expr = taylor(expr, lib_A, 3).removeO()

lib_A11 = Symbol('\mathcal{A}_{1, 1:1}')
expr = expr.subs(lib_A, lib_A11)
for mode, love_S in love_coeffs_sat_LIB.items():
    expr = collect(expr, love_S)
    
    
disp(expr)

# %%
expr = heating_S_LIB
expr = taylor(expr, obliquity_sat, 3).removeO()
expr = taylor(expr, eccentricity, 4).removeO()
expr = expr.subs(spin_frac, Rational(3,2))
expr = taylor(expr, lib_A, 3).removeO()

lib_A32 = Symbol('\mathcal{A}_{1, 3:2}')
expr = expr.subs(lib_A, lib_A32)
for mode, love_S in love_coeffs_sat_LIB.items():
    expr = collect(expr, love_S)
    
    
disp(expr)

# %%
#expr = potential / tidal_susceptibility_reduced
expr = potential / tidal_susceptibility_reduced
expr = expr / radius_factor
# Using Wahr+ substitutions
#   "Angular rate of NSR" = Spin - mean_n
expr = expr.subs(mean_anon, mean_n*time_var)
expr = expr.subs(sidereal_time, spin_sat*time_var)
expr = expr.subs(periapsis, 0)
expr = expr.subs(node, 0)
expr = expr.subs(obliquity_sat, 0)

expr = taylor(expr, eccentricity, 4).removeO()

#expr = expr.subs(obliquity_sat, 0)
#max_order = 2
#orders = sum( Order(eccentricity**a*obliquity_sat**(max_order-a),eccentricity,obliquity_sat) for a in range(max_order+1) )
#expr = taylor(expr, obliquity_sat, 2).removeO()
#expr = expand(expr+orders)

# %%
disp(expr)

# %% [markdown]
# ## Inclination = 0

# %%
print('Full Potential')
expr = full_potential
# expr = taylor(expr, obliquity_sat, 3)
expr = expr.subs(obliquity_sat, 0)
expr = expand(sync_spin(expr, host=True, sat=True, max_q=max_q))
for mode, love_S in love_table_sat.items():
    expr = collect(expr, love_S)
disp(trigsimp(expr))
latex_str = latex(expr)
latex_str = latex_str.replace('\\Xi^{}_{S2}', '\\operatorname{K}_{j}')
print(latex_str)

# %%
print('Tidal Heating')
expr=heating_S_simp
expr = taylor(expr, obliquity_sat, 3).removeO()
expr = expand(expr.subs(spin_sat, Rational(3,2) * mean_n))
for mode, love_S in love_table_sat.items():
    expr = collect(expr, love_S)
disp(expr)
latex_str = latex(expr)
latex_str = latex_str.replace('\\Xi^{}_{S2}', '\\operatorname{K}_{j}')
print('\nLaTeX:')
print(latex_str)

# %%
print('Tidal Heating')
expr=heating_S_simp
expr = taylor(expr, obliquity_sat, 2)
expr = expand(expr.subs(spin_sat, mean_n))
for mode, love_S in love_table_sat.items():
    expr = collect(expr, love_S)
disp(expr)
latex_str = latex(expr)
latex_str = latex_str.replace('\\Xi^{}_{S2}', '\\operatorname{K}_{j}')
print('\nLaTeX:')
print(latex_str)

# %%
# print('dU_dM')
# expr = dUdM_S_simp.subs(inclin_sat, 0)
# expr = expand(sync_spin(expr, host=True, sat=True) / (sign(mean_n)))
# for mode, love_S in love_table_sat.items():
#     expr = collect(expr, love_S)
# disp(expr)
# latex_str = latex(expr)
# latex_str = latex_str.replace('\\Xi^{}_{S2}', '\\operatorname{K}_{j}')
# print(latex_str)

# %%
# print('dU_dw')
# expr = dUdw_S_simp.subs(inclin_sat, 0)
# expr = expand(sync_spin(expr, host=True, sat=True) / (sign(mean_n)))
# for mode, love_S in love_table_sat.items():
#     expr = collect(expr, love_S)
# disp(expr)
# latex_str = latex(expr)
# latex_str = latex_str.replace('\\Xi^{}_{S2}', '\\operatorname{K}_{j}')
# print(latex_str)

# %%
# print('dU_dO')
# expr = dUdO_S_simp.subs(inclin_sat, 0)
# expr = expand(sync_spin(expr, host=True, sat=True) / (sign(mean_n)))
# for mode, love_S in love_table_sat.items():
#     expr = collect(expr, love_S)
# disp(expr)
# latex_str = latex(expr)
# latex_str = latex_str.replace('\\Xi^{}_{S2}', '\\operatorname{K}_{j}')
# print(latex_str)

# %% [markdown]
# ## Eccentricity = 0

# %%
# print('Full Potential')
# expr = full_potential_simp
# expr = expr.subs(ecc, 0)
# expr = expand(sync_spin(expr, host=True, sat=True))
# for mode, love_S in love_table_sat.items():
#     expr = collect(expr, love_S)
# disp(expr)
# latex_str = latex(expr)
# latex_str = latex_str.replace('\\Xi^{}_{S2}', '\\operatorname{K}_{j}')
# print(latex_str)

# %%
# print('Tidal Heating')
# expr = heating_S_simp
# expr = expr.subs(ecc, 0)
# expr = expand(sync_spin(expr, host=True, sat=True) / abs(mean_n))
# for mode, love_S in love_table_sat.items():
#     expr = collect(expr, love_S)
# disp(expr)
# latex_str = latex(expr)
# latex_str = latex_str.replace('\\Xi^{}_{S2}', '\\operatorname{K}_{j}')
# print(latex_str)

# %%
# print('dU_dM')
# expr = dUdM_S_simp.subs(ecc, 0)
# expr = expand(sync_spin(expr, host=True, sat=True) / (sign(mean_n)))
# for mode, love_S in love_table_sat.items():
#     expr = collect(expr, love_S)
# disp(expr)
# latex_str = latex(expr)
# latex_str = latex_str.replace('\\Xi^{}_{S2}', '\\operatorname{K}_{j}')
# print(latex_str)

# %%
# print('dU_dw')
# expr = dUdw_S_simp.subs(ecc, 0)
# expr = expand(sync_spin(expr, host=True, sat=True) / (sign(mean_n)))
# for mode, love_S in love_table_sat.items():
#     expr = collect(expr, love_S)
# disp(expr)
# latex_str = latex(expr)
# latex_str = latex_str.replace('\\Xi^{}_{S2}', '\\operatorname{K}_{j}')
# print(latex_str)

# %%
# print('dU_dO')
# expr = dUdO_S_simp.subs(ecc, 0)
# expr = expand(sync_spin(expr, host=True, sat=True) / (sign(mean_n)))
# for mode, love_S in love_table_sat.items():
#     expr = collect(expr, love_S)
# disp(expr)
# latex_str = latex(expr)
# latex_str = latex_str.replace('\\Xi^{}_{S2}', '\\operatorname{K}_{j}')
# print(latex_str)

# %% [markdown]
# ## General - Inclin Truncated

# %%
Inclin_trunc = 5

# %%
# print('Full Potential')
# expr = full_potential_simp
# expr = taylor(expr, inclin_sat, Inclin_trunc)
# expr = expand(sync_spin(expr, host=True, sat=True))
# for mode, love_S in love_table_sat.items():
#     expr = collect(expr, love_S)
# disp(expr)
# latex_str = latex(expr)
# latex_str = latex_str.replace('\\Xi^{}_{S2}', '\\operatorname{K}_{j}')
# print(latex_str)

# %%
print('Tidal Heating')
expr = heating_S_simp
# # expr = taylor(expr, ecc, 12)
expr = expand(sync_spin(expr, host=True, sat=True, max_q=max_q) / (abs(mean_n)))
expr = taylor(expr, obliquity_sat, Inclin_trunc)
# for mode, love_S in love_table_sat.items():
#     expr = collect(expr, love_S)
disp(nsimplify(expr))
# latex_str = latex(expr)
# latex_str = latex_str.replace('\\Xi^{}_{S2}', '\\operatorname{K}_{j}')
# print(latex_str)

# %%
# print('dU_dM')
# expr = expand(sync_spin(expr, host=True, sat=True) / (sign(mean_n)))
# expr = taylor(expr, inclin_sat, Inclin_trunc)
# for mode, love_S in love_table_sat.items():
#     expr = collect(expr, love_S)
# disp(expr)
# latex_str = latex(expr)
# latex_str = latex_str.replace('\\Xi^{}_{S2}', '\\operatorname{K}_{j}')
# print(latex_str)

# %%
# print('dU_dw')
# expr = expand(sync_spin(expr, host=True, sat=True) / (sign(mean_n)))
# expr = taylor(expr, inclin_sat, Inclin_trunc)
# for mode, love_S in love_table_sat.items():
#     expr = collect(expr, love_S)
# disp(expr)
# latex_str = latex(expr)
# latex_str = latex_str.replace('\\Xi^{}_{S2}', '\\operatorname{K}_{j}')
# print(latex_str)

# %%
# print('dU_dO')
# expr = expand(sync_spin(expr, host=True, sat=True) / (sign(mean_n)))
# expr = taylor(expr, inclin_sat, Inclin_trunc)
# for mode, love_S in love_table_sat.items():
#     expr = collect(expr, love_S)
# disp(expr)
# latex_str = latex(expr)
# latex_str = latex_str.replace('\\Xi^{}_{S2}', '\\operatorname{K}_{j}')
# print(latex_str)

# %%
# Clean up
heating_H = clean_up(heating_H, max_q=max_q)
torque_H = clean_up(torque_H, max_q=max_q)
dUdM_H = clean_up(dUdM_H, max_q=max_q)
dUdw_H = clean_up(dUdw_H, max_q=max_q)
dUdO_H = clean_up(dUdO_H, max_q=max_q)

for mode, love_H in love_table_host.items():
    heating_H = collect(heating_H, love_H)
    dUdM_H = collect(dUdM_H, love_H)
    dUdw_H = collect(dUdw_H, love_H)
    dUdO_H = collect(dUdO_H, love_H)

heating_S = clean_up(heating_S, max_q=max_q)
torque_S = clean_up(torque_S, max_q=max_q)
dUdM_S = clean_up(dUdM_S, max_q=max_q)
dUdw_S = clean_up(dUdw_S, max_q=max_q)
dUdO_S = clean_up(dUdO_S, max_q=max_q)

for mode, love_S in love_table_sat.items():
    heating_S = collect(heating_S, love_S)
    dUdM_S = collect(dUdM_S, love_S)
    dUdw_S = collect(dUdw_S, love_S)
    dUdO_S = collect(dUdO_S, love_S)

# %% [markdown]
# ## Find Disturbing Potential Derivatives

# %%
dRdM = (1 / beta) * (-mass_host * dUdM_S - mass_sat * dUdM_H)
dRdw_host = (1 / beta) * (-mass_sat * dUdw_H)
dRdw_sat = (1 / beta) * (-mass_host * dUdw_S)
dRdO_host = (1 / beta) * (-mass_sat * dUdO_H)
dRdO_sat = (1 / beta) * (-mass_host * dUdO_S)

# %%
dRdM = expand(clean_up(dRdM.subs(mass_host + mass_sat, mean_n**2 * semi_major_axis**3 / newton_G),
                       max_q=max_q))
dRdw_host = expand(clean_up(dRdw_host.subs(mass_host + mass_sat, mean_n**2 * semi_major_axis**3 / newton_G),
                            max_q=max_q))
dRdw_sat = expand(clean_up(dRdw_sat.subs(mass_host + mass_sat, mean_n**2 * semi_major_axis**3 / newton_G),
                           max_q=max_q))
dRdO_host = expand(clean_up(dRdO_host.subs(mass_host + mass_sat, mean_n**2 * semi_major_axis**3 / newton_G),
                            max_q=max_q))
dRdO_sat = expand(clean_up(dRdO_sat.subs(mass_host + mass_sat, mean_n**2 * semi_major_axis**3 / newton_G),
                           max_q=max_q))

# %% [markdown]
# ## Find Time Derivatives

# %%
dadt = (2 / (mean_n * semi_major_axis)) * dRdM
dedt = ((1 - eccentricity**2) / (mean_n * semi_major_axis**2 * eccentricity)) * dRdM - \
    ((1 - eccentricity**2)**(Rational(1,2)) / (mean_n * semi_major_axis**2 * eccentricity)) * (dRdw_host + dRdw_sat)
dspin_dt_host = - (beta / moi_host) * dRdO_host
dspin_dt_sat = - (beta / moi_sat) * dRdO_sat

# %% [markdown]
# ### I = 0, Spin Sync Case

# %%
dadt_synci0 = sync_spin(dadt.subs(obliquity_host, 0).subs(obliquity_sat, 0),
                        sat=True, host=True, max_q=max_q)
dedt_synci0 = sync_spin(dedt.subs(obliquity_host, 0).subs(obliquity_sat, 0),
                        sat=True, host=True, max_q=max_q)
dspin_dt_host_synci0 = sync_spin(dspin_dt_host.subs(obliquity_host, 0).subs(obliquity_sat, 0),
                                 sat=True, host=True, max_q=max_q)
dspin_dt_sat_synci0 = sync_spin(dspin_dt_sat.subs(obliquity_host, 0).subs(obliquity_sat, 0),
                                sat=True, host=True, max_q=max_q)

for mode, love_S in love_table_sat.items():
    dadt_synci0 = collect(dadt_synci0, love_S)
    dedt_synci0 = collect(dedt_synci0, love_S)
    dspin_dt_sat_synci0 = collect(dspin_dt_sat_synci0, love_S)
for mode, love_H in love_table_host.items():
    dadt_synci0 = collect(dadt_synci0, love_H)
    dedt_synci0 = collect(dedt_synci0, love_H)
    dspin_dt_host_synci0 = collect(dspin_dt_host_synci0, love_H)

# %%
print('da/dt')
# disp(dadt_synci0)

latex_str = latex(dadt_synci0/(Rational(3,2)))
# latex_str = latex_str.replace('\\Xi^{}_{S2}', '\\operatorname{K}_{j}')
print(latex_str)

# %%
print('de/dt')
disp(dedt_synci0)

# %%
print('SpinDerivs')
disp(dspin_dt_sat_synci0)
disp(dspin_dt_host_synci0)
