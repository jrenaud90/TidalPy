# %% [markdown]
# # Speed testing for mode manipulators (TidalPy.tides)

# %%
from time import time as timer
import matplotlib.pyplot as plt
import numpy as np
from numba import njit

# %%
from TidalPy import version
from TidalPy.tides.mode_manipulation import find_mode_manipulators

# %%
@njit()
def cpl_neg_imk_helper_func(tidal_frequencies, fixed_k2: float, fixed_q: float):
    """ Njit-safe helper function for calculating -Imk2 for CPL method.

    Parameters
    ----------
    tidal_frequencies : Dict[FreqSig, FloatArray]
        Njit-safe TypedDict of tidal frequencies.
    fixed_k2 : float
        World's static k2
    fixed_q : float
        Fixed dissipation Q factor.

    Returns
    -------
    neg_imk_by_unique_freq : Dict[FreqSig, ComplexArray]
    """

    # Build fake values so that njit can compile the function
    fake_index = list(tidal_frequencies.keys())[0]
    fake_freq = tidal_frequencies[fake_index]
    neg_imk_by_unique_freq = {(-100, -100): fake_freq * (1. + 1.j)}

    # Real calculation
    for freq_sig, freq in tidal_frequencies.items():
        # The 0 * fake_freq is to ensure the correct array size is used.
        neg_imk_by_unique_freq[freq_sig] = fixed_k2 * (1. - (1.j / fixed_q)) + (0. * fake_freq)

    # Delete fake frequency used to compile function
    del neg_imk_by_unique_freq[(-100, -100)]

    return neg_imk_by_unique_freq

# %%
N_range = np.logspace(0, 6, 20, dtype=np.int32)
order_ls = {'-': 2, '--': 3, '-.': 4}
eccen_truncs = {'b': 2, 'g': 6, 'orange': 10, 'r': 20}

radius = 1.e6
gravity = 9.3
density = 1000.
shear_modulus = 50.e9
tidal_scale = 1.
tidal_susceptibility = 1.e22
tidal_host_mass = 1.e27
constant_cmplex_compliance = shear_modulus**(-1) + 1.0j * (shear_modulus*0.1)**(-1)
orbital_freq = 2. * np.pi / (86400. * 6)
spin_freq = 1.1 * orbital_freq

# %%
eccen_run_times = dict()
inclin_run_times = dict()
calculate_run_times = dict()
collapse_run_times = dict()

eccen_compile_times = list()
inclin_compile_times = list()
calculate_compile_times = list()
collapse_compile_times = list()
cases = list()

for ls, order_l in order_ls.items():
    for color, eccen_trunc in eccen_truncs.items():

        cases.append((order_l, eccen_trunc))

        calculate_terms, collapse_modes, eccentricity_func, inclination_func = \
            find_mode_manipulators(order_l, eccen_trunc, True)

        # Compile Time Calculations
        x = np.linspace(0.1, 0.9, 5)
        spin_freq_x = spin_freq * np.ones_like(x)
        orb_freq_x = orbital_freq * np.ones_like(x)
        semi_a_x = orb_freq_x**(-1)
        tidal_susceptibility_x = tidal_susceptibility * np.ones_like(semi_a_x)

        eccen_compile_t0 = timer()
        eccen_res = eccentricity_func(x)
        eccen_compile_time = timer() - eccen_compile_t0
        eccen_compile_times.append(eccen_compile_time)

        inclin_compile_t0 = timer()
        obliquity_res = inclination_func(x)
        inclin_compile_time = timer() - inclin_compile_t0
        inclin_compile_times.append(inclin_compile_time)

        calculate_terms_t0 = timer()
        freqs, results = calculate_terms(spin_freq_x, orb_freq_x, semi_a_x, radius, eccen_res, obliquity_res)
        calculate_compile_time = timer() - calculate_terms_t0
        calculate_compile_times.append(calculate_compile_time)
        
        complex_comp = cpl_neg_imk_helper_func(freqs, fixed_k2=.3, fixed_q=100.)

        collapse_modes_t0 = timer()
        output = \
            collapse_modes(gravity, radius, density, shear_modulus, tidal_scale, tidal_host_mass,
                           tidal_susceptibility_x, complex_comp, results, order_l, cpl_ctl_method=False)
        collapse_compile_time = timer() - collapse_modes_t0
        collapse_compile_times.append(collapse_compile_time)

        # Run Time Calculations
        eccen_run_time_avg_at_case = list()
        inclin_run_time_avg_at_case = list()
        calculate_time_avg_at_case = list()
        collapse_time_avg_at_case = list()
        eccen_run_time_std_at_case = list()
        inclin_run_time_std_at_case = list()
        calculate_time_std_at_case = list()
        collapse_time_std_at_case = list()
        for N in N_range:
            x = np.linspace(0.1, 0.9, N)
            spin_freq_x = spin_freq * np.ones_like(x)
            orb_freq_x = orbital_freq * np.ones_like(x)
            semi_a_x = orb_freq_x**(-1)
            tidal_susceptibility_x = tidal_susceptibility * np.ones_like(semi_a_x)

            eccen_res = eccentricity_func(x)
            obliquity_res = inclination_func(x)
            freqs, results = calculate_terms(spin_freq_x, orb_freq_x, semi_a_x, radius, eccen_res, obliquity_res)
            complex_comp = cpl_neg_imk_helper_func(freqs, fixed_k2=.3, fixed_q=100.)
            
            output = \
                collapse_modes(gravity, radius, density, shear_modulus, tidal_scale, tidal_host_mass,
                               tidal_susceptibility_x, complex_comp, results, order_l, cpl_ctl_method=True)

            eccen_timing = %timeit -o eccentricity_func(x)
            inclin_timing = %timeit -o inclination_func(x)
            calculate_timing = %timeit -o calculate_terms(spin_freq_x, orb_freq_x, semi_a_x, radius,\
                eccen_res, obliquity_res)
            collapse_timing = %timeit -o collapse_modes(gravity, radius, density, shear_modulus, tidal_scale,\
                tidal_host_mass, tidal_susceptibility_x, complex_comp, results, order_l, cpl_ctl_method=False)

            eccen_run_time_avg_at_case.append(eccen_timing.average)
            inclin_run_time_avg_at_case.append(inclin_timing.average)
            calculate_time_avg_at_case.append(calculate_timing.average)
            collapse_time_avg_at_case.append(collapse_timing.average)
            eccen_run_time_std_at_case.append(eccen_timing.stdev)
            inclin_run_time_std_at_case.append(inclin_timing.stdev)
            calculate_time_std_at_case.append(calculate_timing.stdev)
            collapse_time_std_at_case.append(collapse_timing.stdev)

        key = (ls, order_l, color, eccen_trunc)
        eccen_run_times[key] = (np.asarray(eccen_run_time_avg_at_case), np.asarray(eccen_run_time_std_at_case))
        inclin_run_times[key] = (np.asarray(inclin_run_time_avg_at_case), np.asarray(inclin_run_time_std_at_case))
        calculate_run_times[key] = (np.asarray(calculate_time_avg_at_case), np.asarray(calculate_time_std_at_case))
        collapse_run_times[key] = (np.asarray(collapse_time_avg_at_case), np.asarray(collapse_time_std_at_case))
# Out:
# 64.4 µs ± 110 ns per loop (mean ± std. dev. of 7 runs, 10000 loops each)
# 61.3 µs ± 553 ns per loop (mean ± std. dev. of 7 runs, 10000 loops each)
# 168 µs ± 681 ns per loop (mean ± std. dev. of 7 runs, 10000 loops each)
# 180 µs ± 247 ns per loop (mean ± std. dev. of 7 runs, 10000 loops each)
# 64.6 µs ± 386 ns per loop (mean ± std. dev. of 7 runs, 10000 loops each)
# 61.3 µs ± 392 ns per loop (mean ± std. dev. of 7 runs, 10000 loops each)
# 166 µs ± 768 ns per loop (mean ± std. dev. of 7 runs, 10000 loops each)
# 180 µs ± 317 ns per loop (mean ± std. dev. of 7 runs, 10000 loops each)
# 64.5 µs ± 331 ns per loop (mean ± std. dev. of 7 runs, 10000 loops each)
# 60.4 µs ± 96.2 ns per loop (mean ± std. dev. of 7 runs, 10000 loops each)
# 168 µs ± 1.11 µs per loop (mean ± std. dev. of 7 runs, 10000 loops each)
# 180 µs ± 697 ns per loop (mean ± std. dev. of 7 runs, 10000 loops each)
# 64.5 µs ± 89.5 ns per loop (mean ± std. dev. of 7 runs, 10000 loops each)
# 61.4 µs ± 397 ns per loop (mean ± std. dev. of 7 runs, 10000 loops each)
# 166 µs ± 149 ns per loop (mean ± std. dev. of 7 runs, 10000 loops each)
# 181 µs ± 294 ns per loop (mean ± std. dev. of 7 runs, 10000 loops each)
# 64.7 µs ± 357 ns per loop (mean ± std. dev. of 7 runs, 10000 loops each)
# 61.1 µs ± 144 ns per loop (mean ± std. dev. of 7 runs, 10000 loops each)
# 171 µs ± 167 ns per loop (mean ± std. dev. of 7 runs, 10000 loops each)
# 184 µs ± 532 ns per loop (mean ± std. dev. of 7 runs, 10000 loops each)
# 64.9 µs ± 165 ns per loop (mean ± std. dev. of 7 runs, 10000 loops each)
# 61.4 µs ± 135 ns per loop (mean ± std. dev. of 7 runs, 10000 loops each)
# 173 µs ± 775 ns per loop (mean ± std. dev. of 7 runs, 10000 loops each)
# 187 µs ± 794 ns per loop (mean ± std. dev. of 7 runs, 10000 loops each)
# 65.2 µs ± 465 ns per loop (mean ± std. dev. of 7 runs, 10000 loops each)
# 61.7 µs ± 309 ns per loop (mean ± std. dev. of 7 runs, 10000 loops each)
# 176 µs ± 593 ns per loop (mean ± std. dev. of 7 runs, 10000 loops each)
# 190 µs ± 1.08 µs per loop (mean ± std. dev. of 7 runs, 10000 loops each)
# 65.4 µs ± 547 ns per loop (mean ± std. dev. of 7 runs, 10000 loops each)
# 61.7 µs ± 734 ns per loop (mean ± std. dev. of 7 runs, 10000 loops each)
# 179 µs ± 1.02 µs per loop (mean ± std. dev. of 7 runs, 10000 loops each)
# 191 µs ± 921 ns per loop (mean ± std. dev. of 7 runs, 10000 loops each)
# 65.2 µs ± 1.41 µs per loop (mean ± std. dev. of 7 runs, 10000 loops each)
# 62.2 µs ± 931 ns per loop (mean ± std. dev. of 7 runs, 10000 loops each)
# 188 µs ± 695 ns per loop (mean ± std. dev. of 7 runs, 10000 loops each)
# 194 µs ± 865 ns per loop (mean ± std. dev. of 7 runs, 10000 loops each)
# 64.4 µs ± 120 ns per loop (mean ± std. dev. of 7 runs, 10000 loops each)
# 62.3 µs ± 150 ns per loop (mean ± std. dev. of 7 runs, 10000 loops each)
# 181 µs ± 510 ns per loop (mean ± std. dev. of 7 runs, 10000 loops each)
# 192 µs ± 815 ns per loop (mean ± std. dev. of 7 runs, 10000 loops each)
# 65.2 µs ± 348 ns per loop (mean ± std. dev. of 7 runs, 10000 loops each)
# 62.1 µs ± 170 ns per loop (mean ± std. dev. of 7 runs, 10000 loops each)
# 187 µs ± 700 ns per loop (mean ± std. dev. of 7 runs, 10000 loops each)
# 199 µs ± 573 ns per loop (mean ± std. dev. of 7 runs, 10000 loops each)
# 64.5 µs ± 347 ns per loop (mean ± std. dev. of 7 runs, 10000 loops each)
# 61.5 µs ± 147 ns per loop (mean ± std. dev. of 7 runs, 10000 loops each)
# 182 µs ± 880 ns per loop (mean ± std. dev. of 7 runs, 10000 loops each)
# 199 µs ± 352 ns per loop (mean ± std. dev. of 7 runs, 10000 loops each)
# 65.3 µs ± 424 ns per loop (mean ± std. dev. of 7 runs, 10000 loops each)
# 62.4 µs ± 70.5 ns per loop (mean ± std. dev. of 7 runs, 10000 loops each)
# 184 µs ± 912 ns per loop (mean ± std. dev. of 7 runs, 10000 loops each)
# 202 µs ± 941 ns per loop (mean ± std. dev. of 7 runs, 1000 loops each)
# 64.6 µs ± 438 ns per loop (mean ± std. dev. of 7 runs, 10000 loops each)
# 63.8 µs ± 96.4 ns per loop (mean ± std. dev. of 7 runs, 10000 loops each)
# 189 µs ± 542 ns per loop (mean ± std. dev. of 7 runs, 10000 loops each)
# 212 µs ± 825 ns per loop (mean ± std. dev. of 7 runs, 1000 loops each)
# 64.7 µs ± 262 ns per loop (mean ± std. dev. of 7 runs, 10000 loops each)
# 64.1 µs ± 115 ns per loop (mean ± std. dev. of 7 runs, 10000 loops each)
# 185 µs ± 771 ns per loop (mean ± std. dev. of 7 runs, 10000 loops each)
# 215 µs ± 643 ns per loop (mean ± std. dev. of 7 runs, 1000 loops each)
# 64.9 µs ± 747 ns per loop (mean ± std. dev. of 7 runs, 10000 loops each)
# 62.4 µs ± 234 ns per loop (mean ± std. dev. of 7 runs, 10000 loops each)
# 190 µs ± 639 ns per loop (mean ± std. dev. of 7 runs, 10000 loops each)
# 225 µs ± 5.27 µs per loop (mean ± std. dev. of 7 runs, 1000 loops each)
# 65.3 µs ± 683 ns per loop (mean ± std. dev. of 7 runs, 10000 loops each)
# 63.5 µs ± 552 ns per loop (mean ± std. dev. of 7 runs, 10000 loops each)
# 191 µs ± 59.7 ns per loop (mean ± std. dev. of 7 runs, 10000 loops each)
# 238 µs ± 3.2 µs per loop (mean ± std. dev. of 7 runs, 1000 loops each)
# 65.2 µs ± 290 ns per loop (mean ± std. dev. of 7 runs, 10000 loops each)
# 64 µs ± 395 ns per loop (mean ± std. dev. of 7 runs, 10000 loops each)
# 195 µs ± 862 ns per loop (mean ± std. dev. of 7 runs, 10000 loops each)
# 256 µs ± 7.16 µs per loop (mean ± std. dev. of 7 runs, 1000 loops each)
# 65 µs ± 209 ns per loop (mean ± std. dev. of 7 runs, 10000 loops each)
# 65 µs ± 599 ns per loop (mean ± std. dev. of 7 runs, 10000 loops each)
# 204 µs ± 1.24 µs per loop (mean ± std. dev. of 7 runs, 1000 loops each)
# 275 µs ± 2.78 µs per loop (mean ± std. dev. of 7 runs, 1000 loops each)
# 65.5 µs ± 847 ns per loop (mean ± std. dev. of 7 runs, 10000 loops each)
# 66 µs ± 501 ns per loop (mean ± std. dev. of 7 runs, 10000 loops each)
# 215 µs ± 685 ns per loop (mean ± std. dev. of 7 runs, 1000 loops each)
# 305 µs ± 2.25 µs per loop (mean ± std. dev. of 7 runs, 1000 loops each)
# 65.1 µs ± 152 ns per loop (mean ± std. dev. of 7 runs, 10000 loops each)
# 67.3 µs ± 508 ns per loop (mean ± std. dev. of 7 runs, 10000 loops each)
# 227 µs ± 3.43 µs per loop (mean ± std. dev. of 7 runs, 1000 loops each)
# 345 µs ± 355 ns per loop (mean ± std. dev. of 7 runs, 1000 loops each)
# 66.3 µs ± 554 ns per loop (mean ± std. dev. of 7 runs, 10000 loops each)
# 72 µs ± 713 ns per loop (mean ± std. dev. of 7 runs, 10000 loops each)
# 237 µs ± 671 ns per loop (mean ± std. dev. of 7 runs, 1000 loops each)
# 390 µs ± 432 ns per loop (mean ± std. dev. of 7 runs, 1000 loops each)
# 65.7 µs ± 229 ns per loop (mean ± std. dev. of 7 runs, 10000 loops each)
# 71.8 µs ± 152 ns per loop (mean ± std. dev. of 7 runs, 10000 loops each)
# 255 µs ± 387 ns per loop (mean ± std. dev. of 7 runs, 1000 loops each)
# 456 µs ± 1.76 µs per loop (mean ± std. dev. of 7 runs, 1000 loops each)
# 66.5 µs ± 97.7 ns per loop (mean ± std. dev. of 7 runs, 10000 loops each)
# 77.4 µs ± 263 ns per loop (mean ± std. dev. of 7 runs, 10000 loops each)
# 282 µs ± 1.62 µs per loop (mean ± std. dev. of 7 runs, 1000 loops each)
# 550 µs ± 8.79 µs per loop (mean ± std. dev. of 7 runs, 1000 loops each)
# 67.2 µs ± 522 ns per loop (mean ± std. dev. of 7 runs, 10000 loops each)
# 80.1 µs ± 206 ns per loop (mean ± std. dev. of 7 runs, 10000 loops each)
# 324 µs ± 266 ns per loop (mean ± std. dev. of 7 runs, 1000 loops each)
# 654 µs ± 1.84 µs per loop (mean ± std. dev. of 7 runs, 1000 loops each)
# 68.1 µs ± 505 ns per loop (mean ± std. dev. of 7 runs, 10000 loops each)
# 85.7 µs ± 680 ns per loop (mean ± std. dev. of 7 runs, 10000 loops each)
# 357 µs ± 5.85 µs per loop (mean ± std. dev. of 7 runs, 1000 loops each)
# 827 µs ± 15.4 µs per loop (mean ± std. dev. of 7 runs, 1000 loops each)
# 69.2 µs ± 747 ns per loop (mean ± std. dev. of 7 runs, 10000 loops each)
# 96.3 µs ± 576 ns per loop (mean ± std. dev. of 7 runs, 10000 loops each)
# 429 µs ± 1.84 µs per loop (mean ± std. dev. of 7 runs, 1000 loops each)
# 1.07 ms ± 8.51 µs per loop (mean ± std. dev. of 7 runs, 1000 loops each)
# 72.1 µs ± 608 ns per loop (mean ± std. dev. of 7 runs, 10000 loops each)
# 107 µs ± 539 ns per loop (mean ± std. dev. of 7 runs, 10000 loops each)
# 505 µs ± 3.86 µs per loop (mean ± std. dev. of 7 runs, 1000 loops each)
# 1.36 ms ± 22.9 µs per loop (mean ± std. dev. of 7 runs, 1000 loops each)
# 73.8 µs ± 489 ns per loop (mean ± std. dev. of 7 runs, 10000 loops each)
# 121 µs ± 308 ns per loop (mean ± std. dev. of 7 runs, 10000 loops each)
# 633 µs ± 8.96 µs per loop (mean ± std. dev. of 7 runs, 1000 loops each)
# 1.7 ms ± 28.1 µs per loop (mean ± std. dev. of 7 runs, 1000 loops each)
# 76 µs ± 171 ns per loop (mean ± std. dev. of 7 runs, 10000 loops each)
# 141 µs ± 1.39 µs per loop (mean ± std. dev. of 7 runs, 10000 loops each)
# 804 µs ± 13.6 µs per loop (mean ± std. dev. of 7 runs, 1000 loops each)
# 2.83 ms ± 55.1 µs per loop (mean ± std. dev. of 7 runs, 100 loops each)
# 78.6 µs ± 449 ns per loop (mean ± std. dev. of 7 runs, 10000 loops each)
# 165 µs ± 699 ns per loop (mean ± std. dev. of 7 runs, 10000 loops each)
# 1.06 ms ± 24.9 µs per loop (mean ± std. dev. of 7 runs, 1000 loops each)
# 4.65 ms ± 62.7 µs per loop (mean ± std. dev. of 7 runs, 100 loops each)
# 82.3 µs ± 82.1 ns per loop (mean ± std. dev. of 7 runs, 10000 loops each)
# 196 µs ± 435 ns per loop (mean ± std. dev. of 7 runs, 10000 loops each)
# 2.21 ms ± 57.3 µs per loop (mean ± std. dev. of 7 runs, 100 loops each)
# 5.68 ms ± 46.2 µs per loop (mean ± std. dev. of 7 runs, 100 loops each)
# 87.1 µs ± 141 ns per loop (mean ± std. dev. of 7 runs, 10000 loops each)
# 239 µs ± 3.21 µs per loop (mean ± std. dev. of 7 runs, 1000 loops each)
# 3.7 ms ± 89.2 µs per loop (mean ± std. dev. of 7 runs, 100 loops each)
# 8.12 ms ± 22.9 µs per loop (mean ± std. dev. of 7 runs, 100 loops each)
# 93.6 µs ± 304 ns per loop (mean ± std. dev. of 7 runs, 10000 loops each)
# 292 µs ± 1.23 µs per loop (mean ± std. dev. of 7 runs, 1000 loops each)
# 4.55 ms ± 68.4 µs per loop (mean ± std. dev. of 7 runs, 100 loops each)
# 9.48 ms ± 22.5 µs per loop (mean ± std. dev. of 7 runs, 100 loops each)
# 101 µs ± 61.6 ns per loop (mean ± std. dev. of 7 runs, 10000 loops each)
# 366 µs ± 389 ns per loop (mean ± std. dev. of 7 runs, 1000 loops each)
# 5.28 ms ± 103 µs per loop (mean ± std. dev. of 7 runs, 100 loops each)
# 13.6 ms ± 61.1 µs per loop (mean ± std. dev. of 7 runs, 100 loops each)
# 110 µs ± 277 ns per loop (mean ± std. dev. of 7 runs, 10000 loops each)
# 464 µs ± 1.82 µs per loop (mean ± std. dev. of 7 runs, 1000 loops each)
# 6.51 ms ± 100 µs per loop (mean ± std. dev. of 7 runs, 100 loops each)
# 15.1 ms ± 121 µs per loop (mean ± std. dev. of 7 runs, 100 loops each)
# 126 µs ± 206 ns per loop (mean ± std. dev. of 7 runs, 10000 loops each)
# 598 µs ± 915 ns per loop (mean ± std. dev. of 7 runs, 1000 loops each)
# 10.6 ms ± 40.2 µs per loop (mean ± std. dev. of 7 runs, 100 loops each)
# 21 ms ± 923 µs per loop (mean ± std. dev. of 7 runs, 10 loops each)
# 150 µs ± 715 ns per loop (mean ± std. dev. of 7 runs, 10000 loops each)
# 779 µs ± 5.37 µs per loop (mean ± std. dev. of 7 runs, 1000 loops each)
# 11.8 ms ± 98.1 µs per loop (mean ± std. dev. of 7 runs, 100 loops each)
# 29.2 ms ± 573 µs per loop (mean ± std. dev. of 7 runs, 10 loops each)
# 174 µs ± 323 ns per loop (mean ± std. dev. of 7 runs, 10000 loops each)
# 1.02 ms ± 13.3 µs per loop (mean ± std. dev. of 7 runs, 1000 loops each)
# 15.4 ms ± 261 µs per loop (mean ± std. dev. of 7 runs, 100 loops each)
# 38.1 ms ± 569 µs per loop (mean ± std. dev. of 7 runs, 10 loops each)
# 204 µs ± 3.37 µs per loop (mean ± std. dev. of 7 runs, 1000 loops each)
# 1.37 ms ± 52.4 µs per loop (mean ± std. dev. of 7 runs, 1000 loops each)
# 22 ms ± 991 µs per loop (mean ± std. dev. of 7 runs, 10 loops each)
# 51.6 ms ± 920 µs per loop (mean ± std. dev. of 7 runs, 10 loops each)
# 251 µs ± 4.14 µs per loop (mean ± std. dev. of 7 runs, 1000 loops each)
# 1.88 ms ± 17.8 µs per loop (mean ± std. dev. of 7 runs, 1000 loops each)
# 30.6 ms ± 1.87 ms per loop (mean ± std. dev. of 7 runs, 10 loops each)
# 74.5 ms ± 1.27 ms per loop (mean ± std. dev. of 7 runs, 10 loops each)
# 421 µs ± 19.4 µs per loop (mean ± std. dev. of 7 runs, 1000 loops each)
# 2.68 ms ± 34.7 µs per loop (mean ± std. dev. of 7 runs, 100 loops each)
# 43.5 ms ± 3.14 ms per loop (mean ± std. dev. of 7 runs, 10 loops each)
# 101 ms ± 1.25 ms per loop (mean ± std. dev. of 7 runs, 10 loops each)
# 2.72 ms ± 167 µs per loop (mean ± std. dev. of 7 runs, 100 loops each)
# 7.91 ms ± 128 µs per loop (mean ± std. dev. of 7 runs, 100 loops each)
# 119 ms ± 1.3 ms per loop (mean ± std. dev. of 7 runs, 10 loops each)
# 157 ms ± 1.91 ms per loop (mean ± std. dev. of 7 runs, 10 loops each)
# 3.55 ms ± 283 µs per loop (mean ± std. dev. of 7 runs, 100 loops each)
# 10.4 ms ± 58.6 µs per loop (mean ± std. dev. of 7 runs, 100 loops each)
# 160 ms ± 2.67 ms per loop (mean ± std. dev. of 7 runs, 10 loops each)
# 215 ms ± 14 ms per loop (mean ± std. dev. of 7 runs, 1 loop each)
# 4.44 ms ± 217 µs per loop (mean ± std. dev. of 7 runs, 100 loops each)
# 14.3 ms ± 284 µs per loop (mean ± std. dev. of 7 runs, 100 loops each)
# 216 ms ± 14 ms per loop (mean ± std. dev. of 7 runs, 1 loop each)
# 292 ms ± 16 ms per loop (mean ± std. dev. of 7 runs, 1 loop each)
# 6.51 ms ± 469 µs per loop (mean ± std. dev. of 7 runs, 100 loops each)
# 18.8 ms ± 154 µs per loop (mean ± std. dev. of 7 runs, 100 loops each)
# 304 ms ± 25.5 ms per loop (mean ± std. dev. of 7 runs, 1 loop each)
# 393 ms ± 18.8 ms per loop (mean ± std. dev. of 7 runs, 1 loop each)
# 8.47 ms ± 319 µs per loop (mean ± std. dev. of 7 runs, 100 loops each)
# 25.1 ms ± 1.53 ms per loop (mean ± std. dev. of 7 runs, 10 loops each)
# 418 ms ± 26.3 ms per loop (mean ± std. dev. of 7 runs, 1 loop each)
# 547 ms ± 26 ms per loop (mean ± std. dev. of 7 runs, 1 loop each)
# 11.9 ms ± 232 µs per loop (mean ± std. dev. of 7 runs, 100 loops each)
# 34.6 ms ± 2.24 ms per loop (mean ± std. dev. of 7 runs, 10 loops each)
# 584 ms ± 27.1 ms per loop (mean ± std. dev. of 7 runs, 1 loop each)
# 741 ms ± 16.1 ms per loop (mean ± std. dev. of 7 runs, 1 loop each)
# 15.1 ms ± 157 µs per loop (mean ± std. dev. of 7 runs, 100 loops each)
# 44.5 ms ± 2.64 ms per loop (mean ± std. dev. of 7 runs, 10 loops each)
# 751 ms ± 36.8 ms per loop (mean ± std. dev. of 7 runs, 1 loop each)
# 950 ms ± 16.3 ms per loop (mean ± std. dev. of 7 runs, 1 loop each)
# 19.8 ms ± 995 µs per loop (mean ± std. dev. of 7 runs, 10 loops each)
# 56.9 ms ± 1.84 ms per loop (mean ± std. dev. of 7 runs, 10 loops each)
# 976 ms ± 31.6 ms per loop (mean ± std. dev. of 7 runs, 1 loop each)
# 1.34 s ± 30.3 ms per loop (mean ± std. dev. of 7 runs, 1 loop each)
# 67.7 µs ± 359 ns per loop (mean ± std. dev. of 7 runs, 10000 loops each)
# 60.7 µs ± 485 ns per loop (mean ± std. dev. of 7 runs, 10000 loops each)
# 214 µs ± 1.53 µs per loop (mean ± std. dev. of 7 runs, 1000 loops each)
# 200 µs ± 987 ns per loop (mean ± std. dev. of 7 runs, 1000 loops each)
# 67.8 µs ± 366 ns per loop (mean ± std. dev. of 7 runs, 10000 loops each)
# 60.5 µs ± 379 ns per loop (mean ± std. dev. of 7 runs, 10000 loops each)
# 215 µs ± 2.02 µs per loop (mean ± std. dev. of 7 runs, 1000 loops each)
# 200 µs ± 1.48 µs per loop (mean ± std. dev. of 7 runs, 1000 loops each)
# 67.5 µs ± 145 ns per loop (mean ± std. dev. of 7 runs, 10000 loops each)
# 60.9 µs ± 722 ns per loop (mean ± std. dev. of 7 runs, 10000 loops each)
# 213 µs ± 1.08 µs per loop (mean ± std. dev. of 7 runs, 1000 loops each)
# 201 µs ± 384 ns per loop (mean ± std. dev. of 7 runs, 1000 loops each)
# 68 µs ± 449 ns per loop (mean ± std. dev. of 7 runs, 10000 loops each)
# 60.6 µs ± 340 ns per loop (mean ± std. dev. of 7 runs, 10000 loops each)
# 214 µs ± 1.46 µs per loop (mean ± std. dev. of 7 runs, 1000 loops each)
# 202 µs ± 415 ns per loop (mean ± std. dev. of 7 runs, 1000 loops each)
# 67.8 µs ± 414 ns per loop (mean ± std. dev. of 7 runs, 10000 loops each)
# 60.6 µs ± 215 ns per loop (mean ± std. dev. of 7 runs, 10000 loops each)
# 224 µs ± 1.73 µs per loop (mean ± std. dev. of 7 runs, 1000 loops each)
# 209 µs ± 4.07 µs per loop (mean ± std. dev. of 7 runs, 1000 loops each)
# 68.1 µs ± 481 ns per loop (mean ± std. dev. of 7 runs, 10000 loops each)
# 60.6 µs ± 97.3 ns per loop (mean ± std. dev. of 7 runs, 10000 loops each)
# 228 µs ± 973 ns per loop (mean ± std. dev. of 7 runs, 1000 loops each)
# 214 µs ± 2.65 µs per loop (mean ± std. dev. of 7 runs, 1000 loops each)
# 68.8 µs ± 560 ns per loop (mean ± std. dev. of 7 runs, 10000 loops each)
# 61.1 µs ± 598 ns per loop (mean ± std. dev. of 7 runs, 10000 loops each)
# 243 µs ± 3.32 µs per loop (mean ± std. dev. of 7 runs, 1000 loops each)
# 220 µs ± 3.43 µs per loop (mean ± std. dev. of 7 runs, 1000 loops each)
# 70.7 µs ± 216 ns per loop (mean ± std. dev. of 7 runs, 10000 loops each)
# 61.6 µs ± 426 ns per loop (mean ± std. dev. of 7 runs, 10000 loops each)
# 241 µs ± 1.11 µs per loop (mean ± std. dev. of 7 runs, 1000 loops each)
# 219 µs ± 2.7 µs per loop (mean ± std. dev. of 7 runs, 1000 loops each)
# 69.7 µs ± 818 ns per loop (mean ± std. dev. of 7 runs, 10000 loops each)
# 62.8 µs ± 715 ns per loop (mean ± std. dev. of 7 runs, 10000 loops each)
# 257 µs ± 1.98 µs per loop (mean ± std. dev. of 7 runs, 1000 loops each)
# 222 µs ± 860 ns per loop (mean ± std. dev. of 7 runs, 1000 loops each)
# 69 µs ± 837 ns per loop (mean ± std. dev. of 7 runs, 10000 loops each)
# 61.3 µs ± 55.5 ns per loop (mean ± std. dev. of 7 runs, 10000 loops each)
# 249 µs ± 3.45 µs per loop (mean ± std. dev. of 7 runs, 1000 loops each)
# 223 µs ± 2.38 µs per loop (mean ± std. dev. of 7 runs, 1000 loops each)
# 69.1 µs ± 666 ns per loop (mean ± std. dev. of 7 runs, 10000 loops each)
# 62.2 µs ± 813 ns per loop (mean ± std. dev. of 7 runs, 10000 loops each)
# 254 µs ± 322 ns per loop (mean ± std. dev. of 7 runs, 1000 loops each)
# 232 µs ± 4.46 µs per loop (mean ± std. dev. of 7 runs, 1000 loops each)
# 68.5 µs ± 183 ns per loop (mean ± std. dev. of 7 runs, 10000 loops each)
# 61.9 µs ± 647 ns per loop (mean ± std. dev. of 7 runs, 10000 loops each)
# 241 µs ± 329 ns per loop (mean ± std. dev. of 7 runs, 1000 loops each)
# 231 µs ± 5.33 µs per loop (mean ± std. dev. of 7 runs, 1000 loops each)
# 68.6 µs ± 276 ns per loop (mean ± std. dev. of 7 runs, 10000 loops each)
# 61.2 µs ± 319 ns per loop (mean ± std. dev. of 7 runs, 10000 loops each)
# 244 µs ± 502 ns per loop (mean ± std. dev. of 7 runs, 1000 loops each)
# 237 µs ± 1.12 µs per loop (mean ± std. dev. of 7 runs, 1000 loops each)
# 70.4 µs ± 174 ns per loop (mean ± std. dev. of 7 runs, 10000 loops each)
# 64.7 µs ± 681 ns per loop (mean ± std. dev. of 7 runs, 10000 loops each)
# 253 µs ± 223 ns per loop (mean ± std. dev. of 7 runs, 1000 loops each)
# 245 µs ± 314 ns per loop (mean ± std. dev. of 7 runs, 1000 loops each)
# 70.4 µs ± 809 ns per loop (mean ± std. dev. of 7 runs, 10000 loops each)
# 62.8 µs ± 216 ns per loop (mean ± std. dev. of 7 runs, 10000 loops each)
# 253 µs ± 746 ns per loop (mean ± std. dev. of 7 runs, 1000 loops each)
# 254 µs ± 926 ns per loop (mean ± std. dev. of 7 runs, 1000 loops each)
# 69.3 µs ± 512 ns per loop (mean ± std. dev. of 7 runs, 10000 loops each)
# 63.2 µs ± 906 ns per loop (mean ± std. dev. of 7 runs, 10000 loops each)
# 260 µs ± 347 ns per loop (mean ± std. dev. of 7 runs, 1000 loops each)
# 270 µs ± 645 ns per loop (mean ± std. dev. of 7 runs, 1000 loops each)
# 68.8 µs ± 962 ns per loop (mean ± std. dev. of 7 runs, 10000 loops each)
# 63.1 µs ± 462 ns per loop (mean ± std. dev. of 7 runs, 10000 loops each)
# 275 µs ± 7.99 µs per loop (mean ± std. dev. of 7 runs, 1000 loops each)
# 289 µs ± 483 ns per loop (mean ± std. dev. of 7 runs, 1000 loops each)
# 70 µs ± 1.02 µs per loop (mean ± std. dev. of 7 runs, 10000 loops each)
# 63.6 µs ± 317 ns per loop (mean ± std. dev. of 7 runs, 10000 loops each)
# 274 µs ± 394 ns per loop (mean ± std. dev. of 7 runs, 1000 loops each)
# 311 µs ± 465 ns per loop (mean ± std. dev. of 7 runs, 1000 loops each)
# 70.8 µs ± 81.7 ns per loop (mean ± std. dev. of 7 runs, 10000 loops each)
# 64.3 µs ± 45.8 ns per loop (mean ± std. dev. of 7 runs, 10000 loops each)
# 293 µs ± 6.26 µs per loop (mean ± std. dev. of 7 runs, 1000 loops each)
# 349 µs ± 1.75 µs per loop (mean ± std. dev. of 7 runs, 1000 loops each)
# 69.2 µs ± 70.4 ns per loop (mean ± std. dev. of 7 runs, 10000 loops each)
# 65 µs ± 71.2 ns per loop (mean ± std. dev. of 7 runs, 10000 loops each)
# 314 µs ± 1.06 µs per loop (mean ± std. dev. of 7 runs, 1000 loops each)
# 394 µs ± 378 ns per loop (mean ± std. dev. of 7 runs, 1000 loops each)
# 70.2 µs ± 122 ns per loop (mean ± std. dev. of 7 runs, 10000 loops each)
# 68.5 µs ± 495 ns per loop (mean ± std. dev. of 7 runs, 10000 loops each)
# 340 µs ± 548 ns per loop (mean ± std. dev. of 7 runs, 1000 loops each)
# 454 µs ± 1.06 µs per loop (mean ± std. dev. of 7 runs, 1000 loops each)
# 70 µs ± 177 ns per loop (mean ± std. dev. of 7 runs, 10000 loops each)
# 68.6 µs ± 117 ns per loop (mean ± std. dev. of 7 runs, 10000 loops each)
# 368 µs ± 2.48 µs per loop (mean ± std. dev. of 7 runs, 1000 loops each)
# 532 µs ± 885 ns per loop (mean ± std. dev. of 7 runs, 1000 loops each)
# 71.5 µs ± 72.7 ns per loop (mean ± std. dev. of 7 runs, 10000 loops each)
# 72.4 µs ± 224 ns per loop (mean ± std. dev. of 7 runs, 10000 loops each)
# 401 µs ± 888 ns per loop (mean ± std. dev. of 7 runs, 1000 loops each)
# 633 µs ± 4.14 µs per loop (mean ± std. dev. of 7 runs, 1000 loops each)
# 73.2 µs ± 425 ns per loop (mean ± std. dev. of 7 runs, 10000 loops each)
# 75.8 µs ± 410 ns per loop (mean ± std. dev. of 7 runs, 10000 loops each)
# 460 µs ± 831 ns per loop (mean ± std. dev. of 7 runs, 1000 loops each)
# 772 µs ± 8.56 µs per loop (mean ± std. dev. of 7 runs, 1000 loops each)
# 72.9 µs ± 92.6 ns per loop (mean ± std. dev. of 7 runs, 10000 loops each)
# 79.6 µs ± 650 ns per loop (mean ± std. dev. of 7 runs, 10000 loops each)
# 542 µs ± 10.3 µs per loop (mean ± std. dev. of 7 runs, 1000 loops each)
# 954 µs ± 1.48 µs per loop (mean ± std. dev. of 7 runs, 1000 loops each)
# 76.4 µs ± 129 ns per loop (mean ± std. dev. of 7 runs, 10000 loops each)
# 86.1 µs ± 268 ns per loop (mean ± std. dev. of 7 runs, 10000 loops each)
# 628 µs ± 1.1 µs per loop (mean ± std. dev. of 7 runs, 1000 loops each)
# 1.22 ms ± 4.54 µs per loop (mean ± std. dev. of 7 runs, 1000 loops each)
# 79.1 µs ± 284 ns per loop (mean ± std. dev. of 7 runs, 10000 loops each)
# 95.9 µs ± 351 ns per loop (mean ± std. dev. of 7 runs, 10000 loops each)
# 770 µs ± 3.8 µs per loop (mean ± std. dev. of 7 runs, 1000 loops each)
# 1.65 ms ± 12.4 µs per loop (mean ± std. dev. of 7 runs, 1000 loops each)
# 80.9 µs ± 1.04 µs per loop (mean ± std. dev. of 7 runs, 10000 loops each)
# 105 µs ± 640 ns per loop (mean ± std. dev. of 7 runs, 10000 loops each)
# 966 µs ± 8.4 µs per loop (mean ± std. dev. of 7 runs, 1000 loops each)
# 2.14 ms ± 37.2 µs per loop (mean ± std. dev. of 7 runs, 100 loops each)
# 86.3 µs ± 130 ns per loop (mean ± std. dev. of 7 runs, 10000 loops each)
# 121 µs ± 367 ns per loop (mean ± std. dev. of 7 runs, 10000 loops each)
# 1.28 ms ± 12 µs per loop (mean ± std. dev. of 7 runs, 1000 loops each)
# 2.87 ms ± 27.9 µs per loop (mean ± std. dev. of 7 runs, 100 loops each)
# 92.5 µs ± 277 ns per loop (mean ± std. dev. of 7 runs, 10000 loops each)
# 140 µs ± 479 ns per loop (mean ± std. dev. of 7 runs, 10000 loops each)
# 1.8 ms ± 36.6 µs per loop (mean ± std. dev. of 7 runs, 1000 loops each)
# 4.08 ms ± 28 µs per loop (mean ± std. dev. of 7 runs, 100 loops each)
# 99.5 µs ± 159 ns per loop (mean ± std. dev. of 7 runs, 10000 loops each)
# 165 µs ± 415 ns per loop (mean ± std. dev. of 7 runs, 10000 loops each)
# 2.59 ms ± 50.6 µs per loop (mean ± std. dev. of 7 runs, 100 loops each)
# 5.5 ms ± 32.7 µs per loop (mean ± std. dev. of 7 runs, 100 loops each)
# 110 µs ± 1.22 µs per loop (mean ± std. dev. of 7 runs, 10000 loops each)
# 200 µs ± 2.37 µs per loop (mean ± std. dev. of 7 runs, 1000 loops each)
# 3.69 ms ± 91.8 µs per loop (mean ± std. dev. of 7 runs, 100 loops each)
# 7.35 ms ± 48.9 µs per loop (mean ± std. dev. of 7 runs, 100 loops each)
# 120 µs ± 1.02 µs per loop (mean ± std. dev. of 7 runs, 10000 loops each)
# 249 µs ± 5.73 µs per loop (mean ± std. dev. of 7 runs, 1000 loops each)
# 5.16 ms ± 190 µs per loop (mean ± std. dev. of 7 runs, 100 loops each)
# 10.2 ms ± 241 µs per loop (mean ± std. dev. of 7 runs, 100 loops each)
# 137 µs ± 2.39 µs per loop (mean ± std. dev. of 7 runs, 10000 loops each)
# 301 µs ± 2.71 µs per loop (mean ± std. dev. of 7 runs, 1000 loops each)
# 7.35 ms ± 82.8 µs per loop (mean ± std. dev. of 7 runs, 100 loops each)
# 13.2 ms ± 94.9 µs per loop (mean ± std. dev. of 7 runs, 100 loops each)
# 159 µs ± 2.3 µs per loop (mean ± std. dev. of 7 runs, 10000 loops each)
# 385 µs ± 5.45 µs per loop (mean ± std. dev. of 7 runs, 1000 loops each)
# 9.94 ms ± 334 µs per loop (mean ± std. dev. of 7 runs, 100 loops each)
# 17 ms ± 431 µs per loop (mean ± std. dev. of 7 runs, 100 loops each)
# 190 µs ± 539 ns per loop (mean ± std. dev. of 7 runs, 10000 loops each)
# 489 µs ± 7.36 µs per loop (mean ± std. dev. of 7 runs, 1000 loops each)
# 12.1 ms ± 138 µs per loop (mean ± std. dev. of 7 runs, 100 loops each)
# 22.4 ms ± 1.01 ms per loop (mean ± std. dev. of 7 runs, 10 loops each)
# 223 µs ± 1.67 µs per loop (mean ± std. dev. of 7 runs, 1000 loops each)
# 641 µs ± 8.53 µs per loop (mean ± std. dev. of 7 runs, 1000 loops each)
# 16.3 ms ± 115 µs per loop (mean ± std. dev. of 7 runs, 100 loops each)
# 31.1 ms ± 1.86 ms per loop (mean ± std. dev. of 7 runs, 10 loops each)
# 301 µs ± 6.85 µs per loop (mean ± std. dev. of 7 runs, 1000 loops each)
# 848 µs ± 12.6 µs per loop (mean ± std. dev. of 7 runs, 1000 loops each)
# 21.7 ms ± 890 µs per loop (mean ± std. dev. of 7 runs, 10 loops each)
# 37.3 ms ± 985 µs per loop (mean ± std. dev. of 7 runs, 10 loops each)
# 364 µs ± 13.5 µs per loop (mean ± std. dev. of 7 runs, 1000 loops each)
# 1.07 ms ± 26.6 µs per loop (mean ± std. dev. of 7 runs, 1000 loops each)
# 28.6 ms ± 2.38 ms per loop (mean ± std. dev. of 7 runs, 10 loops each)
# 49.6 ms ± 2.77 ms per loop (mean ± std. dev. of 7 runs, 10 loops each)
# 557 µs ± 26.9 µs per loop (mean ± std. dev. of 7 runs, 1000 loops each)
# 1.43 ms ± 18.1 µs per loop (mean ± std. dev. of 7 runs, 1000 loops each)
# 43.7 ms ± 2.17 ms per loop (mean ± std. dev. of 7 runs, 10 loops each)
# 77.9 ms ± 2.29 ms per loop (mean ± std. dev. of 7 runs, 10 loops each)
# 966 µs ± 41.6 µs per loop (mean ± std. dev. of 7 runs, 1000 loops each)
# 1.97 ms ± 36.2 µs per loop (mean ± std. dev. of 7 runs, 1000 loops each)
# 57.9 ms ± 1.61 ms per loop (mean ± std. dev. of 7 runs, 10 loops each)
# 119 ms ± 1.55 ms per loop (mean ± std. dev. of 7 runs, 10 loops each)
# 1.33 ms ± 12.9 µs per loop (mean ± std. dev. of 7 runs, 1000 loops each)
# 2.82 ms ± 54.8 µs per loop (mean ± std. dev. of 7 runs, 100 loops each)
# 88.7 ms ± 4.3 ms per loop (mean ± std. dev. of 7 runs, 10 loops each)
# 163 ms ± 2.17 ms per loop (mean ± std. dev. of 7 runs, 10 loops each)
# 5.65 ms ± 153 µs per loop (mean ± std. dev. of 7 runs, 100 loops each)
# 8.27 ms ± 210 µs per loop (mean ± std. dev. of 7 runs, 100 loops each)
# 282 ms ± 15.8 ms per loop (mean ± std. dev. of 7 runs, 1 loop each)
# 255 ms ± 12.3 ms per loop (mean ± std. dev. of 7 runs, 1 loop each)
# 8.21 ms ± 468 µs per loop (mean ± std. dev. of 7 runs, 100 loops each)
# 10.9 ms ± 162 µs per loop (mean ± std. dev. of 7 runs, 100 loops each)
# 387 ms ± 23.5 ms per loop (mean ± std. dev. of 7 runs, 1 loop each)
# 381 ms ± 30.7 ms per loop (mean ± std. dev. of 7 runs, 1 loop each)
# 10.5 ms ± 155 µs per loop (mean ± std. dev. of 7 runs, 100 loops each)
# 14.5 ms ± 383 µs per loop (mean ± std. dev. of 7 runs, 100 loops each)
# 495 ms ± 16.4 ms per loop (mean ± std. dev. of 7 runs, 1 loop each)
# 478 ms ± 9.59 ms per loop (mean ± std. dev. of 7 runs, 1 loop each)
# 13.9 ms ± 226 µs per loop (mean ± std. dev. of 7 runs, 100 loops each)
# 19 ms ± 1.65 ms per loop (mean ± std. dev. of 7 runs, 10 loops each)
# 675 ms ± 37 ms per loop (mean ± std. dev. of 7 runs, 1 loop each)
# 648 ms ± 25.6 ms per loop (mean ± std. dev. of 7 runs, 1 loop each)
# 19.5 ms ± 1.72 ms per loop (mean ± std. dev. of 7 runs, 10 loops each)
# 25.3 ms ± 1.92 ms per loop (mean ± std. dev. of 7 runs, 10 loops each)
# 921 ms ± 16.7 ms per loop (mean ± std. dev. of 7 runs, 1 loop each)
# 872 ms ± 28.2 ms per loop (mean ± std. dev. of 7 runs, 1 loop each)
# 24.5 ms ± 1.01 ms per loop (mean ± std. dev. of 7 runs, 10 loops each)
# 32.4 ms ± 2.08 ms per loop (mean ± std. dev. of 7 runs, 10 loops each)
# 1.23 s ± 37.3 ms per loop (mean ± std. dev. of 7 runs, 1 loop each)
# 1.14 s ± 21.5 ms per loop (mean ± std. dev. of 7 runs, 1 loop each)
# 30.8 ms ± 567 µs per loop (mean ± std. dev. of 7 runs, 10 loops each)
# 39.4 ms ± 372 µs per loop (mean ± std. dev. of 7 runs, 10 loops each)
# 1.58 s ± 40.3 ms per loop (mean ± std. dev. of 7 runs, 1 loop each)
# 1.46 s ± 26.5 ms per loop (mean ± std. dev. of 7 runs, 1 loop each)
# 40.5 ms ± 758 µs per loop (mean ± std. dev. of 7 runs, 10 loops each)
# 52.3 ms ± 239 µs per loop (mean ± std. dev. of 7 runs, 10 loops each)
# 2.08 s ± 25.9 ms per loop (mean ± std. dev. of 7 runs, 1 loop each)
# 1.94 s ± 32.1 ms per loop (mean ± std. dev. of 7 runs, 1 loop each)
# 71 µs ± 225 ns per loop (mean ± std. dev. of 7 runs, 10000 loops each)
# 60.1 µs ± 543 ns per loop (mean ± std. dev. of 7 runs, 10000 loops each)
# 268 µs ± 725 ns per loop (mean ± std. dev. of 7 runs, 1000 loops each)
# 225 µs ± 543 ns per loop (mean ± std. dev. of 7 runs, 1000 loops each)
# 71.1 µs ± 307 ns per loop (mean ± std. dev. of 7 runs, 10000 loops each)
# 60.1 µs ± 107 ns per loop (mean ± std. dev. of 7 runs, 10000 loops each)
# 271 µs ± 693 ns per loop (mean ± std. dev. of 7 runs, 1000 loops each)
# 224 µs ± 561 ns per loop (mean ± std. dev. of 7 runs, 1000 loops each)
# 70.5 µs ± 120 ns per loop (mean ± std. dev. of 7 runs, 10000 loops each)
# 60.1 µs ± 124 ns per loop (mean ± std. dev. of 7 runs, 10000 loops each)
# 269 µs ± 1.76 µs per loop (mean ± std. dev. of 7 runs, 1000 loops each)
# 228 µs ± 5.79 µs per loop (mean ± std. dev. of 7 runs, 1000 loops each)
# 70.5 µs ± 173 ns per loop (mean ± std. dev. of 7 runs, 10000 loops each)
# 60.2 µs ± 83.1 ns per loop (mean ± std. dev. of 7 runs, 10000 loops each)
# 270 µs ± 778 ns per loop (mean ± std. dev. of 7 runs, 1000 loops each)
# 228 µs ± 530 ns per loop (mean ± std. dev. of 7 runs, 1000 loops each)
# 71.5 µs ± 182 ns per loop (mean ± std. dev. of 7 runs, 10000 loops each)
# 60.8 µs ± 115 ns per loop (mean ± std. dev. of 7 runs, 10000 loops each)
# 287 µs ± 1.1 µs per loop (mean ± std. dev. of 7 runs, 1000 loops each)
# 235 µs ± 292 ns per loop (mean ± std. dev. of 7 runs, 1000 loops each)
# 72.1 µs ± 418 ns per loop (mean ± std. dev. of 7 runs, 10000 loops each)
# 60.6 µs ± 273 ns per loop (mean ± std. dev. of 7 runs, 10000 loops each)
# 296 µs ± 2.63 µs per loop (mean ± std. dev. of 7 runs, 1000 loops each)
# 240 µs ± 871 ns per loop (mean ± std. dev. of 7 runs, 1000 loops each)
# 71.9 µs ± 182 ns per loop (mean ± std. dev. of 7 runs, 10000 loops each)
# 61.2 µs ± 355 ns per loop (mean ± std. dev. of 7 runs, 10000 loops each)
# 300 µs ± 836 ns per loop (mean ± std. dev. of 7 runs, 1000 loops each)
# 244 µs ± 1.67 µs per loop (mean ± std. dev. of 7 runs, 1000 loops each)
# 72 µs ± 242 ns per loop (mean ± std. dev. of 7 runs, 10000 loops each)
# 61.3 µs ± 668 ns per loop (mean ± std. dev. of 7 runs, 10000 loops each)
# 317 µs ± 3.43 µs per loop (mean ± std. dev. of 7 runs, 1000 loops each)
# 249 µs ± 964 ns per loop (mean ± std. dev. of 7 runs, 1000 loops each)
# 73.2 µs ± 355 ns per loop (mean ± std. dev. of 7 runs, 10000 loops each)
# 61.6 µs ± 134 ns per loop (mean ± std. dev. of 7 runs, 10000 loops each)
# 342 µs ± 851 ns per loop (mean ± std. dev. of 7 runs, 1000 loops each)
# 256 µs ± 802 ns per loop (mean ± std. dev. of 7 runs, 1000 loops each)
# 72.5 µs ± 233 ns per loop (mean ± std. dev. of 7 runs, 10000 loops each)
# 61.3 µs ± 142 ns per loop (mean ± std. dev. of 7 runs, 10000 loops each)
# 321 µs ± 447 ns per loop (mean ± std. dev. of 7 runs, 1000 loops each)
# 251 µs ± 4.39 µs per loop (mean ± std. dev. of 7 runs, 1000 loops each)
# 73.1 µs ± 502 ns per loop (mean ± std. dev. of 7 runs, 10000 loops each)
# 62.1 µs ± 881 ns per loop (mean ± std. dev. of 7 runs, 10000 loops each)
# 335 µs ± 367 ns per loop (mean ± std. dev. of 7 runs, 1000 loops each)
# 264 µs ± 1.2 µs per loop (mean ± std. dev. of 7 runs, 1000 loops each)
# 71.9 µs ± 493 ns per loop (mean ± std. dev. of 7 runs, 10000 loops each)
# 61.1 µs ± 592 ns per loop (mean ± std. dev. of 7 runs, 10000 loops each)
# 309 µs ± 5.26 µs per loop (mean ± std. dev. of 7 runs, 1000 loops each)
# 261 µs ± 978 ns per loop (mean ± std. dev. of 7 runs, 1000 loops each)
# 74.6 µs ± 633 ns per loop (mean ± std. dev. of 7 runs, 10000 loops each)
# 63.1 µs ± 557 ns per loop (mean ± std. dev. of 7 runs, 10000 loops each)
# 323 µs ± 7.17 µs per loop (mean ± std. dev. of 7 runs, 1000 loops each)
# 279 µs ± 5.76 µs per loop (mean ± std. dev. of 7 runs, 1000 loops each)
# 76.9 µs ± 1.96 µs per loop (mean ± std. dev. of 7 runs, 10000 loops each)
# 64.5 µs ± 2.15 µs per loop (mean ± std. dev. of 7 runs, 10000 loops each)
# 341 µs ± 8.25 µs per loop (mean ± std. dev. of 7 runs, 1000 loops each)
# 289 µs ± 6.79 µs per loop (mean ± std. dev. of 7 runs, 1000 loops each)
# 75.3 µs ± 2.24 µs per loop (mean ± std. dev. of 7 runs, 10000 loops each)
# 63.6 µs ± 902 ns per loop (mean ± std. dev. of 7 runs, 10000 loops each)
# 339 µs ± 7.59 µs per loop (mean ± std. dev. of 7 runs, 1000 loops each)
# 300 µs ± 5.4 µs per loop (mean ± std. dev. of 7 runs, 1000 loops each)
# 75.9 µs ± 797 ns per loop (mean ± std. dev. of 7 runs, 10000 loops each)
# 64.4 µs ± 2.01 µs per loop (mean ± std. dev. of 7 runs, 10000 loops each)
# 361 µs ± 12.8 µs per loop (mean ± std. dev. of 7 runs, 1000 loops each)
# 323 µs ± 3.47 µs per loop (mean ± std. dev. of 7 runs, 1000 loops each)
# 74.9 µs ± 493 ns per loop (mean ± std. dev. of 7 runs, 10000 loops each)
# 64.1 µs ± 581 ns per loop (mean ± std. dev. of 7 runs, 10000 loops each)
# 361 µs ± 9.64 µs per loop (mean ± std. dev. of 7 runs, 1000 loops each)
# 347 µs ± 2.58 µs per loop (mean ± std. dev. of 7 runs, 1000 loops each)
# 75.4 µs ± 615 ns per loop (mean ± std. dev. of 7 runs, 10000 loops each)
# 66.3 µs ± 404 ns per loop (mean ± std. dev. of 7 runs, 10000 loops each)
# 374 µs ± 2.77 µs per loop (mean ± std. dev. of 7 runs, 1000 loops each)
# 376 µs ± 1.26 µs per loop (mean ± std. dev. of 7 runs, 1000 loops each)
# 74.2 µs ± 176 ns per loop (mean ± std. dev. of 7 runs, 10000 loops each)
# 65.3 µs ± 727 ns per loop (mean ± std. dev. of 7 runs, 10000 loops each)
# 404 µs ± 3.05 µs per loop (mean ± std. dev. of 7 runs, 1000 loops each)
# 431 µs ± 5.4 µs per loop (mean ± std. dev. of 7 runs, 1000 loops each)
# 77.4 µs ± 791 ns per loop (mean ± std. dev. of 7 runs, 10000 loops each)
# 66.3 µs ± 68.1 ns per loop (mean ± std. dev. of 7 runs, 10000 loops each)
# 437 µs ± 923 ns per loop (mean ± std. dev. of 7 runs, 1000 loops each)
# 496 µs ± 8.51 µs per loop (mean ± std. dev. of 7 runs, 1000 loops each)
# 74.7 µs ± 204 ns per loop (mean ± std. dev. of 7 runs, 10000 loops each)
# 67 µs ± 491 ns per loop (mean ± std. dev. of 7 runs, 10000 loops each)
# 475 µs ± 3.59 µs per loop (mean ± std. dev. of 7 runs, 1000 loops each)
# 578 µs ± 5.48 µs per loop (mean ± std. dev. of 7 runs, 1000 loops each)
# 77.8 µs ± 284 ns per loop (mean ± std. dev. of 7 runs, 10000 loops each)
# 69.8 µs ± 511 ns per loop (mean ± std. dev. of 7 runs, 10000 loops each)
# 524 µs ± 9.37 µs per loop (mean ± std. dev. of 7 runs, 1000 loops each)
# 717 µs ± 26.8 µs per loop (mean ± std. dev. of 7 runs, 1000 loops each)
# 77.7 µs ± 1.14 µs per loop (mean ± std. dev. of 7 runs, 10000 loops each)
# 73.2 µs ± 850 ns per loop (mean ± std. dev. of 7 runs, 10000 loops each)
# 597 µs ± 13.5 µs per loop (mean ± std. dev. of 7 runs, 1000 loops each)
# 854 µs ± 19.9 µs per loop (mean ± std. dev. of 7 runs, 1000 loops each)
# 79.3 µs ± 764 ns per loop (mean ± std. dev. of 7 runs, 10000 loops each)
# 75.2 µs ± 534 ns per loop (mean ± std. dev. of 7 runs, 10000 loops each)
# 684 µs ± 13 µs per loop (mean ± std. dev. of 7 runs, 1000 loops each)
# 1.03 ms ± 15.7 µs per loop (mean ± std. dev. of 7 runs, 1000 loops each)
# 83.4 µs ± 854 ns per loop (mean ± std. dev. of 7 runs, 10000 loops each)
# 81.6 µs ± 1.03 µs per loop (mean ± std. dev. of 7 runs, 10000 loops each)
# 818 µs ± 22.9 µs per loop (mean ± std. dev. of 7 runs, 1000 loops each)
# 1.33 ms ± 11.2 µs per loop (mean ± std. dev. of 7 runs, 1000 loops each)
# 87.3 µs ± 1.22 µs per loop (mean ± std. dev. of 7 runs, 10000 loops each)
# 86.6 µs ± 353 ns per loop (mean ± std. dev. of 7 runs, 10000 loops each)
# 1.01 ms ± 23.6 µs per loop (mean ± std. dev. of 7 runs, 1000 loops each)
# 1.79 ms ± 56 µs per loop (mean ± std. dev. of 7 runs, 1000 loops each)
# 92 µs ± 1.7 µs per loop (mean ± std. dev. of 7 runs, 10000 loops each)
# 101 µs ± 6.77 µs per loop (mean ± std. dev. of 7 runs, 10000 loops each)
# 1.25 ms ± 23.6 µs per loop (mean ± std. dev. of 7 runs, 1000 loops each)
# 2.35 ms ± 31 µs per loop (mean ± std. dev. of 7 runs, 100 loops each)
# 93.9 µs ± 583 ns per loop (mean ± std. dev. of 7 runs, 10000 loops each)
# 106 µs ± 1.11 µs per loop (mean ± std. dev. of 7 runs, 10000 loops each)
# 1.53 ms ± 44.9 µs per loop (mean ± std. dev. of 7 runs, 1000 loops each)
# 2.87 ms ± 4.28 µs per loop (mean ± std. dev. of 7 runs, 100 loops each)
# 104 µs ± 940 ns per loop (mean ± std. dev. of 7 runs, 10000 loops each)
# 121 µs ± 131 ns per loop (mean ± std. dev. of 7 runs, 10000 loops each)
# 1.97 ms ± 3.7 µs per loop (mean ± std. dev. of 7 runs, 1000 loops each)
# 3.94 ms ± 44.6 µs per loop (mean ± std. dev. of 7 runs, 100 loops each)
# 113 µs ± 364 ns per loop (mean ± std. dev. of 7 runs, 10000 loops each)
# 140 µs ± 349 ns per loop (mean ± std. dev. of 7 runs, 10000 loops each)
# 2.72 ms ± 29.5 µs per loop (mean ± std. dev. of 7 runs, 100 loops each)
# 5.22 ms ± 19.8 µs per loop (mean ± std. dev. of 7 runs, 100 loops each)
# 125 µs ± 121 ns per loop (mean ± std. dev. of 7 runs, 10000 loops each)
# 166 µs ± 152 ns per loop (mean ± std. dev. of 7 runs, 10000 loops each)
# 3.69 ms ± 23.3 µs per loop (mean ± std. dev. of 7 runs, 100 loops each)
# 6.88 ms ± 40.6 µs per loop (mean ± std. dev. of 7 runs, 100 loops each)
# 144 µs ± 110 ns per loop (mean ± std. dev. of 7 runs, 10000 loops each)
# 203 µs ± 6.11 µs per loop (mean ± std. dev. of 7 runs, 1000 loops each)
# 5.13 ms ± 23.5 µs per loop (mean ± std. dev. of 7 runs, 100 loops each)
# 9.15 ms ± 45.9 µs per loop (mean ± std. dev. of 7 runs, 100 loops each)
# 168 µs ± 243 ns per loop (mean ± std. dev. of 7 runs, 10000 loops each)
# 243 µs ± 726 ns per loop (mean ± std. dev. of 7 runs, 1000 loops each)
# 6.81 ms ± 31.4 µs per loop (mean ± std. dev. of 7 runs, 100 loops each)
# 12.1 ms ± 70.1 µs per loop (mean ± std. dev. of 7 runs, 100 loops each)
# 195 µs ± 259 ns per loop (mean ± std. dev. of 7 runs, 10000 loops each)
# 299 µs ± 951 ns per loop (mean ± std. dev. of 7 runs, 1000 loops each)
# 9.11 ms ± 152 µs per loop (mean ± std. dev. of 7 runs, 100 loops each)
# 16 ms ± 128 µs per loop (mean ± std. dev. of 7 runs, 100 loops each)
# 233 µs ± 448 ns per loop (mean ± std. dev. of 7 runs, 1000 loops each)
# 375 µs ± 3.47 µs per loop (mean ± std. dev. of 7 runs, 1000 loops each)
# 12.4 ms ± 138 µs per loop (mean ± std. dev. of 7 runs, 100 loops each)
# 21.1 ms ± 622 µs per loop (mean ± std. dev. of 7 runs, 10 loops each)
# 294 µs ± 2.56 µs per loop (mean ± std. dev. of 7 runs, 1000 loops each)
# 485 µs ± 8.57 µs per loop (mean ± std. dev. of 7 runs, 1000 loops each)
# 16.8 ms ± 232 µs per loop (mean ± std. dev. of 7 runs, 100 loops each)
# 27.6 ms ± 611 µs per loop (mean ± std. dev. of 7 runs, 10 loops each)
# 427 µs ± 29 µs per loop (mean ± std. dev. of 7 runs, 1000 loops each)
# 627 µs ± 12.1 µs per loop (mean ± std. dev. of 7 runs, 1000 loops each)
# 24 ms ± 615 µs per loop (mean ± std. dev. of 7 runs, 10 loops each)
# 37.5 ms ± 1.01 ms per loop (mean ± std. dev. of 7 runs, 10 loops each)
# 561 µs ± 38.2 µs per loop (mean ± std. dev. of 7 runs, 1000 loops each)
# 816 µs ± 15.8 µs per loop (mean ± std. dev. of 7 runs, 1000 loops each)
# 31.8 ms ± 719 µs per loop (mean ± std. dev. of 7 runs, 10 loops each)
# 48.6 ms ± 1.12 ms per loop (mean ± std. dev. of 7 runs, 10 loops each)
# 862 µs ± 36.2 µs per loop (mean ± std. dev. of 7 runs, 1000 loops each)
# 1.07 ms ± 29.7 µs per loop (mean ± std. dev. of 7 runs, 1000 loops each)
# 44.2 ms ± 1.08 ms per loop (mean ± std. dev. of 7 runs, 10 loops each)
# 71.3 ms ± 1.26 ms per loop (mean ± std. dev. of 7 runs, 10 loops each)
# 1.23 ms ± 30 µs per loop (mean ± std. dev. of 7 runs, 1000 loops each)
# 1.39 ms ± 30.1 µs per loop (mean ± std. dev. of 7 runs, 1000 loops each)
# 61.5 ms ± 2.92 ms per loop (mean ± std. dev. of 7 runs, 10 loops each)
# 99.2 ms ± 1.26 ms per loop (mean ± std. dev. of 7 runs, 10 loops each)
# 1.6 ms ± 32.1 µs per loop (mean ± std. dev. of 7 runs, 1000 loops each)
# 1.85 ms ± 13.6 µs per loop (mean ± std. dev. of 7 runs, 1000 loops each)
# 90.8 ms ± 2.68 ms per loop (mean ± std. dev. of 7 runs, 10 loops each)
# 167 ms ± 651 µs per loop (mean ± std. dev. of 7 runs, 10 loops each)
# 2.18 ms ± 34.2 µs per loop (mean ± std. dev. of 7 runs, 100 loops each)
# 2.56 ms ± 8.76 µs per loop (mean ± std. dev. of 7 runs, 100 loops each)
# 129 ms ± 4.95 ms per loop (mean ± std. dev. of 7 runs, 10 loops each)
# 223 ms ± 4.08 ms per loop (mean ± std. dev. of 7 runs, 1 loop each)
# 8.89 ms ± 874 µs per loop (mean ± std. dev. of 7 runs, 100 loops each)
# 7.69 ms ± 128 µs per loop (mean ± std. dev. of 7 runs, 100 loops each)
# 468 ms ± 14.2 ms per loop (mean ± std. dev. of 7 runs, 1 loop each)
# 362 ms ± 3.97 ms per loop (mean ± std. dev. of 7 runs, 1 loop each)
# 13 ms ± 243 µs per loop (mean ± std. dev. of 7 runs, 100 loops each)
# 10.8 ms ± 113 µs per loop (mean ± std. dev. of 7 runs, 100 loops each)
# 626 ms ± 18 ms per loop (mean ± std. dev. of 7 runs, 1 loop each)
# 491 ms ± 3.07 ms per loop (mean ± std. dev. of 7 runs, 1 loop each)
# 18.2 ms ± 331 µs per loop (mean ± std. dev. of 7 runs, 100 loops each)
# 14.5 ms ± 239 µs per loop (mean ± std. dev. of 7 runs, 100 loops each)
# 835 ms ± 25.1 ms per loop (mean ± std. dev. of 7 runs, 1 loop each)
# 661 ms ± 15.7 ms per loop (mean ± std. dev. of 7 runs, 1 loop each)
# 24.4 ms ± 2.3 ms per loop (mean ± std. dev. of 7 runs, 10 loops each)
# 18.7 ms ± 202 µs per loop (mean ± std. dev. of 7 runs, 100 loops each)
# 1.15 s ± 12.5 ms per loop (mean ± std. dev. of 7 runs, 1 loop each)
# 891 ms ± 25.5 ms per loop (mean ± std. dev. of 7 runs, 1 loop each)
# 31.3 ms ± 2.56 ms per loop (mean ± std. dev. of 7 runs, 10 loops each)
# 23.7 ms ± 1.41 ms per loop (mean ± std. dev. of 7 runs, 10 loops each)
# 1.53 s ± 45.6 ms per loop (mean ± std. dev. of 7 runs, 1 loop each)
# 1.17 s ± 26.6 ms per loop (mean ± std. dev. of 7 runs, 1 loop each)
# 41.5 ms ± 2.26 ms per loop (mean ± std. dev. of 7 runs, 10 loops each)
# 31.3 ms ± 675 µs per loop (mean ± std. dev. of 7 runs, 10 loops each)
# 2.01 s ± 11.3 ms per loop (mean ± std. dev. of 7 runs, 1 loop each)
# 1.54 s ± 26.1 ms per loop (mean ± std. dev. of 7 runs, 1 loop each)
# 56.7 ms ± 4.26 ms per loop (mean ± std. dev. of 7 runs, 10 loops each)
# 42.1 ms ± 1.67 ms per loop (mean ± std. dev. of 7 runs, 10 loops each)
# 2.76 s ± 81.2 ms per loop (mean ± std. dev. of 7 runs, 1 loop each)
# 2.04 s ± 28.6 ms per loop (mean ± std. dev. of 7 runs, 1 loop each)
# 74.3 ms ± 3.5 ms per loop (mean ± std. dev. of 7 runs, 10 loops each)
# 54.6 ms ± 989 µs per loop (mean ± std. dev. of 7 runs, 10 loops each)
# 3.38 s ± 50.1 ms per loop (mean ± std. dev. of 7 runs, 1 loop each)
# 2.6 s ± 26.9 ms per loop (mean ± std. dev. of 7 runs, 1 loop each)
# 80.9 µs ± 210 ns per loop (mean ± std. dev. of 7 runs, 10000 loops each)
# 60.1 µs ± 169 ns per loop (mean ± std. dev. of 7 runs, 10000 loops each)
# 408 µs ± 558 ns per loop (mean ± std. dev. of 7 runs, 1000 loops each)
# 284 µs ± 649 ns per loop (mean ± std. dev. of 7 runs, 1000 loops each)
# 82 µs ± 1.16 µs per loop (mean ± std. dev. of 7 runs, 10000 loops each)
# 60.7 µs ± 236 ns per loop (mean ± std. dev. of 7 runs, 10000 loops each)
# 412 µs ± 461 ns per loop (mean ± std. dev. of 7 runs, 1000 loops each)
# 284 µs ± 603 ns per loop (mean ± std. dev. of 7 runs, 1000 loops each)
# 81 µs ± 68 ns per loop (mean ± std. dev. of 7 runs, 10000 loops each)
# 60 µs ± 124 ns per loop (mean ± std. dev. of 7 runs, 10000 loops each)
# 408 µs ± 829 ns per loop (mean ± std. dev. of 7 runs, 1000 loops each)
# 287 µs ± 2.21 µs per loop (mean ± std. dev. of 7 runs, 1000 loops each)
# 81.6 µs ± 277 ns per loop (mean ± std. dev. of 7 runs, 10000 loops each)
# 60.3 µs ± 114 ns per loop (mean ± std. dev. of 7 runs, 10000 loops each)
# 410 µs ± 1 µs per loop (mean ± std. dev. of 7 runs, 1000 loops each)
# 291 µs ± 1.66 µs per loop (mean ± std. dev. of 7 runs, 1000 loops each)
# 82.4 µs ± 277 ns per loop (mean ± std. dev. of 7 runs, 10000 loops each)
# 60.5 µs ± 375 ns per loop (mean ± std. dev. of 7 runs, 10000 loops each)
# 446 µs ± 2.02 µs per loop (mean ± std. dev. of 7 runs, 1000 loops each)
# 302 µs ± 1.71 µs per loop (mean ± std. dev. of 7 runs, 1000 loops each)
# 82.9 µs ± 302 ns per loop (mean ± std. dev. of 7 runs, 10000 loops each)
# 60.4 µs ± 174 ns per loop (mean ± std. dev. of 7 runs, 10000 loops each)
# 465 µs ± 5 µs per loop (mean ± std. dev. of 7 runs, 1000 loops each)
# 308 µs ± 533 ns per loop (mean ± std. dev. of 7 runs, 1000 loops each)
# 83.4 µs ± 331 ns per loop (mean ± std. dev. of 7 runs, 10000 loops each)
# 60.4 µs ± 178 ns per loop (mean ± std. dev. of 7 runs, 10000 loops each)
# 477 µs ± 2.19 µs per loop (mean ± std. dev. of 7 runs, 1000 loops each)
# 315 µs ± 4.48 µs per loop (mean ± std. dev. of 7 runs, 1000 loops each)
# 84.3 µs ± 281 ns per loop (mean ± std. dev. of 7 runs, 10000 loops each)
# 61 µs ± 607 ns per loop (mean ± std. dev. of 7 runs, 10000 loops each)
# 497 µs ± 939 ns per loop (mean ± std. dev. of 7 runs, 1000 loops each)
# 326 µs ± 3.27 µs per loop (mean ± std. dev. of 7 runs, 1000 loops each)
# 87.7 µs ± 527 ns per loop (mean ± std. dev. of 7 runs, 10000 loops each)
# 62 µs ± 339 ns per loop (mean ± std. dev. of 7 runs, 10000 loops each)
# 542 µs ± 1.46 µs per loop (mean ± std. dev. of 7 runs, 1000 loops each)
# 332 µs ± 644 ns per loop (mean ± std. dev. of 7 runs, 1000 loops each)
# 84.6 µs ± 107 ns per loop (mean ± std. dev. of 7 runs, 10000 loops each)
# 61.2 µs ± 197 ns per loop (mean ± std. dev. of 7 runs, 10000 loops each)
# 519 µs ± 3.1 µs per loop (mean ± std. dev. of 7 runs, 1000 loops each)
# 332 µs ± 3.29 µs per loop (mean ± std. dev. of 7 runs, 1000 loops each)
# 85.4 µs ± 363 ns per loop (mean ± std. dev. of 7 runs, 10000 loops each)
# 61.1 µs ± 121 ns per loop (mean ± std. dev. of 7 runs, 10000 loops each)
# 547 µs ± 881 ns per loop (mean ± std. dev. of 7 runs, 1000 loops each)
# 346 µs ± 5.98 µs per loop (mean ± std. dev. of 7 runs, 1000 loops each)
# 85.9 µs ± 372 ns per loop (mean ± std. dev. of 7 runs, 10000 loops each)
# 63.1 µs ± 112 ns per loop (mean ± std. dev. of 7 runs, 10000 loops each)
# 467 µs ± 622 ns per loop (mean ± std. dev. of 7 runs, 1000 loops each)
# 336 µs ± 347 ns per loop (mean ± std. dev. of 7 runs, 1000 loops each)
# 86.8 µs ± 71.8 ns per loop (mean ± std. dev. of 7 runs, 10000 loops each)
# 61.6 µs ± 126 ns per loop (mean ± std. dev. of 7 runs, 10000 loops each)
# 493 µs ± 2.96 µs per loop (mean ± std. dev. of 7 runs, 1000 loops each)
# 351 µs ± 541 ns per loop (mean ± std. dev. of 7 runs, 1000 loops each)
# 86.9 µs ± 446 ns per loop (mean ± std. dev. of 7 runs, 10000 loops each)
# 64.4 µs ± 156 ns per loop (mean ± std. dev. of 7 runs, 10000 loops each)
# 510 µs ± 1.19 µs per loop (mean ± std. dev. of 7 runs, 1000 loops each)
# 377 µs ± 2.78 µs per loop (mean ± std. dev. of 7 runs, 1000 loops each)
# 86.5 µs ± 255 ns per loop (mean ± std. dev. of 7 runs, 10000 loops each)
# 62.5 µs ± 275 ns per loop (mean ± std. dev. of 7 runs, 10000 loops each)
# 533 µs ± 360 ns per loop (mean ± std. dev. of 7 runs, 1000 loops each)
# 400 µs ± 259 ns per loop (mean ± std. dev. of 7 runs, 1000 loops each)
# 87.8 µs ± 119 ns per loop (mean ± std. dev. of 7 runs, 10000 loops each)
# 62.1 µs ± 208 ns per loop (mean ± std. dev. of 7 runs, 10000 loops each)
# 572 µs ± 2.61 µs per loop (mean ± std. dev. of 7 runs, 1000 loops each)
# 435 µs ± 587 ns per loop (mean ± std. dev. of 7 runs, 1000 loops each)
# 86 µs ± 166 ns per loop (mean ± std. dev. of 7 runs, 10000 loops each)
# 63 µs ± 313 ns per loop (mean ± std. dev. of 7 runs, 10000 loops each)
# 585 µs ± 1.49 µs per loop (mean ± std. dev. of 7 runs, 1000 loops each)
# 479 µs ± 954 ns per loop (mean ± std. dev. of 7 runs, 1000 loops each)
# 91 µs ± 84.4 ns per loop (mean ± std. dev. of 7 runs, 10000 loops each)
# ...
# 3.38 s ± 11.1 ms per loop (mean ± std. dev. of 7 runs, 1 loop each)
# 2.2 s ± 12.1 ms per loop (mean ± std. dev. of 7 runs, 1 loop each)
# 65.9 ms ± 2.38 ms per loop (mean ± std. dev. of 7 runs, 10 loops each)
# 59.7 ms ± 1.35 ms per loop (mean ± std. dev. of 7 runs, 10 loops each)
# 4.61 s ± 63.4 ms per loop (mean ± std. dev. of 7 runs, 1 loop each)
# 3.04 s ± 27 ms per loop (mean ± std. dev. of 7 runs, 1 loop each)
# 91.2 ms ± 3.16 ms per loop (mean ± std. dev. of 7 runs, 10 loops each)
# 81.4 ms ± 1.83 ms per loop (mean ± std. dev. of 7 runs, 10 loops each)
# 6.28 s ± 53.1 ms per loop (mean ± std. dev. of 7 runs, 1 loop each)
# 4.08 s ± 35 ms per loop (mean ± std. dev. of 7 runs, 1 loop each)
# 119 ms ± 3.54 ms per loop (mean ± std. dev. of 7 runs, 10 loops each)
# 107 ms ± 807 µs per loop (mean ± std. dev. of 7 runs, 10 loops each)
# 8.23 s ± 28.6 ms per loop (mean ± std. dev. of 7 runs, 1 loop each)
# 5.32 s ± 54.1 ms per loop (mean ± std. dev. of 7 runs, 1 loop each)
# 159 ms ± 1.95 ms per loop (mean ± std. dev. of 7 runs, 10 loops each)
# 142 ms ± 1.03 ms per loop (mean ± std. dev. of 7 runs, 10 loops each)
# 11.1 s ± 50.3 ms per loop (mean ± std. dev. of 7 runs, 1 loop each)
# 7.07 s ± 27.7 ms per loop (mean ± std. dev. of 7 runs, 1 loop each)
# 224 ms ± 7.93 ms per loop (mean ± std. dev. of 7 runs, 1 loop each)
# 189 ms ± 2.47 ms per loop (mean ± std. dev. of 7 runs, 10 loops each)
# 14.7 s ± 141 ms per loop (mean ± std. dev. of 7 runs, 1 loop each)
# 9.59 s ± 29.4 ms per loop (mean ± std. dev. of 7 runs, 1 loop each)
# 288 ms ± 1.48 ms per loop (mean ± std. dev. of 7 runs, 1 loop each)
# 237 ms ± 4.03 ms per loop (mean ± std. dev. of 7 runs, 1 loop each)
# 19.1 s ± 65.7 ms per loop (mean ± std. dev. of 7 runs, 1 loop each)
# 12.5 s ± 67.5 ms per loop (mean ± std. dev. of 7 runs, 1 loop each)
# 137 µs ± 134 ns per loop (mean ± std. dev. of 7 runs, 10000 loops each)
# 73.2 µs ± 243 ns per loop (mean ± std. dev. of 7 runs, 10000 loops each)
# 1.7 ms ± 2.85 µs per loop (mean ± std. dev. of 7 runs, 1000 loops each)
# 807 µs ± 1.25 µs per loop (mean ± std. dev. of 7 runs, 1000 loops each)
# 138 µs ± 170 ns per loop (mean ± std. dev. of 7 runs, 10000 loops each)
# 72.5 µs ± 121 ns per loop (mean ± std. dev. of 7 runs, 10000 loops each)
# 1.7 ms ± 4.85 µs per loop (mean ± std. dev. of 7 runs, 1000 loops each)
# 803 µs ± 1.32 µs per loop (mean ± std. dev. of 7 runs, 1000 loops each)
# 137 µs ± 203 ns per loop (mean ± std. dev. of 7 runs, 10000 loops each)
# 72.6 µs ± 205 ns per loop (mean ± std. dev. of 7 runs, 10000 loops each)
# 1.7 ms ± 3.8 µs per loop (mean ± std. dev. of 7 runs, 1000 loops each)
# 805 µs ± 785 ns per loop (mean ± std. dev. of 7 runs, 1000 loops each)
# 139 µs ± 184 ns per loop (mean ± std. dev. of 7 runs, 10000 loops each)
# 73.7 µs ± 344 ns per loop (mean ± std. dev. of 7 runs, 10000 loops each)
# 1.7 ms ± 2.77 µs per loop (mean ± std. dev. of 7 runs, 1000 loops each)
# 829 µs ± 1.65 µs per loop (mean ± std. dev. of 7 runs, 1000 loops each)
# 143 µs ± 494 ns per loop (mean ± std. dev. of 7 runs, 10000 loops each)
# 75.3 µs ± 377 ns per loop (mean ± std. dev. of 7 runs, 10000 loops each)
# 1.9 ms ± 3.44 µs per loop (mean ± std. dev. of 7 runs, 1000 loops each)
# 880 µs ± 4.61 µs per loop (mean ± std. dev. of 7 runs, 1000 loops each)
# 145 µs ± 1.18 µs per loop (mean ± std. dev. of 7 runs, 10000 loops each)
# 77.3 µs ± 607 ns per loop (mean ± std. dev. of 7 runs, 10000 loops each)
# 2.04 ms ± 23.5 µs per loop (mean ± std. dev. of 7 runs, 100 loops each)
# 947 µs ± 2.85 µs per loop (mean ± std. dev. of 7 runs, 1000 loops each)
# 146 µs ± 549 ns per loop (mean ± std. dev. of 7 runs, 10000 loops each)
# 76.6 µs ± 1.47 µs per loop (mean ± std. dev. of 7 runs, 10000 loops each)
# 2.08 ms ± 28.2 µs per loop (mean ± std. dev. of 7 runs, 100 loops each)
# 943 µs ± 5.98 µs per loop (mean ± std. dev. of 7 runs, 1000 loops each)
# 149 µs ± 1.02 µs per loop (mean ± std. dev. of 7 runs, 10000 loops each)
# 77.5 µs ± 123 ns per loop (mean ± std. dev. of 7 runs, 10000 loops each)
# 2.21 ms ± 32.2 µs per loop (mean ± std. dev. of 7 runs, 100 loops each)
# 983 µs ± 7.53 µs per loop (mean ± std. dev. of 7 runs, 1000 loops each)
# 152 µs ± 570 ns per loop (mean ± std. dev. of 7 runs, 10000 loops each)
# 78.9 µs ± 161 ns per loop (mean ± std. dev. of 7 runs, 10000 loops each)
# 2.41 ms ± 32.4 µs per loop (mean ± std. dev. of 7 runs, 100 loops each)
# 1.01 ms ± 5.69 µs per loop (mean ± std. dev. of 7 runs, 1000 loops each)
# 151 µs ± 977 ns per loop (mean ± std. dev. of 7 runs, 10000 loops each)
# 77.9 µs ± 81.3 ns per loop (mean ± std. dev. of 7 runs, 10000 loops each)
# 2.28 ms ± 4.89 µs per loop (mean ± std. dev. of 7 runs, 100 loops each)
# 994 µs ± 1.95 µs per loop (mean ± std. dev. of 7 runs, 1000 loops each)
# 152 µs ± 210 ns per loop (mean ± std. dev. of 7 runs, 10000 loops each)
# 78.1 µs ± 111 ns per loop (mean ± std. dev. of 7 runs, 10000 loops each)
# 2.46 ms ± 75.2 µs per loop (mean ± std. dev. of 7 runs, 100 loops each)
# 1.05 ms ± 2.06 µs per loop (mean ± std. dev. of 7 runs, 1000 loops each)
# 148 µs ± 251 ns per loop (mean ± std. dev. of 7 runs, 10000 loops each)
# 77.7 µs ± 318 ns per loop (mean ± std. dev. of 7 runs, 10000 loops each)
# 2 ms ± 2.89 µs per loop (mean ± std. dev. of 7 runs, 1000 loops each)
# 1.03 ms ± 2.06 µs per loop (mean ± std. dev. of 7 runs, 1000 loops each)
# 151 µs ± 335 ns per loop (mean ± std. dev. of 7 runs, 10000 loops each)
# 77.9 µs ± 113 ns per loop (mean ± std. dev. of 7 runs, 10000 loops each)
# 2.13 ms ± 5.4 µs per loop (mean ± std. dev. of 7 runs, 100 loops each)
# 1.1 ms ± 1.57 µs per loop (mean ± std. dev. of 7 runs, 1000 loops each)
# 154 µs ± 321 ns per loop (mean ± std. dev. of 7 runs, 10000 loops each)
# 78.9 µs ± 53.4 ns per loop (mean ± std. dev. of 7 runs, 10000 loops each)
# 2.27 ms ± 5.8 µs per loop (mean ± std. dev. of 7 runs, 100 loops each)
# 1.22 ms ± 1.15 µs per loop (mean ± std. dev. of 7 runs, 1000 loops each)
# 156 µs ± 404 ns per loop (mean ± std. dev. of 7 runs, 10000 loops each)
# 79.9 µs ± 95.1 ns per loop (mean ± std. dev. of 7 runs, 10000 loops each)
# 2.31 ms ± 7.18 µs per loop (mean ± std. dev. of 7 runs, 100 loops each)
# 1.32 ms ± 2.48 µs per loop (mean ± std. dev. of 7 runs, 1000 loops each)
# 160 µs ± 172 ns per loop (mean ± std. dev. of 7 runs, 10000 loops each)
# 81.1 µs ± 191 ns per loop (mean ± std. dev. of 7 runs, 10000 loops each)
# 2.47 ms ± 16 µs per loop (mean ± std. dev. of 7 runs, 100 loops each)
# 1.48 ms ± 2.97 µs per loop (mean ± std. dev. of 7 runs, 1000 loops each)
# 166 µs ± 289 ns per loop (mean ± std. dev. of 7 runs, 10000 loops each)
# 84.1 µs ± 298 ns per loop (mean ± std. dev. of 7 runs, 10000 loops each)
# 2.62 ms ± 9.06 µs per loop (mean ± std. dev. of 7 runs, 100 loops each)
# 1.7 ms ± 4.21 µs per loop (mean ± std. dev. of 7 runs, 1000 loops each)
# 173 µs ± 184 ns per loop (mean ± std. dev. of 7 runs, 10000 loops each)
# 86.6 µs ± 1.46 µs per loop (mean ± std. dev. of 7 runs, 10000 loops each)
# 2.83 ms ± 6.07 µs per loop (mean ± std. dev. of 7 runs, 100 loops each)
# 1.99 ms ± 4.79 µs per loop (mean ± std. dev. of 7 runs, 1000 loops each)
# 183 µs ± 334 ns per loop (mean ± std. dev. of 7 runs, 10000 loops each)
# 90 µs ± 92.8 ns per loop (mean ± std. dev. of 7 runs, 10000 loops each)
# 3.1 ms ± 8.77 µs per loop (mean ± std. dev. of 7 runs, 100 loops each)
# 2.41 ms ± 18.7 µs per loop (mean ± std. dev. of 7 runs, 100 loops each)
# 195 µs ± 190 ns per loop (mean ± std. dev. of 7 runs, 10000 loops each)
# 94 µs ± 143 ns per loop (mean ± std. dev. of 7 runs, 10000 loops each)
# 3.43 ms ± 15.3 µs per loop (mean ± std. dev. of 7 runs, 100 loops each)
# 3.03 ms ± 10.6 µs per loop (mean ± std. dev. of 7 runs, 100 loops each)
# 214 µs ± 2.09 µs per loop (mean ± std. dev. of 7 runs, 1000 loops each)
# 101 µs ± 453 ns per loop (mean ± std. dev. of 7 runs, 10000 loops each)
# 3.85 ms ± 26.9 µs per loop (mean ± std. dev. of 7 runs, 100 loops each)
# 3.85 ms ± 29.8 µs per loop (mean ± std. dev. of 7 runs, 100 loops each)
# 233 µs ± 427 ns per loop (mean ± std. dev. of 7 runs, 1000 loops each)
# 108 µs ± 282 ns per loop (mean ± std. dev. of 7 runs, 10000 loops each)
# 4.54 ms ± 23.5 µs per loop (mean ± std. dev. of 7 runs, 100 loops each)
# 4.9 ms ± 34 µs per loop (mean ± std. dev. of 7 runs, 100 loops each)
# 267 µs ± 1.1 µs per loop (mean ± std. dev. of 7 runs, 1000 loops each)
# 119 µs ± 109 ns per loop (mean ± std. dev. of 7 runs, 10000 loops each)
# 5.36 ms ± 21.1 µs per loop (mean ± std. dev. of 7 runs, 100 loops each)
# 6.25 ms ± 107 µs per loop (mean ± std. dev. of 7 runs, 100 loops each)
# 303 µs ± 730 ns per loop (mean ± std. dev. of 7 runs, 1000 loops each)
# 134 µs ± 258 ns per loop (mean ± std. dev. of 7 runs, 10000 loops each)
# 6.49 ms ± 20.1 µs per loop (mean ± std. dev. of 7 runs, 100 loops each)
# 7.92 ms ± 26.7 µs per loop (mean ± std. dev. of 7 runs, 100 loops each)
# 354 µs ± 730 ns per loop (mean ± std. dev. of 7 runs, 1000 loops each)
# 151 µs ± 386 ns per loop (mean ± std. dev. of 7 runs, 10000 loops each)
# 8.31 ms ± 168 µs per loop (mean ± std. dev. of 7 runs, 100 loops each)
# 10.5 ms ± 126 µs per loop (mean ± std. dev. of 7 runs, 100 loops each)
# 424 µs ± 1.42 µs per loop (mean ± std. dev. of 7 runs, 1000 loops each)
# 176 µs ± 323 ns per loop (mean ± std. dev. of 7 runs, 10000 loops each)
# 10.5 ms ± 61.3 µs per loop (mean ± std. dev. of 7 runs, 100 loops each)
# 13.9 ms ± 81.8 µs per loop (mean ± std. dev. of 7 runs, 100 loops each)
# 518 µs ± 2.98 µs per loop (mean ± std. dev. of 7 runs, 1000 loops each)
# 210 µs ± 716 ns per loop (mean ± std. dev. of 7 runs, 1000 loops each)
# 13.2 ms ± 67.4 µs per loop (mean ± std. dev. of 7 runs, 100 loops each)
# 18.5 ms ± 107 µs per loop (mean ± std. dev. of 7 runs, 100 loops each)
# 662 µs ± 6.46 µs per loop (mean ± std. dev. of 7 runs, 1000 loops each)
# 251 µs ± 711 ns per loop (mean ± std. dev. of 7 runs, 1000 loops each)
# 16.7 ms ± 56.7 µs per loop (mean ± std. dev. of 7 runs, 100 loops each)
# 23.9 ms ± 141 µs per loop (mean ± std. dev. of 7 runs, 10 loops each)
# 1.12 ms ± 9.39 µs per loop (mean ± std. dev. of 7 runs, 1000 loops each)
# 409 µs ± 3.76 µs per loop (mean ± std. dev. of 7 runs, 1000 loops each)
# 41.7 ms ± 1.18 ms per loop (mean ± std. dev. of 7 runs, 10 loops each)
# 38.7 ms ± 574 µs per loop (mean ± std. dev. of 7 runs, 10 loops each)
# 1.27 ms ± 32 µs per loop (mean ± std. dev. of 7 runs, 1000 loops each)
# 478 µs ± 1.62 µs per loop (mean ± std. dev. of 7 runs, 1000 loops each)
# 46.7 ms ± 1.25 ms per loop (mean ± std. dev. of 7 runs, 10 loops each)
# 48.4 ms ± 819 µs per loop (mean ± std. dev. of 7 runs, 10 loops each)
# 1.8 ms ± 37.4 µs per loop (mean ± std. dev. of 7 runs, 1000 loops each)
# 614 µs ± 1.46 µs per loop (mean ± std. dev. of 7 runs, 1000 loops each)
# 69.6 ms ± 894 µs per loop (mean ± std. dev. of 7 runs, 10 loops each)
# 64.5 ms ± 788 µs per loop (mean ± std. dev. of 7 runs, 10 loops each)
# 2.49 ms ± 16 µs per loop (mean ± std. dev. of 7 runs, 100 loops each)
# 852 µs ± 8.71 µs per loop (mean ± std. dev. of 7 runs, 1000 loops each)
# 118 ms ± 1.88 ms per loop (mean ± std. dev. of 7 runs, 10 loops each)
# 90.6 ms ± 1.14 ms per loop (mean ± std. dev. of 7 runs, 10 loops each)
# 3.37 ms ± 7.42 µs per loop (mean ± std. dev. of 7 runs, 100 loops each)
# 1.17 ms ± 3.81 µs per loop (mean ± std. dev. of 7 runs, 1000 loops each)
# 168 ms ± 2.21 ms per loop (mean ± std. dev. of 7 runs, 10 loops each)
# 120 ms ± 1.78 ms per loop (mean ± std. dev. of 7 runs, 10 loops each)
# 4.4 ms ± 26.2 µs per loop (mean ± std. dev. of 7 runs, 100 loops each)
# 1.49 ms ± 4.6 µs per loop (mean ± std. dev. of 7 runs, 1000 loops each)
# 216 ms ± 13.5 ms per loop (mean ± std. dev. of 7 runs, 1 loop each)
# 159 ms ± 682 µs per loop (mean ± std. dev. of 7 runs, 10 loops each)
# 6.1 ms ± 11.9 µs per loop (mean ± std. dev. of 7 runs, 100 loops each)
# 2.13 ms ± 22.2 µs per loop (mean ± std. dev. of 7 runs, 100 loops each)
# 310 ms ± 17.3 ms per loop (mean ± std. dev. of 7 runs, 1 loop each)
# 219 ms ± 19.4 ms per loop (mean ± std. dev. of 7 runs, 1 loop each)
# 8.48 ms ± 39.4 µs per loop (mean ± std. dev. of 7 runs, 100 loops each)
# 3.15 ms ± 6.3 µs per loop (mean ± std. dev. of 7 runs, 100 loops each)
# 443 ms ± 20.1 ms per loop (mean ± std. dev. of 7 runs, 1 loop each)
# 289 ms ± 7.4 ms per loop (mean ± std. dev. of 7 runs, 1 loop each)
# 12.6 ms ± 68.4 µs per loop (mean ± std. dev. of 7 runs, 100 loops each)
# 3.88 ms ± 41.5 µs per loop (mean ± std. dev. of 7 runs, 100 loops each)
# 643 ms ± 38.3 ms per loop (mean ± std. dev. of 7 runs, 1 loop each)
# 388 ms ± 2.07 ms per loop (mean ± std. dev. of 7 runs, 1 loop each)
# 13.7 ms ± 102 µs per loop (mean ± std. dev. of 7 runs, 100 loops each)
# 4.91 ms ± 40.8 µs per loop (mean ± std. dev. of 7 runs, 100 loops each)
# 914 ms ± 45 ms per loop (mean ± std. dev. of 7 runs, 1 loop each)
# 538 ms ± 52.4 ms per loop (mean ± std. dev. of 7 runs, 1 loop each)
# 19.9 ms ± 45.5 µs per loop (mean ± std. dev. of 7 runs, 100 loops each)
# 6.83 ms ± 35.3 µs per loop (mean ± std. dev. of 7 runs, 100 loops each)
# 1.14 s ± 47.5 ms per loop (mean ± std. dev. of 7 runs, 1 loop each)
# 714 ms ± 45.6 ms per loop (mean ± std. dev. of 7 runs, 1 loop each)
# 25.4 ms ± 361 µs per loop (mean ± std. dev. of 7 runs, 10 loops each)
# 8.55 ms ± 25.7 µs per loop (mean ± std. dev. of 7 runs, 100 loops each)
# 1.39 s ± 44.8 ms per loop (mean ± std. dev. of 7 runs, 1 loop each)
# 924 ms ± 3.66 ms per loop (mean ± std. dev. of 7 runs, 1 loop each)
# 31.6 ms ± 202 µs per loop (mean ± std. dev. of 7 runs, 10 loops each)
# 11.1 ms ± 60.3 µs per loop (mean ± std. dev. of 7 runs, 100 loops each)
# 1.9 s ± 72.7 ms per loop (mean ± std. dev. of 7 runs, 1 loop each)
# 1.4 s ± 17.2 ms per loop (mean ± std. dev. of 7 runs, 1 loop each)
# 54.6 ms ± 527 µs per loop (mean ± std. dev. of 7 runs, 10 loops each)
# 15.7 ms ± 82 µs per loop (mean ± std. dev. of 7 runs, 100 loops each)
# 2.41 s ± 76.2 ms per loop (mean ± std. dev. of 7 runs, 1 loop each)
# 1.84 s ± 8.63 ms per loop (mean ± std. dev. of 7 runs, 1 loop each)
# 97 ms ± 2.75 ms per loop (mean ± std. dev. of 7 runs, 10 loops each)
# 31.9 ms ± 770 µs per loop (mean ± std. dev. of 7 runs, 10 loops each)
# 5.11 s ± 42 ms per loop (mean ± std. dev. of 7 runs, 1 loop each)
# 2.52 s ± 21.2 ms per loop (mean ± std. dev. of 7 runs, 1 loop each)
# 135 ms ± 1.97 ms per loop (mean ± std. dev. of 7 runs, 10 loops each)
# 44.3 ms ± 1.14 ms per loop (mean ± std. dev. of 7 runs, 10 loops each)
# 6.91 s ± 90.1 ms per loop (mean ± std. dev. of 7 runs, 1 loop each)
# 3.58 s ± 42.8 ms per loop (mean ± std. dev. of 7 runs, 1 loop each)
# 189 ms ± 3.01 ms per loop (mean ± std. dev. of 7 runs, 10 loops each)
# 59.5 ms ± 1.38 ms per loop (mean ± std. dev. of 7 runs, 10 loops each)
# 9.25 s ± 177 ms per loop (mean ± std. dev. of 7 runs, 1 loop each)
# 4.72 s ± 28.1 ms per loop (mean ± std. dev. of 7 runs, 1 loop each)
# 241 ms ± 8.26 ms per loop (mean ± std. dev. of 7 runs, 1 loop each)
# 79.1 ms ± 1.49 ms per loop (mean ± std. dev. of 7 runs, 10 loops each)
# 12.1 s ± 51.8 ms per loop (mean ± std. dev. of 7 runs, 1 loop each)
# 6.29 s ± 28.9 ms per loop (mean ± std. dev. of 7 runs, 1 loop each)
# 324 ms ± 5.92 ms per loop (mean ± std. dev. of 7 runs, 1 loop each)
# 105 ms ± 1.3 ms per loop (mean ± std. dev. of 7 runs, 10 loops each)
# 16.5 s ± 40.3 ms per loop (mean ± std. dev. of 7 runs, 1 loop each)
# 8.43 s ± 19.3 ms per loop (mean ± std. dev. of 7 runs, 1 loop each)
# 430 ms ± 9.44 ms per loop (mean ± std. dev. of 7 runs, 1 loop each)
# 133 ms ± 806 µs per loop (mean ± std. dev. of 7 runs, 10 loops each)
# 22.2 s ± 336 ms per loop (mean ± std. dev. of 7 runs, 1 loop each)
# 11.1 s ± 46.4 ms per loop (mean ± std. dev. of 7 runs, 1 loop each)
# 564 ms ± 14.7 ms per loop (mean ± std. dev. of 7 runs, 1 loop each)
# 170 ms ± 2.61 ms per loop (mean ± std. dev. of 7 runs, 10 loops each)
# 29 s ± 128 ms per loop (mean ± std. dev. of 7 runs, 1 loop each)
# 15.2 s ± 57 ms per loop (mean ± std. dev. of 7 runs, 1 loop each)
# 814 ms ± 35.5 ms per loop (mean ± std. dev. of 7 runs, 1 loop each)
# 262 ms ± 3.9 ms per loop (mean ± std. dev. of 7 runs, 1 loop each)
# 39.3 s ± 428 ms per loop (mean ± std. dev. of 7 runs, 1 loop each)
# 20 s ± 443 ms per loop (mean ± std. dev. of 7 runs, 1 loop each)

# %% [markdown]
# ### Plot Compile Times

# %%
fig_compile, ax_compile = plt.subplots(2, 2, gridspec_kw={'wspace':0.3, 'hspace':0.3}, figsize=(12, 9))
fig_compile.suptitle('Compile Times')
ax_compile_eccen = ax_compile[0, 0]
ax_compile_inclin = ax_compile[0, 1]
ax_compile_calculate = ax_compile[1, 0]
ax_compile_collapse = ax_compile[1, 1]

ax_compile_eccen.set(ylabel='Eccentricity Func [s]')
ax_compile_inclin.set(ylabel='Inclination Func [s]')
ax_compile_calculate.set(ylabel='Calculate Func [s]')
ax_compile_collapse.set(ylabel='Collapse Func [s]')

x_names = ['$l' + f'{order_l}, ' + 'e^{' + f'{trunc}' + '}$' if i%2==0 else '\n$l' + f'{order_l}, ' + 'e^{' + f'{trunc}' + '}$' for i, (order_l, trunc) in enumerate(cases)]

ax_compile_eccen.scatter(range(len(x_names)), eccen_compile_times)
ax_compile_inclin.scatter(range(len(x_names)), inclin_compile_times)
ax_compile_calculate.scatter(range(len(x_names)), calculate_compile_times)
ax_compile_collapse.scatter(range(len(x_names)), collapse_compile_times)

for ax in [ax_compile_eccen, ax_compile_inclin, ax_compile_calculate, ax_compile_collapse]:

    ax.set_xticks(range(len(x_names)))
    ax.set_xticklabels(x_names)

plt.show()
fig_compile.savefig(f'CompileTimePlot_{version}.pdf')

# %% [markdown]
# ### Plot Run Times

# %%
fig_runtime, ax_runtime = plt.subplots(2, 2, gridspec_kw={'wspace':0.2, 'hspace':0.2}, figsize=(12, 9))
fig_runtime.suptitle('Run Times')
ax_runtime_eccen = ax_runtime[0, 0]
ax_runtime_inclin = ax_runtime[0, 1]
ax_runtime_calculate = ax_runtime[1, 0]
ax_runtime_collapse = ax_runtime[1, 1]

ax_runtime_eccen.set(ylabel='Eccentricity Func [s]')
ax_runtime_inclin.set(ylabel='Inclination Func [s]')
ax_runtime_calculate.set(ylabel='Calculate Func [s]')
ax_runtime_collapse.set(ylabel='Collapse Func [s]')

for ax in [ax_runtime_eccen, ax_runtime_inclin, ax_runtime_calculate, ax_runtime_collapse]:
    ax.set(xlabel='N', xscale='log', yscale='log')

for key, (eccen_avg, eccen_std) in eccen_run_times.items():
    inclin_avg, inclin_std = inclin_run_times[key]
    calculate_avg, calculate_std = calculate_run_times[key]
    collapse_avg, collapse_std = collapse_run_times[key]
    ls, order_l, color, eccen_trunc = key

    if color == 'o':
        color = 'orange'

    label = '$l' + f'{order_l}, ' + 'e^{' + f'{eccen_trunc}' + '}$'
    ax_runtime_eccen.errorbar(N_range, eccen_avg, yerr=eccen_std, c=color, ls=ls, label=label)
    ax_runtime_inclin.errorbar(N_range, inclin_avg, yerr=inclin_std, c=color, ls=ls, label=label)
    ax_runtime_calculate.errorbar(N_range, calculate_avg, yerr=calculate_std, c=color, ls=ls, label=label)
    ax_runtime_collapse.errorbar(N_range, collapse_avg, yerr=collapse_std, c=color, ls=ls, label=label)

ax_runtime_inclin.legend(loc='best', ncol=2)
plt.show()
fig_runtime.savefig(f'RunTimePlot_{version}.pdf')
