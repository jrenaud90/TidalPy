# %% [markdown]
# # Eccentricity and Obliquity Function Performance

# %% [markdown]
# ## Obliquity (Inclination) Functions

# %%
from TidalPy.Tides_x.obliquity import obliquity_func

obliquity = 0.7

for l in range(2, 11):
    print(f"\nDegree l = {l}.")
    for trunc in ('gen', 2, 4, 'off'):
        print(f"\tTrunc = {trunc}.")
        # %timeit obliquity_func(obliquity, l, trunc)
# Results as of TidalPy 0.7.1x
# Degree l = 2.
# 	Trunc = gen.
# 2.36 μs ± 30.5 ns per loop (mean ± std. dev. of 7 runs, 100,000 loops each)
# 	Trunc = 2.
# 2.21 μs ± 22.6 ns per loop (mean ± std. dev. of 7 runs, 100,000 loops each)
# 	Trunc = 4.
# 2.31 μs ± 20.7 ns per loop (mean ± std. dev. of 7 runs, 100,000 loops each)
# 	Trunc = off.
# 1.94 μs ± 9.98 ns per loop (mean ± std. dev. of 7 runs, 1,000,000 loops each)
# Degree l = 3.
# 	Trunc = gen.
# 2.6 μs ± 55.7 ns per loop (mean ± std. dev. of 7 runs, 100,000 loops each)
# 	Trunc = 2.
# 2.39 μs ± 25.7 ns per loop (mean ± std. dev. of 7 runs, 100,000 loops each)
# 	Trunc = 4.
# 2.56 μs ± 48.3 ns per loop (mean ± std. dev. of 7 runs, 100,000 loops each)
# 	Trunc = off.
# 1.94 μs ± 12.2 ns per loop (mean ± std. dev. of 7 runs, 1,000,000 loops each)
# ...
# Degree l = 10.
# 	Trunc = gen.
# 5.22 μs ± 67.4 ns per loop (mean ± std. dev. of 7 runs, 100,000 loops each)
# 	Trunc = 2.
# 3.94 μs ± 34.9 ns per loop (mean ± std. dev. of 7 runs, 100,000 loops each)
# 	Trunc = 4.
# 4.07 μs ± 37.2 ns per loop (mean ± std. dev. of 7 runs, 100,000 loops each)
# 	Trunc = off.
# 2.92 μs ± 36.6 ns per loop (mean ± std. dev. of 7 runs, 100,000 loops each)
# Out:
# Degree l = 2.
# 	Trunc = gen.
# 2.36 μs ± 30.5 ns per loop (mean ± std. dev. of 7 runs, 100,000 loops each)
# 	Trunc = 2.
# 2.21 μs ± 22.6 ns per loop (mean ± std. dev. of 7 runs, 100,000 loops each)
# 	Trunc = 4.
# 2.31 μs ± 20.7 ns per loop (mean ± std. dev. of 7 runs, 100,000 loops each)
# 	Trunc = off.
# 1.94 μs ± 9.98 ns per loop (mean ± std. dev. of 7 runs, 1,000,000 loops each)
#
# Degree l = 3.
# 	Trunc = gen.
# 2.6 μs ± 55.7 ns per loop (mean ± std. dev. of 7 runs, 100,000 loops each)
# 	Trunc = 2.
# 2.39 μs ± 25.7 ns per loop (mean ± std. dev. of 7 runs, 100,000 loops each)
# 	Trunc = 4.
# 2.56 μs ± 48.3 ns per loop (mean ± std. dev. of 7 runs, 100,000 loops each)
# 	Trunc = off.
# 1.94 μs ± 12.2 ns per loop (mean ± std. dev. of 7 runs, 1,000,000 loops each)
#
# Degree l = 4.
# 	Trunc = gen.
# 3.09 μs ± 57.6 ns per loop (mean ± std. dev. of 7 runs, 100,000 loops each)
# 	Trunc = 2.
# 2.65 μs ± 21.8 ns per loop (mean ± std. dev. of 7 runs, 100,000 loops each)
# 	Trunc = 4.
# 2.76 μs ± 73.2 ns per loop (mean ± std. dev. of 7 runs, 100,000 loops each)
# 	Trunc = off.
# 2.33 μs ± 34.8 ns per loop (mean ± std. dev. of 7 runs, 100,000 loops each)
#
# Degree l = 5.
# 	Trunc = gen.
# 3.24 μs ± 59.7 ns per loop (mean ± std. dev. of 7 runs, 100,000 loops each)
# 	Trunc = 2.
# 2.81 μs ± 53.1 ns per loop (mean ± std. dev. of 7 runs, 100,000 loops each)
# 	Trunc = 4.
# 2.96 μs ± 36.8 ns per loop (mean ± std. dev. of 7 runs, 100,000 loops each)
# 	Trunc = off.
# 2.34 μs ± 58.2 ns per loop (mean ± std. dev. of 7 runs, 100,000 loops each)
#
# Degree l = 6.
# 	Trunc = gen.
# 3.5 μs ± 51.4 ns per loop (mean ± std. dev. of 7 runs, 100,000 loops each)
# 	Trunc = 2.
# 3.09 μs ± 40.9 ns per loop (mean ± std. dev. of 7 runs, 100,000 loops each)
# 	Trunc = 4.
# 3.15 μs ± 42.2 ns per loop (mean ± std. dev. of 7 runs, 100,000 loops each)
# 	Trunc = off.
# 2.5 μs ± 11.1 ns per loop (mean ± std. dev. of 7 runs, 100,000 loops each)
#
# Degree l = 7.
# 	Trunc = gen.
# 3.97 μs ± 42.1 ns per loop (mean ± std. dev. of 7 runs, 100,000 loops each)
# 	Trunc = 2.
# 3.24 μs ± 32.8 ns per loop (mean ± std. dev. of 7 runs, 100,000 loops each)
# 	Trunc = 4.
# 3.3 μs ± 10.3 ns per loop (mean ± std. dev. of 7 runs, 100,000 loops each)
# 	Trunc = off.
# 2.49 μs ± 31.5 ns per loop (mean ± std. dev. of 7 runs, 100,000 loops each)
#
# Degree l = 8.
# 	Trunc = gen.
# 4.39 μs ± 22.4 ns per loop (mean ± std. dev. of 7 runs, 100,000 loops each)
# 	Trunc = 2.
# 3.43 μs ± 47.2 ns per loop (mean ± std. dev. of 7 runs, 100,000 loops each)
# 	Trunc = 4.
# 3.58 μs ± 34.4 ns per loop (mean ± std. dev. of 7 runs, 100,000 loops each)
# 	Trunc = off.
# 2.92 μs ± 37.8 ns per loop (mean ± std. dev. of 7 runs, 100,000 loops each)
#
# Degree l = 9.
# 	Trunc = gen.
# 4.6 μs ± 62.2 ns per loop (mean ± std. dev. of 7 runs, 100,000 loops each)
# 	Trunc = 2.
# 3.63 μs ± 34 ns per loop (mean ± std. dev. of 7 runs, 100,000 loops each)
# 	Trunc = 4.
# 3.96 μs ± 27.3 ns per loop (mean ± std. dev. of 7 runs, 100,000 loops each)
# 	Trunc = off.
# 2.89 μs ± 67.5 ns per loop (mean ± std. dev. of 7 runs, 100,000 loops each)
#
# Degree l = 10.
# 	Trunc = gen.
# 5.22 μs ± 67.4 ns per loop (mean ± std. dev. of 7 runs, 100,000 loops each)
# 	Trunc = 2.
# 3.94 μs ± 34.9 ns per loop (mean ± std. dev. of 7 runs, 100,000 loops each)
# 	Trunc = 4.
# 4.07 μs ± 37.2 ns per loop (mean ± std. dev. of 7 runs, 100,000 loops each)
# 	Trunc = off.
# 2.92 μs ± 36.6 ns per loop (mean ± std. dev. of 7 runs, 100,000 loops each)
